# %% [markdown]
# ## Nasdaq 100 Galaxy
#
# Use this utility to update the returns and std_dev fields within `investment-options.csv`.
# Constituents are loaded from `nasdaq100.csv`.

# %% [markdown]
# ### Settings

# %%
# Set refresh_timeseries=True to download timeseries. Otherwise symbol-cache is used.
refresh_timeseries = False
throttle_limit = 100
wait_time = 30

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# ### Build investment-options.csv

# %%
from pathlib import Path

import brownbear as bb

bb.notebook_display_options()

directory = Path('.')
universe = bb.load_nasdaq100_universe(directory)

investment_options = bb.update_investment_options(
    directory=directory,
    universe_df=universe,
    refresh_timeseries=refresh_timeseries,
    throttle_limit=throttle_limit,
    wait_time=wait_time,
)
investment_options
# Out:
# ADBE AMD ABNB ALNY GOOGL GOOG AMZN AEP AMGN ADI AAPL AMAT APP ARM ASML ADSK ADP AXON BKR BKNG AVGO CDNS CHTR CTAS CSCO CCEP CTSH CMCSA CEG CPRT COST CRWD CSX DDOG DXCM FANG DASH EA EXC FAST FER FTNT GEHC GILD HON IDXX INSM INTC INTU ISRG KDP KLAC KHC LRCX LIN LITE MAR MRVL MELI META MCHP MU MSFT MSTR MDLZ MPWR MNST NFLX NVDA NXPI ORLY ODFL PCAR PLTR PANW PAYX PYPL PDD PEP QCOM REGN ROP ROST SNDK STX SHOP SBUX SNPS TMUS TTWO TSLA TXN TRI VRSK VRTX WMT WBD WDC WDAY XEL
# Throttle limit reached. Waiting for 0 seconds...
# ZS
#     Investment Option                     Description Asset Class    3 mo  \
# 0                ADBE                      Adobe Inc.   US Stocks  -56.30
# 1                 AMD          Advanced Micro Devices   US Stocks  216.51
# 2                ABNB                          Airbnb   US Stocks   29.31
# 3                ALNY         Alnylam Pharmaceuticals   US Stocks  -44.90
# 4               GOOGL         Alphabet Inc. (Class A)   US Stocks   17.97
# ...
