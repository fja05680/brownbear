# %% [markdown]
# # List of Nasdaq 100 companies
#
# Retreive from https://en.wikipedia.org/wiki/NASDAQ-100#Components
#
# output: 'nasdaq100.csv'

# %%
from datetime import datetime

import numpy as np
import pandas as pd

from brownbear.utility import get_wikipedia_table

pd.options.mode.chained_assignment = None  # default='warn'
pd.set_option('display.max_rows', 200)

# -*- encoding: utf-8 -*-
# %matplotlib inline

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
get_table = get_wikipedia_table

# %%
title = 'Nasdaq-100'
filename = 'nasdaq100.csv'
nasdaq100 = get_table(title, filename, match='Ticker')

# dd/mm/YY H:M:S
now = datetime.now()
dt_string = now.strftime("%m/%d/%Y %H:%M:%S")
print('{} (retrieved {})'.format(title, dt_string))
nasdaq100
# Out:
# Nasdaq-100 (retrieved 06/18/2026 22:14:50)
#     Ticker                         Company        ICB Industry[15]  \
# 0     ADBE                      Adobe Inc.              Technology
# 1      AMD          Advanced Micro Devices              Technology
# 2     ABNB                          Airbnb  Consumer Discretionary
# 3     ALNY         Alnylam Pharmaceuticals             Health Care
# 4    GOOGL         Alphabet Inc. (Class A)              Technology
# 5     GOOG         Alphabet Inc. (Class C)              Technology
# 6     AMZN                          Amazon  Consumer Discretionary
# 7      AEP         American Electric Power               Utilities
# 8     AMGN                           Amgen             Health Care
# 9      ADI                  Analog Devices              Technology
# 10    AAPL                      Apple Inc.              Technology
# 11    AMAT               Applied Materials              Technology
# ...
