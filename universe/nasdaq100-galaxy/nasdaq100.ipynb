# %% [markdown]
# # List of Nasdaq 100 companies
#
# Retreive from https://en.wikipedia.org/wiki/NASDAQ-100#Components
#
# output: 'nasdaq100.csv'

# %%
# Imports
from datetime import datetime
import numpy as np
import pandas as pd
import os
import re
import shutil
import wikipedia as wp

pd.options.mode.chained_assignment = None  # default='warn'
pd.set_option('display.max_rows', 200)

# -*- encoding: utf-8 -*-
# %matplotlib inline

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
def get_table(title, filename, match, use_cache=False):

    if use_cache and os.path.isfile(filename):
        pass
    else:
        html = wp.page(title).html()
        df = pd.read_html(html, header=0, match=match)[0]
        
        df.to_csv(filename, header=True, index=False, encoding='utf-8')
            
    df = pd.read_csv(filename)
    return df

# %%
title = 'NASDAQ-100'
filename = 'nasdaq100.csv'
sp400 = get_table(title, filename, match='Ticker')

# dd/mm/YY H:M:S
now = datetime.now()
dt_string = now.strftime("%m/%d/%Y %H:%M:%S")
print('{} (retrieved {})'.format(title, dt_string))
sp400
# Out:
# NASDAQ-100 (retrieved 12/04/2020 21:38:21)
#                                         Company Ticker
# 0                           Activision Blizzard   ATVI
# 1                                    Adobe Inc.   ADBE
# 2                        Advanced Micro Devices    AMD
# 3                       Alexion Pharmaceuticals   ALXN
# 4                              Align Technology   ALGN
# 5                       Alphabet Inc. (Class A)  GOOGL
# 6                       Alphabet Inc. (Class C)   GOOG
# 7                                    Amazon.com   AMZN
# 8                                         Amgen   AMGN
# 9                                Analog Devices    ADI
# 10                                        ANSYS   ANSS
# 11                                   Apple Inc.   AAPL
# 12                      Applied Materials, Inc.   AMAT
# 13                                 ASML Holding   ASML
# 14                                     Autodesk   ADSK
# 15              Automatic Data Processing, Inc.    ADP
# 16                                        Baidu   BIDU
# 17                                       Biogen   BIIB
# 18                 BioMarin Pharmaceutical Inc.   BMRN
# 19                             Booking Holdings   BKNG
# 20                                Broadcom Inc.   AVGO
# 21                       Cadence Design Systems   CDNS
# 22                                          CDW    CDW
# 23                           Cerner Corporation   CERN
# 24                 Charter Communications, Inc.   CHTR
# 25       Check Point Software Technologies Ltd.   CHKP
# 26                           Cintas Corporation   CTAS
# 27                                Cisco Systems   CSCO
# 28                               Citrix Systems   CTXS
# 29   Cognizant Technology Solutions Corporation   CTSH
# 30                          Comcast Corporation  CMCSA
# 31                                       Copart   CPRT
# 32                 Costco Wholesale Corporation   COST
# 33                              CSX Corporation    CSX
# 34                                       DexCom   DXCM
# 35                                     DocuSign   DOCU
# 36                            Dollar Tree, Inc.   DLTR
# 37                                    eBay Inc.   EBAY
# 38                              Electronic Arts     EA
