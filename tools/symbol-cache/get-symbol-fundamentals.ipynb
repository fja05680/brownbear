# %% [markdown]
# # Get Symbol Fundamentals
#
# Get fundamental data of any or all symbols in symbol_cache

# %%
import numpy as np
import pandas as pd
import yfinance as yf

import brownbear as bb

# Format price data.
pd.options.display.float_format = '{:0.2f}'.format

# Increase display of dataframe rows.
pd.set_option('display.max_rows', 1500)

# %%
# Keep - useful for looking at data returned from yahooquery.
ticker = yf.Ticker('MO')
info = ticker.info
print(info.get('shortName', None))  # Short name of the company
print(info.get('previousClose', np.nan))
print(info.get('trailingPE', np.nan))
print(info.get('dividendYield', 0) * 100)  # Convert to percentage
print(info.get('marketCap', 0) / 1_000_000)  # Convert to million
info
# Out:
# Altria Group, Inc.
# 58.55
# 9.007646
# 693.0
# 99596.77952
# {'address1': '6601 West Broad Street',
#  'city': 'Richmond',
#  'state': 'VA',
#  'zip': '23230',
#  'country': 'United States',
#  'phone': '804 274 2200',
#  'website': 'https://www.altria.com',
#  'industry': 'Tobacco',
#  'industryKey': 'tobacco',
#  'industryDisp': 'Tobacco',
#  'sector': 'Consumer Defensive',
#  'sectorKey': 'consumer-defensive',
#  'sectorDisp': 'Consumer Defensive',
#  'longBusinessSummary': 'Altria Group, Inc., through its subsidiaries, manufactures and sells smokeable and oral tobacco products in the United States. The company offers cigarettes primarily under the Marlboro brand; large cigars and pipe tobacco under the Black & Mild brand; moist smokeless tobacco and oral tobacco products under the Copenhagen, Skoal, Red Seal, and Husky brands; oral nicotine pouches under the on! brand; and e-vapor products under the NJOY ACE brand. It sells its products to distributors, as well as large retail organizations, such as chain stores. Altria Group, Inc. was founded in 1822 and is headquartered in Richmond, Virginia.',
#  'fullTimeEmployees': 6200,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. William F. Gifford Jr.',
#    'age': 54,
#    'title': 'CEO & Director',
#    'yearBorn': 1970,
#    'fiscalYear': 2015,
#    'totalPay': 8298071,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Salvatore  Mancuso',
#    'age': 59,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1965,
#    'fiscalYear': 2015,
#    'totalPay': 2853789,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jody L. Begley',
#    'age': 51,
#    'title': 'Executive VP & COO',
#    'yearBorn': 1973,
#    'fiscalYear': 2015,
#    'totalPay': 2865223,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Heather A. Newman',
#    'age': 46,
#    'title': 'Senior VP and Chief Strategy & Growth Officer',
#    'yearBorn': 1978,
#    'fiscalYear': 2015,
#    'totalPay': 2181408,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Charles N. Whitaker J.D.',
#    'age': 57,
#    'title': 'Senior VP, Chief Human Resources Officer & Chief Compliance Officer',
#    'yearBorn': 1967,
#    'fiscalYear': 2015,
#    'totalPay': 1042492,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mac  Livingston',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Robert A. McCarter III, J.D.',
#    'age': 51,
#    'title': 'Executive VP & General Counsel',
#    'yearBorn': 1973,
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Jennifer  Hunter',
#    'title': 'Senior VP of Corporate Citizenship & Chief Sustainability Officer - Altria Client Services LLC',
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Shannon  Leistra',
#    'title': 'President & CEO of NJOY, LLC',
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Paige  Magness',
#    'title': 'Senior Vice President of Regulatory Affairs - Altria Client Services LLC',
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 6,
#  'boardRisk': 1,
#  'compensationRisk': 1,
#  'shareHolderRightsRisk': 6,
#  'overallRisk': 2,
#  'governanceEpochDate': 1740787200,
#  'compensationAsOfEpochDate': 1451520000,
#  'irWebsite': 'http://investor.altria.com/phoenix.zhtml?c=80855&p=irol-irhome&src=top_nav',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 58.55,
#  'open': 58.15,
#  'dayLow': 58.15,
#  'dayHigh': 59.105,
#  'regularMarketPreviousClose': 58.55,
#  'regularMarketOpen': 58.15,
#  'regularMarketDayLow': 58.15,
#  'regularMarketDayHigh': 59.105,
#  'dividendRate': 4.08,
#  'dividendYield': 6.93,
#  'exDividendDate': 1742860800,
#  'payoutRatio': 0.6116,
#  'fiveYearAvgDividendYield': 8.02,
#  'beta': 0.606,
#  'trailingPE': 9.007646,
#  'forwardPE': 11.011215,
#  'volume': 6954050,
#  'regularMarketVolume': 6954050,
#  'averageVolume': 8473503,
#  'averageVolume10days': 11064330,
#  'averageDailyVolume10Day': 11064330,
#  'bid': 58.68,
#  'ask': 58.89,
#  'bidSize': 8,
#  'askSize': 8,
#  'marketCap': 99596779520,
#  'fiftyTwoWeekLow': 40.65,
#  'fiftyTwoWeekHigh': 59.67,
#  'priceToSalesTrailing12Months': 4.8716874,
#  'fiftyDayAverage': 53.774,
#  'twoHundredDayAverage': 51.6798,
#  'trailingAnnualDividendRate': 4.0,
#  'trailingAnnualDividendYield': 0.06831768,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 121445875712,
#  'profitMargins': 0.55097,
#  'floatShares': 1687500104,
#  'sharesOutstanding': 1690659968,
#  'sharesShort': 37890284,
#  'sharesShortPriorMonth': 32778625,
#  'sharesShortPreviousMonthDate': 1738281600,
#  'dateShortInterest': 1740700800,
#  'sharesPercentSharesOut': 0.0224,
#  'heldPercentInsiders': 0.00122,
#  'heldPercentInstitutions': 0.61279,
#  'shortRatio': 4.76,
#  'shortPercentOfFloat': 0.0224,
#  'impliedSharesOutstanding': 1690659968,
#  'bookValue': -1.324,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1735603200,
#  'earningsQuarterlyGrowth': 0.475,
#  'netIncomeToCommon': 11235999744,
#  'trailingEps': 6.54,
#  'forwardEps': 5.35,
#  'lastSplitFactor': '3:1',
#  'lastSplitDate': 860716800,
#  'enterpriseToRevenue': 5.94,
#  'enterpriseToEbitda': 9.804,
#  '52WeekChange': 0.3235228,
#  'SandP52WeekChange': 0.09506309,
#  'lastDividendValue': 1.02,
#  'lastDividendDate': 1735171200,
#  'quoteType': 'EQUITY',
#  'currentPrice': 58.91,
#  'targetHighPrice': 73.0,
#  'targetLowPrice': 42.0,
#  'targetMeanPrice': 56.66462,
#  'targetMedianPrice': 58.0,
#  'recommendationMean': 2.57143,
#  'recommendationKey': 'hold',
#  'numberOfAnalystOpinions': 13,
#  'totalCash': 3127000064,
#  'totalCashPerShare': 1.85,
#  'ebitda': 12387000320,
#  'totalDebt': 24925999104,
#  'quickRatio': 0.387,
#  'currentRatio': 0.514,
#  'totalRevenue': 20444000256,
#  'revenuePerShare': 11.9,
#  'returnOnAssets': 0.20511,
#  'grossProfits': 14337999872,
#  'freeCashflow': 4630249984,
#  'operatingCashflow': 8753000448,
#  'earningsGrowth': 0.539,
#  'revenueGrowth': 0.016,
#  'grossMargins': 0.70133,
#  'ebitdaMargins': 0.6059,
#  'operatingMargins': 0.60987,
#  'financialCurrency': 'USD',
#  'symbol': 'MO',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'marketState': 'CLOSED',
#  'shortName': 'Altria Group, Inc.',
#  'longName': 'Altria Group, Inc.',
#  'regularMarketPrice': 58.91,
#  'regularMarketChangePercent': 0.61486,
#  'corporateActions': [{'header': 'Dividend',
#    'message': 'MO announced a cash dividend of 1.02 with an ex-date of Mar. 25, 2025',
#    'meta': {'eventType': 'DIVIDEND',
#     'dateEpochMs': 1742875200000,
#     'amount': '1.02'}}],
#  'postMarketTime': 1741996770,
#  'regularMarketTime': 1741982402,
#  'fullExchangeName': 'NYSE',
#  'averageDailyVolume3Month': 8473503,
#  'fiftyTwoWeekLowChange': 18.259998,
#  'fiftyTwoWeekLowChangePercent': 0.44920042,
#  'fiftyTwoWeekRange': '40.65 - 59.67',
#  'fiftyTwoWeekHighChange': -0.7599983,
#  'fiftyTwoWeekHighChangePercent': -0.012736691,
#  'fiftyTwoWeekChangePercent': 32.35228,
#  'dividendDate': 1745971200,
#  'earningsTimestamp': 1745929800,
#  'earningsTimestampStart': 1745929800,
#  'earningsTimestampEnd': 1745929800,
#  'earningsCallTimestampStart': 1745931600,
#  'earningsCallTimestampEnd': 1745931600,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 6.54,
#  'epsForward': 5.35,
#  'epsCurrentYear': 5.34024,
#  'priceEpsCurrentYear': 11.03134,
#  'fiftyDayAverageChange': 5.1360016,
#  'fiftyDayAverageChangePercent': 0.09551088,
#  'twoHundredDayAverageChange': 7.2302017,
#  'twoHundredDayAverageChangePercent': 0.13990383,
#  'priceToBook': -44.493958,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '2.6 - Hold',
#  'cryptoTradeable': False,
#  'postMarketChangePercent': -0.0679017,
#  'postMarketPrice': 58.87,
#  'postMarketChange': -0.0400009,
#  'regularMarketChange': 0.360001,
#  'regularMarketDayRange': '58.15 - 59.105',
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': -252322200000,
#  'exchange': 'NYQ',
#  'messageBoardId': 'finmb_53839346',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'gmtOffSetMilliseconds': -14400000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'displayName': 'Altria',
#  'trailingPegRatio': 4.0147}

# %% [markdown]
# Get fundamental data for the symbols below

# %%
# Important: set reset_cache=True at first, then set to False
df = bb.get_symbol_fundamentals(throttle_limit=100, wait_time=30, reset_cache=False)
df
# Out:
# Fetching fundamental data for 8 symbols...
# VVI
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/VVI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=VVI&crumb=r6fAHajWdl2
# Error fetching data for VVI: 'NoneType' object has no attribute 'update'
# ALTM
# Error fetching data for ALTM: list index out of range
# ROIC
# Error fetching data for ROIC: list index out of range
# NARI
# Error fetching data for NARI: list index out of range
# JBT
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/JBT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=JBT&crumb=r6fAHajWdl2
# Error fetching data for JBT: 'NoneType' object has no attribute 'update'
# BSIG
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/BSIG?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=BSIG&crumb=r6fAHajWdl2
# Error fetching data for BSIG: 'NoneType' object has no attribute 'update'
# TPX
# Error fetching data for TPX: list index out of range
# IEF
#                             companyName  previousClose trailingPE  \
# symbol
# VC                  Visteon Corporation          80.77       8.21
# VRTS    Virtus Investment Partners, Inc         167.94      10.27
# VDE                 Vanguard Energy ETF         120.86      13.74
# UAL      United Airlines Holdings, Inc.          69.90       7.80
# CWK             Cushman & Wakefield plc          10.39      19.09
# ...                                 ...            ...        ...
# SWI              SolarWinds Corporation          18.30      28.66
# COLL     Collegium Pharmaceutical, Inc.          29.10      15.84
# ARR       ARMOUR Residential REIT, Inc.          18.58          0
# OHI     Omega Healthcare Investors, Inc          36.77      24.27
# IEF     iShares 7-10 Year Treasury Bond          94.81          0
#
#         dividendYield  marketCap
# symbol
# VC               0.00    2182.96
# VRTS           519.00    1207.61
# VDE            310.00    5193.08
# UAL              0.00   24115.14
# CWK              0.00    2455.78
# ...               ...        ...
# SWI              0.00    3147.27
# COLL             0.00     927.56
# ARR           1532.00    1436.60
# OHI            712.00   10882.49
# IEF            358.00   13794.08
#
# [1627 rows x 5 columns]

# %%
df.to_csv('fundamentals.csv', encoding="utf-8")
