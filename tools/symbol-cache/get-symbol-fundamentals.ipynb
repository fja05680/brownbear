# %% [markdown]
# # Get Symbol Fundamentals
#
# Get fundamental data of any or all symbols in symbol_cache

# %%
import numpy as np
import pandas as pd
import yfinance as yf

import brownbear as bb

# Format price data.
pd.options.display.float_format = '{:0.2f}'.format

# Increase display of dataframe rows.
pd.set_option('display.max_rows', 1500)

# %%
# Keep - useful for looking at data returned from yahooquery.
ticker = yf.Ticker('MO')
info = ticker.info
print(info.get('shortName', None))  # Short name of the company
print(info.get('previousClose', np.nan))
print(info.get('trailingPE', np.nan))
print(info.get('dividendYield', 0) * 100)  # Convert to percentage
print(info.get('marketCap', 0) / 1_000_000)  # Convert to million
info
# Out:
# Altria Group, Inc.
# 51.54
# 7.9862385
# 7.75
# 88302.649344
# {'address1': '6601 West Broad Street',
#  'city': 'Richmond',
#  'state': 'VA',
#  'zip': '23230',
#  'country': 'United States',
#  'phone': '804 274 2200',
#  'website': 'https://www.altria.com',
#  'industry': 'Tobacco',
#  'industryKey': 'tobacco',
#  'industryDisp': 'Tobacco',
#  'sector': 'Consumer Defensive',
#  'sectorKey': 'consumer-defensive',
#  'sectorDisp': 'Consumer Defensive',
#  'longBusinessSummary': 'Altria Group, Inc., through its subsidiaries, manufactures and sells smokeable and oral tobacco products in the United States. The company offers cigarettes primarily under the Marlboro brand; large cigars and pipe tobacco under the Black & Mild brand; moist smokeless tobacco and snus products under the Copenhagen, Skoal, Red Seal, and Husky brands; oral nicotine pouches under the on! brand; and e-vapor products under the NJOY ACE brand. It sells its products to distributors, as well as large retail organizations, such as chain stores. The company was founded in 1822 and is headquartered in Richmond, Virginia.',
#  'fullTimeEmployees': 6400,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. William F. Gifford Jr.',
#    'age': 54,
#    'title': 'CEO & Director',
#    'yearBorn': 1970,
#    'fiscalYear': 2015,
#    'totalPay': 8298071,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Salvatore  Mancuso',
#    'age': 58,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1966,
#    'fiscalYear': 2015,
#    'totalPay': 2853789,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jody L. Begley',
#    'age': 52,
#    'title': 'Executive VP & COO',
#    'yearBorn': 1972,
#    'fiscalYear': 2015,
#    'totalPay': 2865223,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Heather A. Newman',
#    'age': 47,
#    'title': 'Senior VP and Chief Strategy & Growth Officer',
#    'yearBorn': 1977,
#    'fiscalYear': 2015,
#    'totalPay': 2181408,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Charles N. Whitaker J.D.',
#    'age': 57,
#    'title': 'Senior VP, Chief Human Resources Officer & Chief Compliance Officer',
#    'yearBorn': 1967,
#    'fiscalYear': 2015,
#    'totalPay': 1042492,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mac  Livingston',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Robert A. McCarter III',
#    'title': 'Executive VP & General Counsel',
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Jennifer  Hunter',
#    'title': 'Senior VP of Corporate Citizenship & Chief Sustainability Officer - Altria Client Services LLC',
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Shannon  Leistra',
#    'title': 'President & CEO of NJOY, LLC',
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Paige  Magness',
#    'title': 'Senior Vice President of Regulatory Affairs - Altria Client Services LLC',
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 6,
#  'boardRisk': 1,
#  'compensationRisk': 1,
#  'shareHolderRightsRisk': 6,
#  'overallRisk': 2,
#  'governanceEpochDate': 1735689600,
#  'compensationAsOfEpochDate': 1451520000,
#  'irWebsite': 'http://investor.altria.com/phoenix.zhtml?c=80855&p=irol-irhome&src=top_nav',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 51.54,
#  'open': 51.3,
#  'dayLow': 51.3,
#  'dayHigh': 52.455,
#  'regularMarketPreviousClose': 51.54,
#  'regularMarketOpen': 51.3,
#  'regularMarketDayLow': 51.3,
#  'regularMarketDayHigh': 52.455,
#  'dividendRate': 4.08,
#  'dividendYield': 0.0775,
#  'exDividendDate': 1735171200,
#  'payoutRatio': 0.6689,
#  'fiveYearAvgDividendYield': 8.03,
#  'beta': 0.67,
#  'trailingPE': 7.9862385,
#  'forwardPE': 9.442695,
#  'volume': 6371059,
#  'regularMarketVolume': 6371059,
#  'averageVolume': 7769956,
#  'averageVolume10days': 9216580,
#  'averageDailyVolume10Day': 9216580,
#  'bid': 51.88,
#  'ask': 52.21,
#  'bidSize': 800,
#  'askSize': 1300,
#  'marketCap': 88302649344,
#  'fiftyTwoWeekLow': 39.25,
#  'fiftyTwoWeekHigh': 58.04,
#  'priceToSalesTrailing12Months': 4.3366394,
#  'fiftyDayAverage': 53.8508,
#  'twoHundredDayAverage': 50.0714,
#  'currency': 'USD',
#  'enterpriseValue': 112556851200,
#  'profitMargins': 0.50511,
#  'floatShares': 1691847059,
#  'sharesOutstanding': 1690649984,
#  'sharesShort': 30611931,
#  'sharesShortPriorMonth': 28336534,
#  'sharesShortPreviousMonthDate': 1734048000,
#  'dateShortInterest': 1736899200,
#  'sharesPercentSharesOut': 0.018099999,
#  'heldPercentInsiders': 0.00122,
#  'heldPercentInstitutions': 0.60831,
#  'shortRatio': 3.82,
#  'shortPercentOfFloat': 0.018099999,
#  'impliedSharesOutstanding': 1694809984,
#  'bookValue': -2.044,
#  'lastFiscalYearEnd': 1703980800,
#  'nextFiscalYearEnd': 1735603200,
#  'mostRecentQuarter': 1727654400,
#  'earningsQuarterlyGrowth': 0.059,
#  'netIncomeToCommon': 10259999744,
#  'trailingEps': 6.54,
#  'forwardEps': 5.35,
#  'lastSplitFactor': '3:1',
#  'lastSplitDate': 860716800,
#  'enterpriseToRevenue': 5.528,
#  'enterpriseToEbitda': 9.214,
#  '52WeekChange': 0.28899312,
#  'SandP52WeekChange': 0.22208416,
#  'lastDividendValue': 1.02,
#  'lastDividendDate': 1735171200,
#  'exchange': 'NYQ',
#  'quoteType': 'EQUITY',
#  'symbol': 'MO',
#  'underlyingSymbol': 'MO',
#  'shortName': 'Altria Group, Inc.',
#  'longName': 'Altria Group, Inc.',
#  'firstTradeDateEpochUtc': -252322200,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': 'eb0459bf-ce41-3588-8ecf-61fb07987581',
#  'messageBoardId': 'finmb_53839346',
#  'gmtOffSetMilliseconds': -18000000,
#  'currentPrice': 52.23,
#  'targetHighPrice': 73.0,
#  'targetLowPrice': 42.0,
#  'targetMeanPrice': 56.20308,
#  'targetMedianPrice': 57.64,
#  'recommendationMean': 2.57143,
#  'recommendationKey': 'hold',
#  'numberOfAnalystOpinions': 13,
#  'totalCash': 1896999936,
#  'totalCashPerShare': 1.119,
#  'ebitda': 12216000512,
#  'totalDebt': 25155000320,
#  'quickRatio': 0.274,
#  'currentRatio': 0.438,
#  'totalRevenue': 20362000384,
#  'revenuePerShare': 11.726,
#  'returnOnAssets': 0.21103,
#  'grossProfits': 14204000256,
#  'freeCashflow': 4325499904,
#  'operatingCashflow': 8640000000,
#  'earningsGrowth': 0.099,
#  'revenueGrowth': 0.013,
#  'grossMargins': 0.69757,
#  'ebitdaMargins': 0.59994,
#  'operatingMargins': 0.59843,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 3.6533}

# %% [markdown]
# Get fundamental data for the symbols below

# %%
df = bb.get_symbol_fundamentals(throttle_limit=100, wait_time=30)
df
# Out:
# VC VRTS VDE UAL CWK WAL ITRI LII APLE ET CHWY VNT BLDR FCX HCI PTGX TXN L MATW GMED MGPI MSI SJW TALO SIG UGI WMT HCC MUR NWS MUSA KKR EIX YELP WH IBOC POWL GATX SSD CUBI STEP BRK-B NNN AME NEM PRU FFBC SW COLM MLKN R TSLA VNQ PAG ESNT RDNT NBHC KNSL EPRT SNCY CELH SBSI ETN OMC GEV CRM EVR WM LSTR MSGS LANC SR META VSAT BMRN NBIX RYN BWXT PUMP CRI CMA BDC MTD DBE AZPN PVH XLP EWT AVGO UUP VST PRG FLGT AMED IBIT TECH XLB FN BX QCOM
# Throttle limit reached. Waiting for 30 seconds...
# AIN PNW DGII GRMN PODD IVZ FOXF MCK PLTR DBA PLUS NTCT FTNT SHAK EXTR FXC ACN KO HRL PFE TFIN FICO CMC CBT UGA CENX NDAQ SABR AESI NEU RCL MKC GE HAFC YUM VVI APO IYR SPGI NEE CHX CHDN HTZ LPG EOG MDB ACM CTRA WU CHH AAP TAP TEL GVA NPK TMP DHI DAY AR BRBR MSEX APTV IDXX ADM ANIP PBF BDN SLM URBN ALLY EVTC AIT MO JBSS TILE THS UFPT TXRH ROCK CHRW FITB CFR GIS LMAT SLP SHEN LEG WEC TJX TCBI FSS BOOT ENOV CPRX NSC UNM ETSY NPO AZN PK
# Throttle limit reached. Waiting for 30 seconds...
# LH WBD KBR TPL CLB AOM HSY XRAY HXL VLTO PAYC AZO BOH RSP ROKU LRN MP WCC MTRN SBCF SEM PFG AMH ON ABNB AVNT UTHR BKE TYL EA THC ACLS COF UVV STC CDP CCOI OII NSP GWW CORN HAE MELI CVCO OUT XHR TWO NABL VSCO VTSMX SCHW ALB DLR ROIV TXT GME SPY ATGE MCO VPL ORI VRTX KD MOG-A BKNG GEO XRX WMG BGS MDU ALTM VICI GNW DG AXON NBTB GTES ROG NWE FTV PARR PLAY CHCO MNST PB CRUS VCIT FBTC QRVO LDOS HUM VNO FOX STAA QDEL MDLZ GNL EPD JCI SSTK
# Throttle limit reached. Waiting for 30 seconds...
# CXM FBK BITW APP OTTR AAON AM ANDE PCRX HLI HMN CART AVA GTY ELME PAYX SRE TGTX BC PRAA EBND PECO TSN ABT HBI PII EPAM PR USB KNF CUBE ROIC AAT MIDD BBWI TMDX MMS HQY CW AZTA PCH CI HON CBOE RBA ATEN NARI SKT HWC TMHC MKTX AGO EYE GEN NYT EPAC GM RSG ROL EXPO TRMK RRX CXW BKU SXC ED OFG IAC WAFD NATL CCS CNP NWN CPRI CTA KMI FAF AAL CAT EWH REXR CTAS BIL ADUS WS TTGT AES APPF TSCO AHCO EQH MXL AGYS EAT PTEN KMPR DBP CAKE ASTE ACHC
# Throttle limit reached. Waiting for 30 seconds...
# ALRM HIMS OLLI HFWA HRB SBH UPBD XLE CVBF LESL PYPL BANR SNV TWI WTW SBUX ADMA GBTC GDX NX WTFC RJF IIIN TER FBIN MGEE FSLR APD WRB SFBS OPCH AN BL HLT CL VCSH BHE ROAD HTLD PRDO WSR FANG OGE VZ ANET FMC NHC AKR SCL BLFS NXRT VTOL GLD CAL SLB XLV MTDR NAVI THRY CYTK SHO ADC DVAX CZR BSX VAL CG NOVT MRTN KRYS SCI UNH MAR NXPI CHEF AMGN LNW LAMR ICUI NSA EW CPB UBER BIO SITC MRCY MTCH NVR COHR CB NJR UNIT DOV FNB SJM CHRD CPT UAA MTB PPL
# Throttle limit reached. Waiting for 30 seconds...
# OSIS EQIX ACA VXUS AVNS MLM GSHD CTRE IRM LEA KAR IWM DE EXE BJ JKHY ESE TPH MU AXP SKY SEE CON KHC TDY XYL ROP IART HAIN AON SMCI MSFT SXI ARM ELS HIW PBH AMZN NFLX IWF DAR TIP NEOG ADNT CHD ADSK INSP ALEX CRSR ENS ST BXMT AGG CTSH BFS RUSHA GEF PALL ZION THG JBGS AGCO PSX GDOT ALLE ETR MRNA PCG JJSF QLYS LRCX LTC MHO XLI PGNY STRA CLH VIAV CBRE CVX FIZZ BOX CNXC ATR NTAP EXR FR EXPE DBB BWX DD GDYN REGN INCY CROX MCRI SNPS CNR CABO WLK
# Throttle limit reached. Waiting for 30 seconds...
# YOU PMT NVST TKO AMPH BA TOL MTUS CURB MCW ACGL ATO CALM CPK DXCM CNS KEY USNA EXPI TGI CF SEDG PPBI VLY HALO GPC X DUK PI PHIN A MPW PHM BBY SBAC CPER KLIC UPS BG SATS SF HRMY WSFS BYD XLC AXTA NEO MBC CDW ETD IRDM VICR JHG FIX SMPL WAB AAPL TRIP VMC SITM LLY OZK ITGR EMN AWI PEB ISRG FHB CACI PNFP V VRSN ASGN GHC ASH RUN CINF HOPE JBLU REX HWKN DOW REZI ENR NMIH DGX CE SWKS DLX KMX KFY WTRG TLT GLW XPEL HOMB CASH PAYO AMWD FOUR
# Throttle limit reached. Waiting for 30 seconds...
# FXF SRPT SBRA PWR GBCI TRV TR TRGP CC CADE MYRG COLB IBKR O WOLF LYV MSTR FCN SLG STT GAP TTC BANC VIR KEYS USFD ORCL MMC WWW CWT PRGS BURL JBHT SXT RTX IEX DRI ESS WSM EXEL KTB HELE GD XNCR CPF ATI GPN VOYA SPSM ACAD CTS AVB EXPD OTIS CERT DFS HNI VVV AIZ UNF ONTO IPGP DLB TNC PGR LITE LIVN PLMR IRT CFFN SYK ZWS WEN HZO OMI PLNT PRGO WDAY VAC XLF ASB GMS FBNC PZZA OSK OGN ULTA BNDX AEO DRH FNF JXN MANH MLI VIRT SOLV ECL PSN LEN DIA
# Throttle limit reached. Waiting for 30 seconds...
# VLO J HAS FCFS MLAB MTN FXA CSWI SLV BRC GFF SAIA ADEA ES CVS AZZ KEX ZBRA FELE MODG WMB ABCB HBAN JNPR NWL GDEN WBA DY HR DNOW RES ORLY INTU CASY XOM VRE FLEX FCPT ILMN BMI OI CANE PFGC VSTS JNJ TRUP ACIW DXC BALL GOOG CAR LKFN RHI APOG PNC CEG RAMP WD AMKR KLG TMO WHR ZI SHC INN ITW PRA JBT XLY BF-B CRK XHB EEM DBC HOG GKOS AMP JEF WOR GPI FBRT CRGY AVY DINO AMT CBRL LMT CMI EFX ALV FDS NVT FOXA RL LPX TDW GEHC SWK AVAV SANM
# Throttle limit reached. Waiting for 30 seconds...
# QNST GRBK SO ENVA DELL DASH KRC FHN VECO LIN MPC ALKS KMT AEIS EBAY EWBC DXPE CCI RH CNX PEG LGND MTSI SIGI XEL KLAC TBBK GBX NVDA NSIT HLNE CORT XOP LVS EXLS GPRE ARCB OXY RGLD NDSN RXO MMI ROST CNO CALX CMCSA HSIC HCA BKH BWZ ENSG ASTH IT CNC WDC MS UHS NGVT TRN PKG BERY BAC KWR POR COR FFIN NKE EFA CPRT AMSF VTLE SPSC CWEN HASI AIR FYBR ECG HPQ NLY LGIH FBP FE SAH OIH TROW LBRT AMTM CIEN PDCO MAS MTG VTRS FIS LOW STBA GT HES FCF INVA HAYW
# Throttle limit reached. Waiting for 30 seconds...
# ASML UNFI BEN KVUE SHW TDG DEA ALL WWD UFCS ALK BLK REG EGP COHU AYI TPR TGT WHD CNMD IRWD EVRG HII AROC BLMN WELL TTEK BILL DUOL SHV TFX AMBC GDDY JOE BSIG ADP TMUS OGS DV PRLB HGV RC CRVL TKR CENTA PDD BRX PSTG WABC PSMT DHR ODFL RLI ADI STWD SMTC YETI PLD DECK BHLB CGNX ITT GPK PPG TFC AWR USO ORA TTD EXP CME EHC CCEP THRM TNDM AUB JLL NXT SLVM KN ESAB BLD HSTM TT EGBN MGY ASIX HOLX OC KR UA EQR NBR SPYD TTMI ALG NOG CNM AMN IR
# Throttle limit reached. Waiting for 30 seconds...
# WKC WFRD APAM K ECPG MET RGR CFG BFH LSCC AORT MSA IP ELF IEI CRC SLAB LQD LYB IBND IBM KREF TRST CXT NOV ODP PRVA DFIN DOCN DAL AL CNXN H MTZ DT LNN AOS BJRI USPH JBL RVTY WAT SSB UE ZTS FIVE NCLH IIPR PDFS PPC CLX COO ZD HST QTUM DBX LNTH PG GNRC PIPR INSW DOCU LZB CSX LCII VFC AMAT TTWO RNR FXE POST AMR OLED OLN TEAM NVRI GWRE SCHL PAHC FXY TDS FL SUPN BDX FTDR WSO HSII CBU UMBF PTC SPTN WTS EPC BTU G EFC GOGO COTY BMY SYNA
# Throttle limit reached. Waiting for 30 seconds...
# TBRG PEY EME TREX NUE AOR STZ AWK CARS PRK MTX ONB EWZ SMG GFS VTR CARG LKQ BGC HUBG CCK ALGT KNX DOCS WT WEX EG BLKB CVI RNST WLY PFS AX FRT LULU CDNS WPC PBI KALU GS LHX HIG CMS MCHP UNP HLIT DKS ABR TNL CLF BKR BANF IBP SNDR IQV HTH F CEVA SNEX ARW PLAB EQT CPAY MRK TEX JWN PFBC CSL RF LFUS MAT GES AFL PRI JNK PEN WRLD PGX DCOM HWM CIVI RDN NFG RPM HP AMG CWEN-A ABG KIM MD EZPW MC SAIC LUMN AVT CCL MDT MATX XPO LNT
# Throttle limit reached. Waiting for 30 seconds...
# TGNA WING POWI FDX VCEL IEUR SKX KSS OMCL INGR
# Error fetching data for INGR: ('Connection broken: IncompleteRead(2595 bytes read, 844 more expected)', IncompleteRead(2595 bytes read, 844 more expected))
# SNX ADTN MGM KOP COST SPXC OXM DORM MYGN FDP SPG FLS DFH BXP CARR LOPE MORN VMI BRKR TRNO WYNN KBH FTRE CNK JAZZ ZBH IDA IPAR SCVL GL AOK ALTR MOH T WFC IDCC RS IWD WGO MAN NOW AOA SCSC BR EMR KMB WDFC TPX TRMB IFF AMCR AOSL GOOGL PM CATY MRVL STAG FLR NI AXL DOC ARLO MASI APH UFPI SAFE BTI DLTR SLGN STEL EIG CTVA CRS ARMK DCI SDY LECO NTRS URI EL ANSS PJT GXO ANF RRC ICHR PINC LW COP FLO
# Throttle limit reached. Waiting for 30 seconds...
# SAFT BAX SAM STLD SM CVLT ALGN GGG SYY WY PENN MA UBSI PH KW EMBC MAA UHT INDB ARWR AIG HPE RGEN FULT ALE AEE NOC FAST BCC FXB CENT UCTT BCPC JACK UL ABM CSGS MATV FWRD AJG IOSP AMD UTL ICE SWX MNRO UDR GILD SHOO CHE RCUS BUD PNR NYMT BK SONO ETHE SMP KDP SYF HAL EXC CAG HI FND FUL CMG SNA WNC SFM FLG GTLS PFF GO RWT MOS D PANW NXST EPR MMSI AEP COOP BCO APA VYX THO CBSH MMM LNC DEI CSCO STE ADBE CRWD M PPLT MKSI LXP PATK
# Throttle limit reached. Waiting for 30 seconds...
# VSH HUBB QQQ PCAR AHH DTE ZS MCD JPST HD TXNM BIIB NOBL MEDP INVH NWBI PLXS NVEE SEIC DIS AA WBS BRKL GLPI WST AFG BWA KRG GIII OVV CSGP MCY DTM EWJ VRRM GNTX DVA ENPH POOL FHI HCSG IPG PARA ROK SHY DDOG CRL VTI NRG JPM FFIV DIOD VOO TDC WERN DVN VBTX MDY RBC DPZ C LAD BHF SON ALGM ASO ARE WMS ABBV BND CUZ PCTY FXI CAH XLU LUV ERIE CR OKE UNG RMBS HLX CTKB EEFT SFNC PSA LQDT MTH COKE VNOM BRO AVTR RGA VRSK FORM PEP CHTR DAN MPWR AKAM
# Throttle limit reached. Waiting for 30 seconds...
# XLRE XLK RMD STX FUN ELV INTC NWSA SPNT ARI LAKE MAC FI MHK MSM MARA CNH CSR RYAN SDGR SKYW MSCI SWI COLL ARR OHI
#                             companyName  previousClose trailingPE  \
# symbol
# VC                  Visteon Corporation          86.74       4.59
# VRTS    Virtus Investment Partners, Inc         208.96      11.80
# VDE                 Vanguard Energy ETF         126.83      13.56
# UAL      United Airlines Holdings, Inc.         109.40      11.20
# CWK             Cushman & Wakefield plc          13.87      36.29
# ...                                 ...            ...        ...
# MSCI                          MSCI Inc.         590.73      42.57
# SWI              SolarWinds Corporation          14.98      67.64
# COLL     Collegium Pharmaceutical, Inc.          32.51      13.73
# ARR       ARMOUR Residential REIT, Inc.          18.78       6.49
# OHI     Omega Healthcare Investors, Inc          36.84      27.25
#
#         dividendYield  marketCap
# symbol
# VC               0.00    2321.64
# VRTS             4.26    1400.19
# VDE              0.00       0.00
# UAL              0.00   34808.23
# CWK              0.00    3164.63
# ...               ...        ...
# MSCI             1.02   46769.64
# SWI              0.00    2538.11
# COLL             0.00    1035.88
# ARR             15.30    1049.41
# OHI              7.23   10279.89
#
# [1626 rows x 5 columns]

# %%
df.to_csv('fundamentals.csv', encoding="utf-8")
