# %% [markdown]
# # Get Symbol Fundamentals
#
# Get fundamental data of any or all symbols in symbol_cache

# %%
import numpy as np
import pandas as pd
import yfinance as yf

import brownbear as bb

# Format price data.
pd.options.display.float_format = '{:0.2f}'.format

# Increase display of dataframe rows.
pd.set_option('display.max_rows', 1500)

# %%
# Keep - useful for looking at data returned from yahooquery.
ticker = yf.Ticker('MO')
info = ticker.info
print(info.get('shortName', None))  # Short name of the company
print(info.get('previousClose', np.nan))
print(info.get('trailingPE', np.nan))
print(info.get('dividendYield', 0) * 100)  # Convert to percentage
print(info.get('marketCap', 0) / 1_000_000)  # Convert to million
info
# Out:
# Altria Group, Inc.
# 55.08
# 8.539755
# 731.0
# 94423.359488
# {'address1': '6601 West Broad Street',
#  'city': 'Richmond',
#  'state': 'VA',
#  'zip': '23230',
#  'country': 'United States',
#  'phone': '804 274 2200',
#  'website': 'https://www.altria.com',
#  'industry': 'Tobacco',
#  'industryKey': 'tobacco',
#  'industryDisp': 'Tobacco',
#  'sector': 'Consumer Defensive',
#  'sectorKey': 'consumer-defensive',
#  'sectorDisp': 'Consumer Defensive',
#  'longBusinessSummary': 'Altria Group, Inc., through its subsidiaries, manufactures and sells smokeable and oral tobacco products in the United States. The company offers cigarettes primarily under the Marlboro brand; large cigars and pipe tobacco under the Black & Mild brand; moist smokeless tobacco and oral tobacco products under the Copenhagen, Skoal, Red Seal, and Husky brands; oral nicotine pouches under the on! brand; and e-vapor products under the NJOY ACE brand. It sells its products to distributors, as well as large retail organizations, such as chain stores. The company was founded in 1822 and is headquartered in Richmond, Virginia.',
#  'fullTimeEmployees': 6200,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. William F. Gifford Jr.',
#    'age': 54,
#    'title': 'CEO & Director',
#    'yearBorn': 1970,
#    'fiscalYear': 2015,
#    'totalPay': 8298071,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Salvatore  Mancuso',
#    'age': 59,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1965,
#    'fiscalYear': 2015,
#    'totalPay': 2853789,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jody L. Begley',
#    'age': 51,
#    'title': 'Executive VP & COO',
#    'yearBorn': 1973,
#    'fiscalYear': 2015,
#    'totalPay': 2865223,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Heather A. Newman',
#    'age': 46,
#    'title': 'Senior VP and Chief Strategy & Growth Officer',
#    'yearBorn': 1978,
#    'fiscalYear': 2015,
#    'totalPay': 2181408,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Charles N. Whitaker J.D.',
#    'age': 57,
#    'title': 'Senior VP, Chief Human Resources Officer & Chief Compliance Officer',
#    'yearBorn': 1967,
#    'fiscalYear': 2015,
#    'totalPay': 1042492,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Mac  Livingston',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Robert A. McCarter III, J.D.',
#    'age': 51,
#    'title': 'Executive VP & General Counsel',
#    'yearBorn': 1973,
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Jennifer  Hunter',
#    'title': 'Senior VP of Corporate Citizenship & Chief Sustainability Officer - Altria Client Services LLC',
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Shannon  Leistra',
#    'title': 'President & CEO of NJOY, LLC',
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Paige  Magness',
#    'title': 'Senior Vice President of Regulatory Affairs - Altria Client Services LLC',
#    'fiscalYear': 2015,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 6,
#  'boardRisk': 1,
#  'compensationRisk': 1,
#  'shareHolderRightsRisk': 6,
#  'overallRisk': 2,
#  'governanceEpochDate': 1740787200,
#  'compensationAsOfEpochDate': 1451520000,
#  'irWebsite': 'http://investor.altria.com/phoenix.zhtml?c=80855&p=irol-irhome&src=top_nav',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 55.08,
#  'open': 55.55,
#  'dayLow': 55.27,
#  'dayHigh': 56.09,
#  'regularMarketPreviousClose': 55.08,
#  'regularMarketOpen': 55.55,
#  'regularMarketDayLow': 55.27,
#  'regularMarketDayHigh': 56.09,
#  'dividendRate': 4.08,
#  'dividendYield': 7.31,
#  'exDividendDate': 1742860800,
#  'payoutRatio': 0.6116,
#  'fiveYearAvgDividendYield': 8.02,
#  'beta': 0.677,
#  'trailingPE': 8.539755,
#  'forwardPE': 10.439252,
#  'volume': 5674745,
#  'regularMarketVolume': 5674745,
#  'averageVolume': 7857608,
#  'averageVolume10days': 8259750,
#  'averageDailyVolume10Day': 8259750,
#  'bid': 55.68,
#  'ask': 55.79,
#  'bidSize': 8,
#  'askSize': 10,
#  'marketCap': 94423359488,
#  'fiftyTwoWeekLow': 39.25,
#  'fiftyTwoWeekHigh': 58.04,
#  'priceToSalesTrailing12Months': 4.618634,
#  'fiftyDayAverage': 52.899,
#  'twoHundredDayAverage': 51.08645,
#  'trailingAnnualDividendRate': 4.0,
#  'trailingAnnualDividendYield': 0.072621636,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 116272455680,
#  'profitMargins': 0.55097,
#  'floatShares': 1687669170,
#  'sharesOutstanding': 1690659968,
#  'sharesShort': 34075104,
#  'sharesShortPriorMonth': 30611931,
#  'sharesShortPreviousMonthDate': 1736899200,
#  'dateShortInterest': 1739491200,
#  'sharesPercentSharesOut': 0.0202,
#  'heldPercentInsiders': 0.0026800002,
#  'heldPercentInstitutions': 0.61164004,
#  'shortRatio': 4.58,
#  'shortPercentOfFloat': 0.0202,
#  'impliedSharesOutstanding': 1690659968,
#  'bookValue': -1.324,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1735603200,
#  'earningsQuarterlyGrowth': 0.475,
#  'netIncomeToCommon': 11235999744,
#  'trailingEps': 6.54,
#  'forwardEps': 5.35,
#  'lastSplitFactor': '3:1',
#  'lastSplitDate': 860716800,
#  'enterpriseToRevenue': 5.687,
#  'enterpriseToEbitda': 9.387,
#  '52WeekChange': 0.4057387,
#  'SandP52WeekChange': 0.16050637,
#  'lastDividendValue': 1.02,
#  'lastDividendDate': 1735171200,
#  'quoteType': 'EQUITY',
#  'currentPrice': 55.85,
#  'targetHighPrice': 73.0,
#  'targetLowPrice': 42.0,
#  'targetMeanPrice': 56.20308,
#  'targetMedianPrice': 57.64,
#  'recommendationMean': 2.57143,
#  'recommendationKey': 'hold',
#  'numberOfAnalystOpinions': 13,
#  'totalCash': 3127000064,
#  'totalCashPerShare': 1.85,
#  'ebitda': 12387000320,
#  'totalDebt': 24925999104,
#  'quickRatio': 0.387,
#  'currentRatio': 0.514,
#  'totalRevenue': 20444000256,
#  'revenuePerShare': 11.9,
#  'returnOnAssets': 0.20511,
#  'grossProfits': 14337999872,
#  'freeCashflow': 4630249984,
#  'operatingCashflow': 8753000448,
#  'earningsGrowth': 0.539,
#  'revenueGrowth': 0.016,
#  'grossMargins': 0.70133,
#  'ebitdaMargins': 0.6059,
#  'operatingMargins': 0.60987,
#  'financialCurrency': 'USD',
#  'symbol': 'MO',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'shortName': 'Altria Group, Inc.',
#  'longName': 'Altria Group, Inc.',
#  'postMarketTime': 1740790770,
#  'regularMarketTime': 1740776402,
#  'exchange': 'NYQ',
#  'messageBoardId': 'finmb_53839346',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'marketState': 'CLOSED',
#  'regularMarketChangePercent': 1.39796,
#  'regularMarketPrice': 55.85,
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': -252322200000,
#  'postMarketChangePercent': -0.0179021,
#  'postMarketPrice': 55.84,
#  'postMarketChange': -0.00999832,
#  'regularMarketChange': 0.769997,
#  'regularMarketDayRange': '55.27 - 56.09',
#  'fullExchangeName': 'NYSE',
#  'averageDailyVolume3Month': 7857608,
#  'fiftyTwoWeekLowChange': 16.599998,
#  'fiftyTwoWeekLowChangePercent': 0.42292988,
#  'fiftyTwoWeekRange': '39.25 - 58.04',
#  'fiftyTwoWeekHighChange': -2.1900024,
#  'fiftyTwoWeekHighChangePercent': -0.03773264,
#  'fiftyTwoWeekChangePercent': 40.57387,
#  'dividendDate': 1736467200,
#  'earningsTimestamp': 1745929800,
#  'earningsTimestampStart': 1745929800,
#  'earningsTimestampEnd': 1745929800,
#  'earningsCallTimestampStart': 1745931600,
#  'earningsCallTimestampEnd': 1745931600,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 6.54,
#  'epsForward': 5.35,
#  'epsCurrentYear': 5.3387,
#  'priceEpsCurrentYear': 10.461349,
#  'fiftyDayAverageChange': 2.9510002,
#  'fiftyDayAverageChangePercent': 0.05578556,
#  'twoHundredDayAverageChange': 4.76355,
#  'twoHundredDayAverageChangePercent': 0.09324488,
#  'priceToBook': -42.182777,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '2.6 - Hold',
#  'cryptoTradeable': False,
#  'corporateActions': [{'header': 'Dividend',
#    'message': 'MO announced a cash dividend of 1.02 with an ex-date of Mar. 25, 2025',
#    'meta': {'eventType': 'DIVIDEND',
#     'dateEpochMs': 1742878800000,
#     'amount': '1.02'}}],
#  'displayName': 'Altria',
#  'trailingPegRatio': 3.9863}

# %% [markdown]
# Get fundamental data for the symbols below

# %%
# Important: set reset_cache=True at first, then set to False
df = bb.get_symbol_fundamentals(throttle_limit=100, wait_time=30, reset_cache=False)
df
# Out:
# Fetching fundamental data for 6 symbols...
# VVI
# Error fetching data for VVI: list index out of range
# ROIC
# Error fetching data for ROIC: list index out of range
# NARI
# Error fetching data for NARI: list index out of range
# JBT
# Error fetching data for JBT: list index out of range
# BSIG
# Error fetching data for BSIG: list index out of range
# TPX
# Error fetching data for TPX: list index out of range
#                             companyName  previousClose trailingPE  \
# symbol
# VC                  Visteon Corporation          86.57       8.83
# VRTS    Virtus Investment Partners, Inc         183.27      11.11
# VDE                 Vanguard Energy ETF         124.66      13.98
# UAL      United Airlines Holdings, Inc.          92.17       9.93
# CWK             Cushman & Wakefield plc          11.90      21.23
# ...                                 ...            ...        ...
# ALGN             Align Technology, Inc.         185.77      33.34
# GGG                          Graco Inc.          86.06      30.88
# SYY                   Sysco Corporation          74.72      19.37
# WY                 Weyerhaeuser Company          30.06      55.74
# PENN           PENN Entertainment, Inc.          20.39          0
#
#         dividendYield  marketCap
# symbol
# VC               0.00    2348.42
# VRTS           479.00    1317.86
# VDE            317.00    5285.77
# UAL              0.00   30707.77
# CWK              0.00    2731.45
# ...               ...        ...
# ALGN             0.00   13764.96
# GGG            126.00   14757.84
# SYY            270.00   36956.43
# WY             279.00   21839.90
# PENN             0.00    3289.89
#
# [1624 rows x 5 columns]

# %%
df.to_csv('fundamentals.csv', encoding="utf-8")
