# %% [markdown]
# <img src="../../images/brownbear.png" width="400">
#
# ## A financial tool that can analyze and maximize investment portfolios on a risk adjusted basis
#
#
# Description: This notebook is useful for examining potfolios comprised of stocks from the Nasdaq 100.  Construct portfolios from the 100 stocks in the Nasdaq 100 and examine the results of different weighting schemes.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import brownbear as bb

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# display all rows
pd.set_option('display.max_rows', None)

# do not truncate column names
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# ### Some Globals

# %%
investment_universe = ['nasdaq100-galaxy']
risk_free_rate = 0
annual_returns = '3 Yr'
vola = 'Vola'
ds_vola = 'DS Vola'

# %%
# Fetch Investment Options - all values annualized
df = bb.fetch(investment_universe, risk_free_rate, annual_returns, vola, ds_vola)
df
# Out:
#     Investment Option                  Description Asset Class      1 mo  \
# 0                ATVI          Activision Blizzard   US Stocks    -22.31
# 1                ADBE                   Adobe Inc.   US Stocks    253.91
# 2                 ADP                          ADP   US Stocks    -50.18
# 3                ABNB                       Airbnb   US Stocks   3189.65
# 4                ALGN             Align Technology   US Stocks  16022.62
# 5               GOOGL      Alphabet Inc. (Class A)   US Stocks    703.18
# 6                GOOG      Alphabet Inc. (Class C)   US Stocks    675.37
# 7                AMZN                       Amazon   US Stocks    928.34
# 8                 AMD  Advanced Micro Devices Inc.   US Stocks   3003.16
# 9                 AEP      American Electric Power   US Stocks    -35.35
# 10               AMGN                        Amgen   US Stocks    -59.57
# 11                ADI               Analog Devices   US Stocks    145.77
# 12               ANSS                        Ansys   US Stocks    347.06
# 13               AAPL                   Apple Inc.   US Stocks   1016.42
# 14               AMAT            Applied Materials   US Stocks    866.92
# 15               ASML                 ASML Holding   US Stocks    711.17
# 16                AZN                  AstraZeneca   US Stocks    -66.54
# 17               TEAM                    Atlassian   US Stocks   3233.64
# 18               ADSK                     Autodesk   US Stocks    705.89
# 19                BKR                 Baker Hughes   US Stocks    340.99
# 20               BIIB                       Biogen   US Stocks     74.20
# 21               BKNG             Booking Holdings   US Stocks    514.17
# 22               AVGO                Broadcom Inc.   US Stocks    117.08
# 23               CDNS       Cadence Design Systems   US Stocks    539.22
# 24               CHTR       Charter Communications   US Stocks    422.54
# 25               CTAS                       Cintas   US Stocks     -3.75
# 26               CSCO                        Cisco   US Stocks     30.93
# 27               CTSH                    Cognizant   US Stocks    592.49
# 28              CMCSA                      Comcast   US Stocks    188.71
# 29                CEG         Constellation Energy   US Stocks     -2.98
# 30               CPRT                       Copart   US Stocks    240.34
# 31               CSGP                 CoStar Group   US Stocks    -19.79
# 19           0.33
# 20           0.00
# 21           0.25
# 22           0.99
# 23           1.10
# 24        -309.82
# 25           0.47
# 26           0.14
# 27           0.12
# 28         -32.13
# 29           1.61
# 30           0.31
# 31           0.14
# 32           0.86
# 33           0.42
# 34           0.30
# 35           0.34
# 36           0.43
# 37           0.39
# 38           0.56
# 39           0.31
# 40           0.10
# 41           1.10
# 42           0.43
# 43           0.62
# 44        -132.86
# 45           0.80
# 46           0.47
# 47           0.37
# 48           0.25
# 49           0.55
# 50        -387.37
# 51        -615.70
# 52           0.45
# 53           0.26
# 54           0.28
# 55           0.45
# 56           0.98
# 57           0.62
# 58           0.45
# 59       -6990.25
# 60           0.22
# 61           0.13
# 62           0.53
# 63           0.33
# 64        -180.33
# 65           0.48
# 66           0.11
# 67           0.59
# 68           0.98
# 69           0.37
# 70           0.56
# 71         -12.82
# 72           0.96
# 73           0.38
# 74           0.86
# 75           1.31
# 76           0.75
# 77           0.69
# 78           0.50
# 79        -503.22
# 80           0.50
# 81           0.51
# 82           0.45
# 83           1.15
# 84       -4776.88
# 85           0.02
# 86           0.21
# 87        -208.61
# 88           0.26
# 89           1.00
# 90           0.85
# 91           0.58
# 92           0.64
# 93           0.10
# 94           0.30
# 95        -218.04
# 96       -1218.33
# 97         -61.49
# 98           0.11
# 99        -157.37
# 100          0.65

# %%
# rank
rank = bb.rank(df, rank_by='Sharpe Ratio', group_by=None, num_per_group=50)
rank_filtered = rank
rank_filtered = rank.loc[(rank['3 mo'] > 0) & rank['1 Yr'] > 0]
rank_filtered = rank_filtered.head(20)
rank_filtered
# Out:
#    Investment Option                Description Asset Class    1 mo   3 mo  \
# 75              ODFL  Old Dominion Freight Line   US Stocks 1921.35 313.85
# 83              REGN                  Regeneron   US Stocks  146.18  25.11
# 23              CDNS     Cadence Design Systems   US Stocks  539.22 169.22
# 89              SNPS                   Synopsys   US Stocks  316.40 173.30
# 22              AVGO              Broadcom Inc.   US Stocks  117.08 204.90
# 68              MRNA                    Moderna   US Stocks  -24.52  84.66
# 56              KLAC            KLA Corporation   US Stocks  134.86 195.65
# 72              NVDA                     Nvidia   US Stocks 7249.17 549.80
# 32              COST                     Costco   US Stocks  331.27  29.41
# 15              ASML               ASML Holding   US Stocks  711.17 444.08
# 13              AAPL                 Apple Inc.   US Stocks 1016.42  29.65
# 76              PCAR                     Paccar   US Stocks  297.53  99.08
# 92               TXN          Texas Instruments   US Stocks  166.86  80.04
# 11               ADI             Analog Devices   US Stocks  145.77 161.55
# 57               KHC                Kraft Heinz   US Stocks  -42.52  18.69
# 43              FAST                   Fastenal   US Stocks  370.50  67.01
# 67              MSFT                  Microsoft   US Stocks  322.86  91.97
# 14              AMAT          Applied Materials   US Stocks  866.92 252.76
# 70              MNST           Monster Beverage   US Stocks   -4.03  51.82
# 16               AZN                AstraZeneca   US Stocks  -66.54  27.51
#
#      1 Yr   3 Yr   5 Yr  Vola  DS Vola  Std Dev  Annual Returns  Sharpe Ratio
# 75  14.92  40.15  30.95 47.37    13.09    30.57           40.15          1.31
# 83  25.73  30.06  17.76 36.72    26.52    26.07           30.06          1.15
# 23  21.37  35.67  34.50 28.08     9.93    32.33           35.67          1.10
# 89  14.51  32.38  31.65 24.88    10.10    32.51           32.38          1.00
# 22   2.22  28.69  24.77 29.51    11.15    28.85           28.69          0.99
# 68   2.15 102.48 102.48 36.47    20.73   104.49          102.48          0.98
# 56   4.58  33.56  32.18 44.64    26.45    34.35           33.56          0.98
# 72 -16.33  50.77  28.80 55.40    24.76    52.87           50.77          0.96
# 32  -0.55  21.09  23.35 30.78     9.99    24.62           21.09          0.86
# 15   0.23  32.65  28.87 38.30    17.08    39.39           32.65          0.83
# 13 -11.63  25.54  31.11 21.61     7.16    32.56           25.54          0.78
# 76  19.64  16.87  12.43 36.67    10.95    22.63           16.87          0.75
# 92  -0.16  16.01  13.64 27.33     9.76    24.93           16.01          0.64
# 11   7.87  18.91  16.52 22.58     7.82    30.01           18.91          0.63
# 57  12.81  15.68  -8.75 27.61    22.04    25.28           15.68          0.62
# 43  -2.91  16.66  17.86 34.46    10.65    26.97           16.66          0.62
# 67 -16.81  13.84  23.82 30.21    12.85    23.42           13.84          0.59
# 14 -13.97  25.18  19.14 47.57    20.77    43.73           25.18          0.58
# 70  16.73  13.91   8.43 20.19     9.19    24.83           13.91          0.56
# 16  10.06  12.07  16.00 18.52    13.52    21.68           12.07          0.56

# %% [markdown]
# ### Sample Portfolios
# Format 'Investment option': weight

# %%
# everything ranked
ranked_portfolio = {
    'Title': 'Ranked Portfolio'
}
everything = list(rank_filtered['Investment Option'])
ranked_portfolio.update(dict.fromkeys(everything, 1/len(everything)))

# top 10
top10_portfolio = {
    'Title': 'Ranked Portfolio'
}
top10 = list(rank_filtered['Investment Option'])[:10]
top10_portfolio.update(dict.fromkeys(top10, 1/len(top10)))

# %% [markdown]
# ### Custom Portfolios

# %%
# My portfolio
my_portfolio = {
    'Title': 'My Portfolio',

}

# %% [markdown]
# ### Choose Portfolio Option

# %%
# Select one of the portfolios from above
portfolio_option = top10_portfolio

# %%
# Make a copy so that the original portfolio is preserved
portfolio_option = portfolio_option.copy()

# %% [markdown]
# ### Analysis Options

# %%
# Specify the weighting scheme.  It will replace the weights specified in the portfolio
# You can also fix the weights on some Investent Options, Asset Classes, and Asset Subclasses
# while the others are automatically calculated.

# 'Equal' - will use equal weights.

# 'Sharpe Ratio' - will use proportionally weighted # allocations based on the percent
#  of an investment option's sharpe ratio to the sum of all the sharpe ratios in the portfolio.

# 'Std Dev' - will use standard deviation adjusted weights

# 'Annual Returns' - will use return adjusted weights

# 'Vola' - will use volatility adjusted weights

# 'DS Vola' - will use downside volatility adjusted weights

# None: 'Investment Option' means use user specified weights
#       'Asset Class' means do not group by Asset Class
#       'Asset Subclass means do not group by Asset Subclass 

weight_by = {
    'Asset Class':       {'weight_by': None},
    'Asset Subclass':    {'weight_by': None},
    'Investment Option': {'weight_by': 'DS Vola'},
}
#weight_by = None

# %%
bb.DEBUG = False

# Analyze portfolio
annual_ret, std_dev, sharpe_ratio = \
    bb.analyze(df, portfolio_option, weight_by)

# %%
# Display Results
summary = bb.summary(df, portfolio_option, annual_ret, std_dev, sharpe_ratio)
summary
# Out:
#                           ODFL   REGN   CDNS   SNPS   AVGO    MRNA   KLAC  \
# Annual Returns           40.15  30.06  35.67  32.38  28.69  102.48  33.56
# Std Dev                  30.57  26.07  32.33  32.51  28.85  104.49  34.35
# Sharpe Ratio              1.31   1.15   1.10   1.00   0.99    0.98   0.98
# Weight                    0.11   0.05   0.15   0.14   0.13    0.07   0.05
# Worst Typical Down Year -20.99 -22.08 -28.99 -32.64 -29.01 -106.50 -35.14
# Black Swan              -51.56 -48.15 -61.32 -65.15 -57.86 -210.99 -69.49
#
#                            NVDA   COST   ASML  Ranked Portfolio
# Annual Returns            50.77  21.09  32.65             37.55
# Std Dev                   52.87  24.62  39.39             34.66
# Sharpe Ratio               0.96   0.86   0.83              1.08
# Weight                     0.06   0.15   0.09              1.00
# Worst Typical Down Year  -54.97 -28.15 -46.13            -31.78
# Black Swan              -107.84 -52.77 -85.52            -66.44

# %%
# Show pie charts of investment and asset class weights
bb.show_pie_charts(df, portfolio_option, charts=['Investment Option'])
# Out:
# ASML   0.09
# AVGO   0.13
# CDNS   0.15
# COST   0.15
# KLAC   0.05
# MRNA   0.07
# NVDA   0.06
# ODFL   0.11
# REGN   0.05
# SNPS   0.14

# %%
# Show exact weights
bb.print_portfolio(portfolio_option)
# Out:
# Ranked Portfolio Weights:
#     ODFL                           0.1109
#     REGN                           0.0548
#     CDNS                           0.1462
#     SNPS                           0.1438
#     AVGO                           0.1302
#     MRNA                           0.0701
#     KLAC                           0.0549
#     NVDA                           0.0587
#     COST                           0.1454
#     ASML                           0.0850

# %% [markdown]
# ### Optimize Portfolio

# %%
# Run_portfolio_optimizer = True will run portfolio optimizer after portfolio analysis is complete
run_portfolio_optimizer = True

# %%
# Optimize sharpe ratio while specifying Annual Rate, Worst Typical Down Year,
# and Black Swan.  Setting a constraint to None optimizes absolute Sharpe Ratio
# without regard to that constraint.

'''
constraints = {
    'Annual Return': 12,
    'Worst Typical Down Year': -5,
    'Black Swan': None
}
'''

constraints = {
    'Annual Return': 8,
    'Worst Typical Down Year': None,
    'Black Swan': -40
}

if run_portfolio_optimizer:
    bb.optimizer(df, portfolio_option, constraints)
# Out:
# Running optimizer
#
# Impossible criteria specified, lower your expectations!!!

# %% [markdown]
# ### Use Sharpe Ratio adjusted weights
# Recommend that you also try using Sharpe Ratio adjusted weights and compare those results with the Optimized Portflio.
# It tends to produce a higher Annual Return while keeping the allocations more balanced than the Optimizer.  (See 'Analysis Options' section).
