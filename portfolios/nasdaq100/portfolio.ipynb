# %% [markdown]
# <img src="../../images/brownbear.png" width="400">
#
# ## A financial tool that can analyze and maximize investment portfolios on a risk adjusted basis
#
#
# Description: This notebook is useful for examining potfolios comprised of stocks from the Nasdaq 100.  Construct portfolios from the 100 stocks in the Nasdaq 100 and examine the results of different weighting schemes.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import brownbear as bb

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# display all rows
pd.set_option('display.max_rows', None)

# do not truncate column names
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# ### Some Globals

# %%
investment_universe = ['nasdaq100-galaxy']
risk_free_rate = 0
annual_returns = '3 Yr'
vola = 'Vola'
ds_vola = 'DS Vola'

# %%
# Fetch Investment Options - all values annualized
df = bb.fetch(investment_universe, risk_free_rate, annual_returns, vola, ds_vola)
df
# Out:
#     Investment Option                                 Description Asset Class  \
# 0                ATVI                         Activision Blizzard   US Stocks
# 1                ADBE                                  Adobe Inc.   US Stocks
# 2                 AMD                      Advanced Micro Devices   US Stocks
# 3                ALXN                     Alexion Pharmaceuticals   US Stocks
# 4                ALGN                            Align Technology   US Stocks
# 5               GOOGL                     Alphabet Inc. (Class A)   US Stocks
# 6                GOOG                     Alphabet Inc. (Class C)   US Stocks
# 7                AMZN                                  Amazon.com   US Stocks
# 8                 AEP                     American Electric Power   US Stocks
# 9                AMGN                                       Amgen   US Stocks
# 10                ADI                              Analog Devices   US Stocks
# 11               ANSS                                       Ansys   US Stocks
# 12               AAPL                                  Apple Inc.   US Stocks
# 13               AMAT                     Applied Materials, Inc.   US Stocks
# 14               ASML                                ASML Holding   US Stocks
# 15               TEAM                                   Atlassian   US Stocks
# 16               ADSK                                    Autodesk   US Stocks
# 17                ADP             Automatic Data Processing, Inc.   US Stocks
# 18               BIDU                                       Baidu   US Stocks
# 19               BIIB                                      Biogen   US Stocks
# 20               BKNG                            Booking Holdings   US Stocks
# 21               AVGO                               Broadcom Inc.   US Stocks
# 22               CDNS                      Cadence Design Systems   US Stocks
# 23                CDW                                         CDW   US Stocks
# 24               CERN                          Cerner Corporation   US Stocks
# 25               CHTR                Charter Communications, Inc.   US Stocks
# 26               CHKP      Check Point Software Technologies Ltd.   US Stocks
# 27               CTAS                          Cintas Corporation   US Stocks
# 28               CSCO                               Cisco Systems   US Stocks
# 29               CTSH  Cognizant Technology Solutions Corporation   US Stocks
# 30              CMCSA                         Comcast Corporation   US Stocks
# 31               CPRT                                      Copart   US Stocks
# 32               COST                Costco Wholesale Corporation   US Stocks
# 33                CSX                             CSX Corporation   US Stocks
# 34               DXCM                                      DexCom   US Stocks
# 35               DOCU                                    DocuSign   US Stocks
# 36               DLTR                           Dollar Tree, Inc.   US Stocks
# 51            20.27          0.75
# 52            25.50          0.73
# 53            26.73          1.08
# 54            42.66          1.29
# 55            -4.41       -162.86
# 56            50.34          1.32
# 57            38.15          1.00
# 58             1.65          0.04
# 59            31.39          0.94
# 60            46.80          1.18
# 61            21.94          0.82
# 62            62.72          1.31
# 63            17.03          0.43
# 64            12.33          0.31
# 65            36.84          2.02
# 66           240.11          2.25
# 67            19.80          1.06
# 68            22.57          0.78
# 69            37.45          1.19
# 70            10.99          0.37
# 71            38.81          0.94
# 72            23.58          0.62
# 73            23.77          0.86
# 74            54.94          1.21
# 75            19.34          0.83
# 76            19.00          0.87
# 77            45.97          1.55
# 78           115.14          1.75
# 79            17.32          1.04
# 80            99.44          1.38
# 81            35.85          0.83
# 82            17.93          0.52
# 83            13.72          0.49
# 84            34.09          0.82
# 85            -2.23        -57.13
# 86            21.33          0.61
# 87            -0.99        -44.21
# 88            27.71          1.11
# 89            41.83          1.66
# 90            36.26          1.67
# 91           116.12          1.47
# 92            21.26          0.88
# 93            -5.44       -218.42
# 94            17.58          0.77
# 95            17.50          0.75
# 96            11.94          0.42
# 97            -1.30        -40.99
# 98            20.34          0.52
# 99            20.00          1.15
# 100           23.86          0.71
# 101           59.73          0.92

# %%
# rank
rank = bb.rank(df, rank_by='Sharpe Ratio', group_by=None, num_per_group=50)
rank_filtered = rank
rank_filtered = rank.loc[(rank['3 mo'] > 0) & rank['1 Yr'] > 0]
rank_filtered = rank_filtered.head(20)
rank_filtered
# Out:
#    Investment Option                   Description Asset Class    1 mo   3 mo  \
# 66              MRNA                       Moderna   US Stocks 1586.73 490.56
# 65              MSFT         Microsoft Corporation   US Stocks   26.64  38.77
# 14              ASML                  ASML Holding   US Stocks  111.78 185.85
# 90              TMUS                   T-Mobile US   US Stocks  144.60  80.47
# 89              SNPS                Synopsys, Inc.   US Stocks  145.10  59.20
# 25              CHTR  Charter Communications, Inc.   US Stocks   17.06  43.21
# 22              CDNS        Cadence Design Systems   US Stocks   -1.32   0.19
# 32              COST  Costco Wholesale Corporation   US Stocks   60.70 124.34
# 77              PYPL                        PayPal   US Stocks  108.67  46.60
# 91              TSLA                   Tesla, Inc.   US Stocks  -74.33   0.74
# 35              DOCU                      DocuSign   US Stocks  683.58  69.85
# 2                AMD        Advanced Micro Devices   US Stocks   75.89  16.52
# 46              IDXX            Idexx Laboratories   US Stocks   87.26  55.89
# 56              LRCX                  Lam Research   US Stocks  131.67 106.93
# 50              INTU                        Intuit   US Stocks  616.06 114.58
# 54              KLAC               KLA Corporation   US Stocks   25.85  33.37
# 6               GOOG       Alphabet Inc. (Class C)   US Stocks   60.69  82.80
# 69              NTES                 NetEase, Inc.   US Stocks  113.81  26.42
# 34              DXCM                        DexCom   US Stocks   72.28  22.34
# 12              AAPL                    Apple Inc.   US Stocks  -17.18  16.35
#
#      1 Yr   3 Yr   5 Yr  Vola  DS Vola  Std Dev  Annual Returns  Sharpe Ratio
# 66 240.11 240.11 240.11 47.48    18.38   106.57          240.11          2.25
# 65  38.43  36.84  38.99 21.79    12.31    18.27           36.84          2.02
# 14  94.83  51.03  48.20 38.00    22.19    26.18           51.03          1.95
# 90  44.26  36.26  27.32 23.48    14.84    21.70           36.26          1.67
# 89  40.25  41.83  37.32 30.88    16.13    25.17           41.83          1.66
# 25  26.41  36.57  24.54 24.28    12.35    22.90           36.57          1.60
# 22  38.87  42.92  38.66 27.41    17.25    26.94           42.92          1.59
# 32  29.02  27.19  23.49 16.08    10.00    17.48           27.19          1.56
# 77  70.14  45.97  46.82 27.93    17.60    29.74           45.97          1.55
# 91 246.52 116.12  68.74 50.06    30.90    79.21          116.12          1.47
# 35  66.53  63.21  63.21 76.21    22.06    43.85           63.21          1.44
# 2   55.01  76.45  80.65 27.23    17.28    54.88           76.45          1.39
# 46  80.07  36.65  44.41 24.56    15.86    27.05           36.65          1.35
# 56 127.44  50.34  53.53 47.84    30.85    38.04           50.34          1.32
# 50  64.34  31.66  34.89 23.42    10.73    24.17           31.66          1.31
# 54  72.55  42.66  37.12 40.78    26.52    33.11           42.66          1.29
# 6   73.62  29.11  27.40 23.39    13.48    24.03           29.11          1.21
# 69  46.11  37.45  29.40 43.02    20.37    31.40           37.45          1.19
# 34  11.04  60.01  41.44 36.79    22.43    50.82           60.01          1.18
# 12  57.28  39.50  40.71 22.00    12.70    33.48           39.50          1.18

# %% [markdown]
# ### Sample Portfolios
# Format 'Investment option': weight

# %%
# everything ranked
ranked_portfolio = {
    'Title': 'Ranked Portfolio'
}
everything = list(rank_filtered['Investment Option'])
ranked_portfolio.update(dict.fromkeys(everything, 1/len(everything)))

# top 10
top10_portfolio = {
    'Title': 'Ranked Portfolio'
}
top10 = list(rank_filtered['Investment Option'])[:10]
top10_portfolio.update(dict.fromkeys(top10, 1/len(top10)))

# %% [markdown]
# ### Custom Portfolios

# %%
# My portfolio
my_portfolio = {
    'Title': 'My Portfolio',

}

# %% [markdown]
# ### Choose Portfolio Option

# %%
# Select one of the portfolios from above
portfolio_option = top10_portfolio

# %%
# Make a copy so that the original portfolio is preserved
portfolio_option = portfolio_option.copy()

# %% [markdown]
# ### Analysis Options

# %%
# Specify the weighting scheme.  It will replace the weights specified in the portfolio
# You can also fix the weights on some Investent Options, Asset Classes, and Asset Subclasses
# while the others are automatically calculated.

# 'Equal' - will use equal weights.

# 'Sharpe Ratio' - will use proportionally weighted # allocations based on the percent
#  of an investment option's sharpe ratio to the sum of all the sharpe ratios in the portfolio.

# 'Std Dev' - will use standard deviation adjusted weights

# 'Annual Returns' - will use return adjusted weights

# 'Vola' - will use volatility adjusted weights

# 'DS Vola' - will use downside volatility adjusted weights

# None: 'Investment Option' means use user specified weights
#       'Asset Class' means do not group by Asset Class
#       'Asset Subclass means do not group by Asset Subclass 

weight_by = {
    'Asset Class':       {'weight_by': None},
    'Asset Subclass':    {'weight_by': None},
    'Investment Option': {'weight_by': 'DS Vola'},
}
#weight_by = None

# %%
bb.DEBUG = False

# Analyze portfolio
annual_ret, std_dev, sharpe_ratio = \
    bb.analyze(df, portfolio_option, weight_by)

# %%
# Display Results
summary = bb.summary(df, portfolio_option, annual_ret, std_dev, sharpe_ratio)
summary
# Out:
#                           MRNA   MSFT   ASML   TMUS   SNPS   CHTR   CDNS  \
# Annual Returns          240.11  36.84  51.03  36.26  41.83  36.57  42.92
# Std Dev                 106.57  18.27  26.18  21.70  25.17  22.90  26.94
# Sharpe Ratio              2.25   2.02   1.95   1.67   1.66   1.60   1.59
# Weight                    0.09   0.13   0.07   0.11   0.10   0.13   0.09
# Worst Typical Down Year  26.97   0.30  -1.33  -7.14  -8.51  -9.23 -10.96
# Black Swan              -79.60 -17.97 -27.51 -28.84 -33.68 -32.13 -37.90
#
#                           COST   PYPL    TSLA  Ranked Portfolio
# Annual Returns           27.19  45.97  116.12             59.43
# Std Dev                  17.48  29.74   79.21             30.56
# Sharpe Ratio              1.56   1.55    1.47              1.94
# Weight                    0.16   0.09    0.05              1.00
# Worst Typical Down Year  -7.77 -13.51  -42.30             -1.69
# Black Swan              -25.25 -43.25 -121.51            -32.25

# %%
# Show pie charts of investment and asset class weights
bb.show_pie_charts(df, portfolio_option, charts=['Investment Option'])
# Out:
# ASML   0.07
# CDNS   0.09
# CHTR   0.13
# COST   0.16
# MSFT   0.13
# MRNA   0.09
# PYPL   0.09
# SNPS   0.10
# TMUS   0.11
# TSLA   0.05

# %%
# Show exact weights
bb.print_portfolio(portfolio_option)
# Out:
# Ranked Portfolio Weights:
#     MRNA                           0.0852
#     MSFT                           0.1273
#     ASML                           0.0706
#     TMUS                           0.1056
#     SNPS                           0.0971
#     CHTR                           0.1269
#     CDNS                           0.0908
#     COST                           0.1567
#     PYPL                           0.0890
#     TSLA                           0.0507

# %% [markdown]
# ### Optimize Portfolio

# %%
# Run_portfolio_optimizer = True will run portfolio optimizer after portfolio analysis is complete
run_portfolio_optimizer = True

# %%
# Optimize sharpe ratio while specifying Annual Rate, Worst Typical Down Year,
# and Black Swan.  Setting a constraint to None optimizes absolute Sharpe Ratio
# without regard to that constraint.

'''
constraints = {
    'Annual Return': 12,
    'Worst Typical Down Year': -5,
    'Black Swan': None
}
'''

constraints = {
    'Annual Return': 8,
    'Worst Typical Down Year': None,
    'Black Swan': -40
}

if run_portfolio_optimizer:
    bb.optimizer(df, portfolio_option, constraints)
# Out:
# Running optimizer...........
#
# Ranked Portfolio Metrics:
#     max_sharpe_ratio            2.20
#     annual_return              99.08
#     std_dev                    44.94
#     worst typical down year     9.20
#     black_swan                -35.73
#
#
# Ranked Portfolio Weights:
#     MRNA                           0.2900
#     MSFT                           0.2500
#     ASML                           0.1900
#     TMUS                           0.0500
#     SNPS                           0.1300
#     CHTR                           0.0900
#     CDNS                           0.0000
#     COST                           0.0000
#     PYPL                           0.0000
#     TSLA                           0.0000

# %% [markdown]
# ### Use Sharpe Ratio adjusted weights
# Recommend that you also try using Sharpe Ratio adjusted weights and compare those results with the Optimized Portflio.
# It tends to produce a higher Annual Return while keeping the allocations more balanced than the Optimizer.  (See 'Analysis Options' section).
