# %% [markdown]
# <img src="../../images/brownbear.png" width="400">
#
# ## A financial tool that can analyze and maximize investment portfolios on a risk adjusted basis
#
#
# Description: This notebook is useful for examining potfolios comprised of stocks from the Nasdaq 100.  Construct portfolios from the 100 stocks in the Nasdaq 100 and examine the results of different weighting schemes.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import brownbear as bb

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# display all rows
pd.set_option('display.max_rows', None)

# do not truncate column names
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# ### Some Globals

# %%
investment_universe = ['nasdaq100-galaxy']
risk_free_rate = 0
annual_returns = '3 Yr'
vola = 'Vola'
ds_vola = 'DS Vola'

# %%
# Fetch Investment Options - all values annualized
df = bb.fetch(investment_universe, risk_free_rate, annual_returns, vola, ds_vola)
df
# Out:
#    Investment Option                                 Description Asset Class  \
# 0               ATVI                         Activision Blizzard   US Stocks
# 1               ADBE                                  Adobe Inc.   US Stocks
# 2                AMD                      Advanced Micro Devices   US Stocks
# 3               ALXN                     Alexion Pharmaceuticals   US Stocks
# 4              GOOGL                     Alphabet Inc. (Class A)   US Stocks
# 5               GOOG                     Alphabet Inc. (Class C)   US Stocks
# 6               AMZN                                  Amazon.com   US Stocks
# 7                AEP                     American Electric Power   US Stocks
# 8               AMGN                                       Amgen   US Stocks
# 9                ADI                              Analog Devices   US Stocks
# 10              ANSS                                       Ansys   US Stocks
# 11              AAPL                                  Apple Inc.   US Stocks
# 12              AMAT                     Applied Materials, Inc.   US Stocks
# 13              ASML                                ASML Holding   US Stocks
# 14              TEAM                                   Atlassian   US Stocks
# 15              ADSK                                    Autodesk   US Stocks
# 16               ADP             Automatic Data Processing, Inc.   US Stocks
# 17              BIDU                                       Baidu   US Stocks
# 18              BIIB                                      Biogen   US Stocks
# 19              BKNG                            Booking Holdings   US Stocks
# 20              AVGO                               Broadcom Inc.   US Stocks
# 21              CDNS                      Cadence Design Systems   US Stocks
# 22               CDW                                         CDW   US Stocks
# 23              CERN                          Cerner Corporation   US Stocks
# 24              CHTR                Charter Communications, Inc.   US Stocks
# 25              CHKP      Check Point Software Technologies Ltd.   US Stocks
# 26              CTAS                          Cintas Corporation   US Stocks
# 27              CSCO                               Cisco Systems   US Stocks
# 28              CTSH  Cognizant Technology Solutions Corporation   US Stocks
# 29             CMCSA                         Comcast Corporation   US Stocks
# 30              CPRT                                      Copart   US Stocks
# 31              COST                Costco Wholesale Corporation   US Stocks
# 32               CSX                             CSX Corporation   US Stocks
# 33              DXCM                                      DexCom   US Stocks
# 34              DLTR                           Dollar Tree, Inc.   US Stocks
# 35              EBAY                                   eBay Inc.   US Stocks
# 36                EA                             Electronic Arts   US Stocks
# 37               EXC                          Exelon Corporation   US Stocks
# 38                FB                              Facebook, Inc.   US Stocks
# 19            6.91          0.21
# 20           28.29          1.00
# 21           52.36          1.97
# 22           30.26          1.12
# 23            3.11          0.15
# 24           19.66          0.76
# 25            1.37          0.06
# 26           25.23          0.73
# 27            2.75          0.11
# 28           -2.77        -82.74
# 29           12.40          0.53
# 30           32.51          1.04
# 31           21.91          1.26
# 32           19.36          0.76
# 33           91.13          1.73
# 34           -2.58        -76.19
# 35            9.96          0.31
# 36            1.43          0.05
# 37            3.64          0.20
# 38           11.68          0.36
# 39           21.77          0.72
# 40           16.65          0.69
# 41           -5.76       -137.32
# 42           40.87          1.57
# 43           -3.50       -129.12
# 44           10.02          0.36
# 45           32.25          1.34
# 46           24.37          0.68
# 47           20.20          0.84
# 48           42.61          1.23
# 49          -15.38       -570.14
# 50           44.75          1.12
# 51           55.85          1.43
# 52            2.51          0.06
# 53           52.06          1.37
# 54           17.62          0.64
# 55           60.99          1.28
# 56           22.77          0.55
# 57           24.02          0.56
# 58           36.35          1.98
# 59            8.26          0.44
# 60           10.06          0.33
# 61           30.88          0.74
# 62           14.79          0.39
# 63           20.61          0.78
# 64           12.85          0.54
# 65           14.47          0.65
# 66           48.50          1.63
# 67            8.43          0.49
# 68           31.00          0.69
# 69           11.52          0.32
# 70           14.32          0.51
# 71           -1.80        -47.74
# 72           19.22          0.52
# 73           14.73          0.33
# 74           26.16          0.98
# 75           42.09          1.66
# 76           25.21          1.12
# 77          111.42          1.39
# 78           19.51          0.80
# 79           -5.73       -234.70
# 80           18.28          0.79
# 81           17.03          0.77
# 82            7.83          0.27
# 83           -9.08       -278.21
# 84           24.26          0.61
# 85           12.76          0.81
# 86           23.93          0.70

# %%
# rank
rank = bb.rank(df, rank_by='Sharpe Ratio', group_by=None, num_per_group=50)
rank_filtered = rank
rank_filtered = rank.loc[(rank['3 mo'] > 0) & rank['1 Yr'] > 0]
rank_filtered = rank_filtered.head(20)
rank_filtered
# Out:
#    Investment Option             Description Asset Class   1 mo   3 mo   1 Yr  \
# 14              TEAM               Atlassian   US Stocks 193.52  53.65  66.22
# 58              MSFT   Microsoft Corporation   US Stocks   0.08  40.69  48.40
# 21              CDNS  Cadence Design Systems   US Stocks 209.00 163.49 114.29
# 33              DXCM                  DexCom   US Stocks 370.18 159.79  41.32
# 75              SNPS          Synopsys, Inc.   US Stocks -36.09  67.67  79.21
# 66              PYPL                  PayPal   US Stocks 333.81 153.18 140.96
# 13              ASML            ASML Holding   US Stocks 154.44 219.18 106.39
# 42              IDXX      Idexx Laboratories   US Stocks 282.20  83.66 107.94
# 77              TSLA             Tesla, Inc.   US Stocks -94.80 118.85 397.42
# 53              MTCH             Match Group   US Stocks 505.47  47.62 164.70
# 45              INTU                  Intuit   US Stocks 136.69  64.20  46.21
# 55              MELI            MercadoLibre   US Stocks -43.80  67.80 173.02
# 48              KLAC         KLA Corporation   US Stocks 204.30 142.17 113.63
# 11              AAPL              Apple Inc.   US Stocks -84.77  23.63  78.71
# 50              LRCX            Lam Research   US Stocks 218.16 163.21 101.80
# 22               CDW                     CDW   US Stocks 647.17  74.67  36.86
# 10              ANSS                   Ansys   US Stocks -23.93  28.74  39.66
# 20              AVGO           Broadcom Inc.   US Stocks  93.61 113.05  79.35
# 74              SBUX   Starbucks Corporation   US Stocks 244.25  48.37  40.78
# 15              ADSK                Autodesk   US Stocks  11.68  29.01  52.78
#
#      3 Yr  5 Yr  Vola  DS Vola  Std Dev  Annual Returns  Sharpe Ratio
# 14  65.15 58.80 39.21    25.53    32.27           65.15          2.02
# 58  36.35 37.21 22.42    14.76    18.39           36.35          1.98
# 21  52.36 45.54 36.79    18.94    26.62           52.36          1.97
# 33  91.13 42.71 28.66    12.57    52.79           91.13          1.73
# 75  42.09 40.65 42.65    29.60    25.42           42.09          1.66
# 66  48.50 47.88 49.22    24.06    29.68           48.50          1.63
# 13  42.94 46.14 38.88    23.62    26.43           42.94          1.62
# 42  40.87 48.04 33.01    18.07    26.08           40.87          1.57
# 77 111.42 78.30 59.74    41.50    80.37          111.42          1.39
# 53  52.06 64.59 64.68    33.15    38.08           52.06          1.37
# 45  32.25 32.48 37.55    22.78    24.13           32.25          1.34
# 55  60.99 74.28 45.43    31.20    47.77           60.99          1.28
# 48  42.61 39.03 58.80    31.69    34.64           42.61          1.23
# 11  41.10 40.06 24.03    18.76    34.12           41.10          1.20
# 50  44.75 53.56 61.22    34.44    39.93           44.75          1.12
# 22  30.26 33.47 37.61    13.26    27.09           30.26          1.12
# 10  28.24 32.27 52.21    42.65    27.69           28.24          1.02
# 20  28.29 33.08 32.27    20.07    28.36           28.29          1.00
# 74  26.16 15.15 27.66     8.64    26.57           26.16          0.98
# 15  33.15 41.06 35.68    21.28    35.12           33.15          0.94

# %% [markdown]
# ### Sample Portfolios
# Format 'Investment option': weight

# %%
# everything ranked
ranked_portfolio = {
    'Title': 'Ranked Portfolio'
}
everything = list(rank_filtered['Investment Option'])
ranked_portfolio.update(dict.fromkeys(everything, 1/len(everything)))

# top 10
top10_portfolio = {
    'Title': 'Ranked Portfolio'
}
top10 = list(rank_filtered['Investment Option'])[:10]
top10_portfolio.update(dict.fromkeys(top10, 1/len(top10)))

# %% [markdown]
# ### Custom Portfolios

# %%
# My portfolio
my_portfolio = {
    'Title': 'My Portfolio',

}

# %% [markdown]
# ### Choose Portfolio Option

# %%
# Select one of the portfolios from above
portfolio_option = top10_portfolio

# %%
# Make a copy so that the original portfolio is preserved
portfolio_option = portfolio_option.copy()

# %% [markdown]
# ### Analysis Options

# %%
# Specify the weighting scheme.  It will replace the weights specified in the portfolio
# You can also fix the weights on some Investent Options, Asset Classes, and Asset Subclasses
# while the others are automatically calculated.

# 'Equal' - will use equal weights.

# 'Sharpe Ratio' - will use proportionally weighted # allocations based on the percent
#  of an investment option's sharpe ratio to the sum of all the sharpe ratios in the portfolio.

# 'Std Dev' - will use standard deviation adjusted weights

# 'Annual Returns' - will use return adjusted weights

# 'Vola' - will use volatility adjusted weights

# 'DS Vola' - will use downside volatility adjusted weights

# None: 'Investment Option' means use user specified weights
#       'Asset Class' means do not group by Asset Class
#       'Asset Subclass means do not group by Asset Subclass 

weight_by = {
    'Asset Class':       {'weight_by': None},
    'Asset Subclass':    {'weight_by': None},
    'Investment Option': {'weight_by': 'DS Vola'},
}
#weight_by = None

# %%
bb.DEBUG = False

# Analyze portfolio
annual_ret, std_dev, sharpe_ratio = \
    bb.analyze(df, portfolio_option, weight_by)

# %%
# Display Results
summary = bb.summary(df, portfolio_option, annual_ret, std_dev, sharpe_ratio)
summary
# Out:
#                           TEAM   MSFT   CDNS   DXCM   SNPS   PYPL   ASML  \
# Annual Returns           65.15  36.35  52.36  91.13  42.09  48.50  42.94
# Std Dev                  32.27  18.39  26.62  52.79  25.42  29.68  26.43
# Sharpe Ratio              2.02   1.98   1.97   1.73   1.66   1.63   1.62
# Weight                    0.08   0.15   0.11   0.17   0.07   0.09   0.09
# Worst Typical Down Year   0.61  -0.43  -0.88 -14.45  -8.75 -10.86  -9.92
# Black Swan              -31.66 -18.82 -27.50 -67.24 -34.17 -40.54 -36.35
#
#                           IDXX    TSLA   MTCH  Ranked Portfolio
# Annual Returns           40.87  111.42  52.06             57.45
# Std Dev                  26.08   80.37  38.08             31.70
# Sharpe Ratio              1.57    1.39   1.37              1.81
# Weight                    0.12    0.05   0.06              1.00
# Worst Typical Down Year -11.29  -49.32 -24.10             -5.95
# Black Swan              -37.37 -129.69 -62.18            -37.64

# %%
# Show pie charts of investment and asset class weights
bb.show_pie_charts(df, portfolio_option, charts=['Investment Option'])
# Out:
# ASML   0.09
# TEAM   0.08
# CDNS   0.11
# DXCM   0.17
# IDXX   0.12
# MTCH   0.06
# MSFT   0.15
# PYPL   0.09
# SNPS   0.07
# TSLA   0.05

# %%
# Show exact weights
bb.print_portfolio(portfolio_option)
# Out:
# Ranked Portfolio Weights:
#     TEAM                           0.0840
#     MSFT                           0.1452
#     CDNS                           0.1132
#     DXCM                           0.1705
#     SNPS                           0.0724
#     PYPL                           0.0891
#     ASML                           0.0907
#     IDXX                           0.1186
#     TSLA                           0.0516
#     MTCH                           0.0647

# %% [markdown]
# ### Optimize Portfolio

# %%
# Run_portfolio_optimizer = True will run portfolio optimizer after portfolio analysis is complete
run_portfolio_optimizer = True

# %%
# Optimize sharpe ratio while specifying Annual Rate, Worst Typical Down Year,
# and Black Swan.  Setting a constraint to None optimizes absolute Sharpe Ratio
# without regard to that constraint.

'''
constraints = {
    'Annual Return': 12,
    'Worst Typical Down Year': -5,
    'Black Swan': None
}
'''

constraints = {
    'Annual Return': 8,
    'Worst Typical Down Year': None,
    'Black Swan': -40
}

if run_portfolio_optimizer:
    bb.optimizer(df, portfolio_option, constraints)
# Out:
# Running optimizer..........
#
# Ranked Portfolio Metrics:
#     max_sharpe_ratio            2.00
#     annual_return              54.88
#     std_dev                    27.45
#     worst typical down year    -0.02
#     black_swan                -27.47
#
#
# Ranked Portfolio Weights:
#     TEAM                           0.3200
#     MSFT                           0.2100
#     CDNS                           0.1600
#     DXCM                           0.0800
#     SNPS                           0.0400
#     PYPL                           0.1600
#     ASML                           0.0300
#     IDXX                           0.0000
#     TSLA                           0.0000
#     MTCH                           0.0000

# %% [markdown]
# ### Use Sharpe Ratio adjusted weights
# Recommend that you also try using Sharpe Ratio adjusted weights and compare those results with the Optimized Portflio.
# It tends to produce a higher Annual Return while keeping the allocations more balanced than the Optimizer.  (See 'Analysis Options' section).
