# %% [markdown]
# <img src="../../images/brownbear.png" width="400">
#
# ## A financial tool that can analyze and maximize investment portfolios on a risk adjusted basis
#
#
# Description: This notebook is useful for examining potfolios comprised of stocks from the Nasdaq 100.  Construct portfolios from the 100 stocks in the Nasdaq 100 and examine the results of different weighting schemes.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import brownbear as bb

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# display all rows
pd.set_option('display.max_rows', None)

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# ### Some Globals

# %%
investment_universe = ['nasdaq100-galaxy']
risk_free_rate = 0
annual_returns = '3 Yr'
vola = 'Vola'
ds_vola = 'DS Vola'

# %%
# Fetch Investment Options - all values annualized
df = bb.fetch(investment_universe, risk_free_rate, annual_returns, vola, ds_vola)
df
# Out:
#    Investment Option                                 Description Asset Class  \
# 0               ATVI                         Activision Blizzard   US Stocks
# 1               ADBE                                  Adobe Inc.   US Stocks
# 2                AMD                      Advanced Micro Devices   US Stocks
# 3               ALXN                     Alexion Pharmaceuticals   US Stocks
# 4               ALGN                            Align Technology   US Stocks
# 5              GOOGL                     Alphabet Inc. (Class A)   US Stocks
# 6               GOOG                     Alphabet Inc. (Class C)   US Stocks
# 7               AMZN                                  Amazon.com   US Stocks
# 8                AEP                     American Electric Power   US Stocks
# 9               AMGN                                       Amgen   US Stocks
# 10               ADI                              Analog Devices   US Stocks
# 11              ANSS                                       Ansys   US Stocks
# 12              AAPL                                  Apple Inc.   US Stocks
# 13              AMAT                     Applied Materials, Inc.   US Stocks
# 14              ASML                                ASML Holding   US Stocks
# 15              TEAM                                   Atlassian   US Stocks
# 16              ADSK                                    Autodesk   US Stocks
# 17               ADP             Automatic Data Processing, Inc.   US Stocks
# 18              BIDU                                       Baidu   US Stocks
# 19              BIIB                                      Biogen   US Stocks
# 20              BKNG                            Booking Holdings   US Stocks
# 21              AVGO                               Broadcom Inc.   US Stocks
# 22              CDNS                      Cadence Design Systems   US Stocks
# 23               CDW                                         CDW   US Stocks
# 24              CERN                          Cerner Corporation   US Stocks
# 25              CHTR                Charter Communications, Inc.   US Stocks
# 26              CHKP      Check Point Software Technologies Ltd.   US Stocks
# 27              CTAS                          Cintas Corporation   US Stocks
# 28              CSCO                               Cisco Systems   US Stocks
# 29              CTSH  Cognizant Technology Solutions Corporation   US Stocks
# 30             CMCSA                         Comcast Corporation   US Stocks
# 31              CPRT                                      Copart   US Stocks
# 32              COST                Costco Wholesale Corporation   US Stocks
# 33               CSX                             CSX Corporation   US Stocks
# 34              DXCM                                      DexCom   US Stocks
# 2   71.65 101.91 117.44 37.73    25.26    56.68          101.91          1.80
# 34  61.12  94.22  49.56 35.20    19.43    52.79           94.22          1.78
# 43  82.28  45.04  49.79 32.93    17.97    26.03           45.04          1.73
# 84 419.65 133.71  93.52 44.13    25.97    79.30          133.71          1.69
# 32  18.61  28.26  22.09 17.24    11.43    16.84           28.26          1.68
# 54  35.70  64.52  43.11 28.45    15.26    38.65           64.52          1.67
# 57 156.56  64.48  71.47 69.61    33.15    39.36           64.48          1.64
# 59 192.39  76.71  86.14 52.51    26.09    47.18           76.71          1.63
# 1   33.41  38.57  46.16 24.64    13.76    23.87           38.57          1.62
# 12  70.76  53.72  43.71 31.36    17.31    33.46           53.72          1.61
# 47  34.77  38.60  35.77 30.71    14.96    24.30           38.60          1.59
# 51  75.10  47.92  39.41 48.53    28.32    34.37           47.92          1.39
# 11  34.10  37.46  36.00 33.86    19.46    27.69           37.46          1.35
# 53  66.21  51.58  54.68 53.20    28.52    39.34           51.58          1.31

# %% [markdown]
# ### Sample Portfolios
# Format 'Investment option': weight

# %%
# everything ranked
ranked_portfolio = {
    'Title': 'Ranked Portfolio'
}
everything = list(rank_filtered['Investment Option'])
ranked_portfolio.update(dict.fromkeys(everything, 1/len(everything)))

# top 10
top10_portfolio = {
    'Title': 'Ranked Portfolio'
}
top10 = list(rank_filtered['Investment Option'])[:10]
top10_portfolio.update(dict.fromkeys(top10, 1/len(top10)))

# %% [markdown]
# ### Custom Portfolios

# %%
# My portfolio
my_portfolio = {
    'Title': 'My Portfolio',

}

# %% [markdown]
# ### Choose Portfolio Option

# %%
# Select one of the portfolios from above
portfolio_option = top10_portfolio

# %%
# Make a copy so that the original portfolio is preserved
portfolio_option = portfolio_option.copy()

# %% [markdown]
# ### Analysis Options

# %%
# Specify the weighting scheme.  It will replace the weights specified in the portfolio
# You can also fix the weights on some Investent Options, Asset Classes, and Asset Subclasses
# while the others are automatically calculated.

# 'Equal' - will use equal weights.

# 'Sharpe Ratio' - will use proportionally weighted # allocations based on the percent
#  of an investment option's sharpe ratio to the sum of all the sharpe ratios in the portfolio.

# 'Std Dev' - will use standard deviation adjusted weights

# 'Annual Returns' - will use return adjusted weights

# 'Vola' - will use volatility adjusted weights

# 'DS Vola' - will use downside volatility adjusted weights

# None: 'Investment Option' means use user specified weights
#       'Asset Class' means do not group by Asset Class
#       'Asset Subclass means do not group by Asset Subclass 

weight_by = {
    'Asset Class':       {'weight_by': None},
    'Asset Subclass':    {'weight_by': None},
    'Investment Option': {'weight_by': 'DS Vola'},
}
#weight_by = None

# %%
bb.DEBUG = False

# Analyze portfolio
annual_ret, std_dev, sharpe_ratio = \
    bb.analyze(df, portfolio_option, weight_by)

# %%
# Display Results
summary = bb.summary(df, portfolio_option, annual_ret, std_dev, sharpe_ratio)
summary
# Out:
#                           MSFT   TEAM   CDNS   SNPS   PYPL   ASML    AMD  \
# Annual Returns           43.90  72.88  55.28  49.65  57.62  48.26 101.91
# Std Dev                  18.36  32.36  26.52  25.22  31.00  26.43  56.68
# Sharpe Ratio              2.39   2.25   2.08   1.97   1.86   1.83   1.80
# Weight                    0.16   0.10   0.12   0.11   0.10   0.08   0.07
# Worst Typical Down Year   7.18   8.16   2.24  -0.79  -4.38  -4.60 -11.45
# Black Swan              -11.18 -24.20 -24.28 -26.01 -35.38 -31.03 -68.13
#
#                           DXCM   IDXX    TSLA  Ranked Portfolio
# Annual Returns           94.22  45.04  133.71             70.25
# Std Dev                  52.79  26.03   79.30             34.92
# Sharpe Ratio              1.78   1.73    1.69              2.01
# Weight                    0.09   0.10    0.07              1.00
# Worst Typical Down Year -11.36  -7.02  -24.89              0.41
# Black Swan              -64.15 -33.05 -104.19            -34.51

# %%
# Show pie charts of investment and asset class weights
bb.show_pie_charts(df, portfolio_option, charts=['Investment Option'])
# Out:
# AMD    0.07
# ASML   0.08
# TEAM   0.10
# CDNS   0.12
# DXCM   0.09
# IDXX   0.10
# MSFT   0.16
# PYPL   0.10
# SNPS   0.11
# TSLA   0.07

# %%
# Show exact weights
bb.print_portfolio(portfolio_option)
# Out:
# Ranked Portfolio Weights:
#     MSFT                           0.1622
#     TEAM                           0.0977
#     CDNS                           0.1165
#     SNPS                           0.1107
#     PYPL                           0.0974
#     ASML                           0.0834
#     AMD                            0.0710
#     DXCM                           0.0923
#     IDXX                           0.0998
#     TSLA                           0.0691

# %% [markdown]
# ### Optimize Portfolio

# %%
# Run_portfolio_optimizer = True will run portfolio optimizer after portfolio analysis is complete
run_portfolio_optimizer = True

# %%
# Optimize sharpe ratio while specifying Annual Rate, Worst Typical Down Year,
# and Black Swan.  Setting a constraint to None optimizes absolute Sharpe Ratio
# without regard to that constraint.

'''
constraints = {
    'Annual Return': 12,
    'Worst Typical Down Year': -5,
    'Black Swan': None
}
'''

constraints = {
    'Annual Return': 8,
    'Worst Typical Down Year': None,
    'Black Swan': -40
}

if run_portfolio_optimizer:
    bb.optimizer(df, portfolio_option, constraints)
# Out:
# Running optimizer.......
#
# Ranked Portfolio Metrics:
#     max_sharpe_ratio            2.23
#     annual_return              63.61
#     std_dev                    28.49
#     worst typical down year     6.64
#     black_swan                -21.84
#
#
# Ranked Portfolio Weights:
#     MSFT                           0.2800
#     TEAM                           0.3300
#     CDNS                           0.1300
#     SNPS                           0.0400
#     PYPL                           0.0300
#     ASML                           0.0400
#     AMD                            0.0400
#     DXCM                           0.1100
#     IDXX                           0.0000
#     TSLA                           0.0000

# %% [markdown]
# ### Use Sharpe Ratio adjusted weights
# Recommend that you also try using Sharpe Ratio adjusted weights and compare those results with the Optimized Portflio.
# It tends to produce a higher Annual Return while keeping the allocations more balanced than the Optimizer.  (See 'Analysis Options' section).
