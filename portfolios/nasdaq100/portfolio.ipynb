# %% [markdown]
# <img src="../../images/brownbear.png" width="400">
#
# ## A financial tool that can analyze and maximize investment portfolios on a risk adjusted basis
#
#
# Description: This notebook is useful for examining potfolios comprised of stocks from the Nasdaq 100.  Construct portfolios from the 100 stocks in the Nasdaq 100 and examine the results of different weighting schemes.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import brownbear as bb

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# display all rows
pd.set_option('display.max_rows', None)

# do not truncate column names
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# ### Some Globals

# %%
investment_universe = ['nasdaq100-galaxy']
risk_free_rate = 0
annual_returns = '3 Yr'
vola = 'Vola'
ds_vola = 'DS Vola'

# %%
# Fetch Investment Options - all values annualized
df = bb.fetch(investment_universe, risk_free_rate, annual_returns, vola, ds_vola)
df
# Out:
#     Investment Option                     Description Asset Class   1 mo  \
# 0                ADBE                      Adobe Inc.   US Stocks  -8.16
# 1                 AMD          Advanced Micro Devices   US Stocks -85.58
# 2                ABNB                          Airbnb   US Stocks  74.41
# 3               GOOGL         Alphabet Inc. (Class A)   US Stocks -80.83
# 4                GOOG         Alphabet Inc. (Class C)   US Stocks -80.29
# 5                AMZN                          Amazon   US Stocks -73.43
# 6                 AEP         American Electric Power   US Stocks 186.60
# 7                AMGN                           Amgen   US Stocks 222.47
# 8                 ADI                  Analog Devices   US Stocks 200.40
# 9                ANSS                           Ansys   US Stocks -36.91
# 10               AAPL                      Apple Inc.   US Stocks  14.67
# 11               AMAT               Applied Materials   US Stocks -70.26
# 12                APP                        AppLovin   US Stocks -75.57
# 13                ARM                    Arm Holdings   US Stocks -74.56
# 14               ASML                    ASML Holding   US Stocks  -5.85
# 15                AZN                     AstraZeneca   US Stocks 214.99
# 16               TEAM                       Atlassian   US Stocks  74.83
# 17               ADSK                        Autodesk   US Stocks -71.19
# 18                ADP       Automatic Data Processing   US Stocks  76.75
# 19               AXON                 Axon Enterprise   US Stocks -89.95
# 20                BKR                    Baker Hughes   US Stocks  60.73
# 21               BIIB                          Biogen   US Stocks -28.06
# 22               BKNG                Booking Holdings   US Stocks 106.51
# 23               AVGO                        Broadcom   US Stocks -33.59
# 24               CDNS          Cadence Design Systems   US Stocks -82.66
# 25                CDW                 CDW Corporation   US Stocks -65.82
# 26               CHTR          Charter Communications   US Stocks  15.12
# 27               CTAS                          Cintas   US Stocks  73.54
# 28               CSCO                           Cisco   US Stocks 142.40
# 29               CCEP  Coca-Cola Europacific Partners   US Stocks 225.51
# 30               CTSH                       Cognizant   US Stocks  42.37
# 31              CMCSA                         Comcast   US Stocks -38.43
# 22           0.91
# 23           1.40
# 24           0.74
# 25           0.11
# 26        -592.04
# 27           1.52
# 28           0.42
# 29           1.06
# 30           0.05
# 31        -131.70
# 32           1.87
# 33           0.82
# 34           0.45
# 35           1.22
# 36           0.66
# 37           0.00
# 38        -392.89
# 39        -108.93
# 40           0.40
# 41           0.62
# 42           0.05
# 43           0.33
# 44           0.77
# 45           0.65
# 46        -168.79
# 47           1.14
# 48        -305.54
# 49           0.36
# 50         -96.58
# 51        -773.64
# 52           0.40
# 53           0.77
# 54         -31.66
# 55           0.85
# 56         -90.98
# 57           0.42
# 58           0.97
# 59           0.20
# 60           0.74
# 61           0.25
# 62           0.70
# 63           1.18
# 64        -140.55
# 65           0.08
# 66           0.61
# 67           0.75
# 68           0.07
# 69        -554.41
# 70           0.54
# 71           0.84
# 72           1.42
# 73           0.19
# 74           1.40
# 75           0.24
# 76        -315.81
# 77           0.96
# 78           1.23
# 79           1.00
# 80           0.64
# 81        -418.56
# 82           0.44
# 83           0.01
# 84           0.04
# 85           0.17
# 86           0.56
# 87           0.63
# 88           0.39
# 89           0.54
# 90           0.35
# 91           1.61
# 92           0.07
# 93           0.35
# 94         -85.56
# 95           0.79
# 96           1.14
# 97       -1414.25
# 98           0.22
# 99           0.36
# 100       -316.21

# %%
# rank
rank = bb.rank(df, rank_by='Sharpe Ratio', group_by=None, num_per_group=50)
rank_filtered = rank
rank_filtered = rank.loc[(rank['3 mo'] > 0) & rank['1 Yr'] > 0]
rank_filtered = rank_filtered.head(20)
rank_filtered
# Out:
#    Investment Option                     Description Asset Class   1 mo  \
# 32               CEG            Constellation Energy   US Stocks -84.00
# 91              TMUS                     T-Mobile US   US Stocks 439.05
# 74              ORLY             O'Reilly Automotive   US Stocks 116.35
# 23              AVGO                        Broadcom   US Stocks -33.59
# 78              PLTR           Palantir Technologies   US Stocks 112.18
# 35              COST                          Costco   US Stocks 178.03
# 63              META                  Meta Platforms   US Stocks -13.75
# 96              VRTX          Vertex Pharmaceuticals   US Stocks 171.15
# 47              GILD                 Gilead Sciences   US Stocks 755.19
# 29              CCEP  Coca-Cola Europacific Partners   US Stocks 225.51
# 58               LIN                       Linde plc   US Stocks 114.22
# 18               ADP       Automatic Data Processing   US Stocks  76.75
# 12               APP                        AppLovin   US Stocks -75.57
# 55              KLAC                 KLA Corporation   US Stocks  -4.17
# 71              NFLX                   Netflix, Inc.   US Stocks   3.00
# 95              VRSK                Verisk Analytics   US Stocks  80.97
# 53              ISRG              Intuitive Surgical   US Stocks   0.93
# 62              MELI                    MercadoLibre   US Stocks 301.56
# 36              CRWD                     CrowdStrike   US Stocks -20.23
# 45              FTNT                        Fortinet   US Stocks 173.28
#
#      3 mo   1 Yr   3 Yr   5 Yr   Vola  DS Vola  Std Dev  Annual Returns  \
# 32   2.62  61.97  81.51  81.51  51.63    40.19    43.61           81.51
# 91  64.10  66.80  31.44  23.87  28.38    13.09    19.52           31.44
# 74  51.20  26.98  29.55  29.49  19.75     9.41    21.07           29.55
# 23 116.66  55.93  55.71  52.05  48.39    30.51    39.80           55.71
# 78 197.69 246.19 101.18 101.18 115.35    51.86    82.24          101.18
# 35  42.46  41.58  30.22  30.18  23.32    12.23    24.74           30.22
# 63  96.11  37.57  50.07  27.80  22.95    15.33    42.44           50.07
# 96  16.61  11.34  27.65  15.84  29.69    13.72    24.25           27.65
# 47 163.31  62.94  28.18  14.87  32.30    10.39    24.72           28.18
# 29  48.51  25.36  21.37  13.09  16.74     6.56    20.14           21.37
# 58  11.70   6.28  18.69  20.02  16.59     6.85    19.26           18.69
# 18  16.92  28.17  19.59  15.95  11.52     5.05    20.66           19.59
# 12   7.92 437.26  79.54  79.54 116.26    56.69    86.30           79.54
# 55  47.49   5.55  28.70  38.57  29.86    21.71    33.69           28.70
# 71  64.68  62.97  38.70  22.18  24.58    14.93    46.34           38.70
# 95   8.24  22.96  19.44  13.48  19.43    13.69    24.52           19.44
# 53  30.21  48.31  27.50  25.22  23.60    15.52    35.86           27.50
# 62   4.24  32.00  32.10  27.49  35.99    13.68    45.58           32.10
# 36  31.78  21.31  34.03  46.50  43.59    29.44    51.83           34.03
# 45  81.00  54.41  23.82  38.74  25.34    14.00    36.64           23.82
#
#     Sharpe Ratio
# 32          1.87
# 91          1.61
# 74          1.40
# 23          1.40
# 78          1.23
# 35          1.22
# 63          1.18
# 96          1.14
# 47          1.14
# 29          1.06
# 58          0.97
# 18          0.95
# 12          0.92
# 55          0.85
# 71          0.84
# 95          0.79
# 53          0.77
# 62          0.70
# 36          0.66
# 45          0.65

# %% [markdown]
# ### Sample Portfolios
# Format 'Investment option': weight

# %%
# everything ranked
ranked_portfolio = {
    'Title': 'Ranked Portfolio'
}
everything = list(rank_filtered['Investment Option'])
ranked_portfolio.update(dict.fromkeys(everything, 1/len(everything)))

# top 10
top10_portfolio = {
    'Title': 'Ranked Portfolio'
}
top10 = list(rank_filtered['Investment Option'])[:10]
top10_portfolio.update(dict.fromkeys(top10, 1/len(top10)))

# %% [markdown]
# ### Custom Portfolios

# %%
# My portfolio
my_portfolio = {
    'Title': 'My Portfolio',

}

# %% [markdown]
# ### Choose Portfolio Option

# %%
# Select one of the portfolios from above
portfolio_option = top10_portfolio

# %%
# Make a copy so that the original portfolio is preserved
portfolio_option = portfolio_option.copy()

# %% [markdown]
# ### Analysis Options

# %%
# Specify the weighting scheme.  It will replace the weights specified in the portfolio
# You can also fix the weights on some Investent Options, Asset Classes, and Asset Subclasses
# while the others are automatically calculated.

# 'Equal' - will use equal weights.

# 'Sharpe Ratio' - will use proportionally weighted # allocations based on the percent
#  of an investment option's sharpe ratio to the sum of all the sharpe ratios in the portfolio.

# 'Std Dev' - will use standard deviation adjusted weights

# 'Annual Returns' - will use return adjusted weights

# 'Vola' - will use volatility adjusted weights

# 'DS Vola' - will use downside volatility adjusted weights

# None: 'Investment Option' means use user specified weights
#       'Asset Class' means do not group by Asset Class
#       'Asset Subclass means do not group by Asset Subclass 

weight_by = {
    'Asset Class':       {'weight_by': None},
    'Asset Subclass':    {'weight_by': None},
    'Investment Option': {'weight_by': 'DS Vola'},
}
#weight_by = None

# %%
bb.DEBUG = False

# Analyze portfolio
annual_ret, std_dev, sharpe_ratio = \
    bb.analyze(df, portfolio_option, weight_by)

# %%
# Display Results
summary = bb.summary(df, portfolio_option, annual_ret, std_dev, sharpe_ratio)
summary
# Out:
#                            CEG   TMUS   ORLY   AVGO    PLTR   COST   META  \
# Annual Returns           81.51  31.44  29.55  55.71  101.18  30.22  50.07
# Std Dev                  43.61  19.52  21.07  39.80   82.24  24.74  42.44
# Sharpe Ratio              1.87   1.61   1.40   1.40    1.23   1.22   1.18
# Weight                    0.03   0.10   0.15   0.05    0.03   0.11   0.09
# Worst Typical Down Year  -5.71  -7.60 -12.59 -23.89  -63.30 -19.26 -34.81
# Black Swan              -49.32 -27.12 -33.66 -63.69 -145.54 -44.00 -77.25
#
#                           VRTX   GILD   CCEP  Ranked Portfolio
# Annual Returns           27.65  28.18  21.37             34.43
# Std Dev                  24.25  24.72  20.14             25.20
# Sharpe Ratio              1.14   1.14   1.06              1.37
# Weight                    0.10   0.13   0.21              1.00
# Worst Typical Down Year -20.85 -21.26 -18.91            -15.97
# Black Swan              -45.10 -45.98 -39.05            -41.17

# %%
# Show pie charts of investment and asset class weights
bb.show_pie_charts(df, portfolio_option, charts=['Investment Option'])
# Out:
# AVGO   0.05
# CCEP   0.21
# CEG    0.03
# COST   0.11
# GILD   0.13
# META   0.09
# ORLY   0.15
# PLTR   0.03
# TMUS   0.10
# VRTX   0.10

# %%
# Show exact weights
bb.print_portfolio(portfolio_option)
# Out:
# Ranked Portfolio Weights:
#     CEG                            0.0342
#     TMUS                           0.1049
#     ORLY                           0.1459
#     AVGO                           0.0450
#     PLTR                           0.0265
#     COST                           0.1123
#     META                           0.0896
#     VRTX                           0.1001
#     GILD                           0.1322
#     CCEP                           0.2093

# %% [markdown]
# ### Optimize Portfolio

# %%
# Run_portfolio_optimizer = True will run portfolio optimizer after portfolio analysis is complete
run_portfolio_optimizer = False

# %%
# Optimize sharpe ratio while specifying Annual Rate, Worst Typical Down Year,
# and Black Swan.  Setting a constraint to None optimizes absolute Sharpe Ratio
# without regard to that constraint.

'''
constraints = {
    'Annual Return': 12,
    'Worst Typical Down Year': -5,
    'Black Swan': None
}
'''

constraints = {
    'Annual Return': 8,
    'Worst Typical Down Year': None,
    'Black Swan': -40
}

if run_portfolio_optimizer:
    bb.optimizer(df, portfolio_option, constraints)

# %% [markdown]
# ### Use Sharpe Ratio adjusted weights
# Recommend that you also try using Sharpe Ratio adjusted weights and compare those results with the Optimized Portflio.
# It tends to produce a higher Annual Return while keeping the allocations more balanced than the Optimizer.  (See 'Analysis Options' section).
