# %% [markdown]
# <img src="../../images/brownbear.png" width="400">
#
# ## A financial tool that can analyze and maximize investment portfolios on a risk adjusted basis
#
#
# Description: This notebook is useful for examining potfolios comprised of stocks from the Nasdaq 100.  Construct portfolios from the 100 stocks in the Nasdaq 100 and examine the results of different weighting schemes.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import brownbear as bb

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# display all rows
pd.set_option('display.max_rows', None)

# do not truncate column names
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# ### Some Globals

# %%
investment_universe = ['nasdaq100-galaxy']
risk_free_rate = 0
annual_returns = '3 Yr'
vola = 'Vola'
ds_vola = 'DS Vola'

# %%
# Fetch Investment Options - all values annualized
df = bb.fetch(investment_universe, risk_free_rate, annual_returns, vola, ds_vola)
df
# Out:
#     Investment Option                     Description Asset Class    1 mo  \
# 0                ADBE                      Adobe Inc.   US Stocks  -84.88
# 1                 AMD          Advanced Micro Devices   US Stocks  -85.95
# 2                ABNB                          Airbnb   US Stocks  -41.51
# 3               GOOGL         Alphabet Inc. (Class A)   US Stocks  234.57
# 4                GOOG         Alphabet Inc. (Class C)   US Stocks  225.28
# 5                AMZN                          Amazon   US Stocks   69.85
# 6                 AEP         American Electric Power   US Stocks  -54.75
# 7                AMGN                           Amgen   US Stocks  -56.87
# 8                 ADI                  Analog Devices   US Stocks  -45.10
# 9                ANSS                           Ansys   US Stocks  -39.66
# 10               AAPL                      Apple Inc.   US Stocks   23.55
# 11               AMAT               Applied Materials   US Stocks  -73.88
# 12                APP                        AppLovin   US Stocks    4.27
# 13                ARM                    Arm Holdings   US Stocks  -66.23
# 14               ASML                    ASML Holding   US Stocks  -17.13
# 15                AZN                     AstraZeneca   US Stocks  -18.90
# 16               TEAM                       Atlassian   US Stocks  -67.04
# 17               ADSK                        Autodesk   US Stocks  -12.67
# 18                ADP       Automatic Data Processing   US Stocks  -45.01
# 19               AXON                 Axon Enterprise   US Stocks  -54.02
# 20                BKR                    Baker Hughes   US Stocks  -45.11
# 21               BIIB                          Biogen   US Stocks  -66.30
# 22               BKNG                Booking Holdings   US Stocks  -49.71
# 23               AVGO                        Broadcom   US Stocks 5421.63
# 24               CDNS          Cadence Design Systems   US Stocks  -39.22
# 25                CDW                 CDW Corporation   US Stocks  -51.57
# 26               CHTR          Charter Communications   US Stocks  -76.69
# 27               CTAS                          Cintas   US Stocks  -91.04
# 28               CSCO                           Cisco   US Stocks   -6.46
# 29               CCEP  Coca-Cola Europacific Partners   US Stocks    2.38
# 30               CTSH                       Cognizant   US Stocks  -49.00
# 14        -139.12
# 15           0.30
# 16        -737.87
# 17           0.04
# 18           0.37
# 19           1.20
# 20           0.59
# 21        -486.66
# 22           0.91
# 23           1.41
# 24           0.61
# 25        -136.19
# 26        -802.77
# 27           0.88
# 28           0.02
# 29           0.66
# 30         -86.02
# 31        -195.72
# 32           2.88
# 33           0.51
# 34        -113.80
# 35           0.76
# 36           0.37
# 37         -93.59
# 38        -349.49
# 39        -856.57
# 40           0.66
# 41           0.09
# 42           0.15
# 43           0.07
# 44           0.25
# 45           0.24
# 46           0.09
# 47           0.50
# 48        -588.73
# 49           0.21
# 50        -519.86
# 51       -1079.76
# 52         -18.55
# 53           0.36
# 54         -41.03
# 55           0.44
# 56         -22.55
# 57           0.14
# 58           0.39
# 59         -90.30
# 60           0.72
# 61           0.18
# 62           0.22
# 63           0.44
# 64        -450.50
# 65         -98.94
# 66           0.36
# 67           0.63
# 68         -18.31
# 69       -1409.79
# 70           0.15
# 71           0.28
# 72           1.23
# 73         -71.98
# 74           0.91
# 75         -13.87
# 76        -168.29
# 77           0.98
# 78           0.73
# 79           0.71
# 80           0.15
# 81        -958.82
# 82           0.32
# 83         -24.36
# 84        -134.40
# 85           0.12
# 86           0.11
# 87           0.41
# 88        -149.60
# 89           0.29
# 90           0.02
# 91           1.25
# 92           0.02
# 93           0.09
# 94           0.19
# 95           0.27
# 96           0.94
# 97       -1276.25
# 98        -102.96
# 99           0.13
# 100       -855.51

# %%
# rank
rank = bb.rank(df, rank_by='Sharpe Ratio', group_by=None, num_per_group=50)
rank_filtered = rank
rank_filtered = rank.loc[(rank['3 mo'] > 0) & rank['1 Yr'] > 0]
rank_filtered = rank_filtered.head(20)
rank_filtered
# Out:
#    Investment Option             Description Asset Class    1 mo    3 mo  \
# 23              AVGO                Broadcom   US Stocks 5421.63  245.08
# 91              TMUS             T-Mobile US   US Stocks  -72.98   23.90
# 72              NVDA                  Nvidia   US Stocks   -2.65   83.46
# 19              AXON         Axon Enterprise   US Stocks  -54.02  372.82
# 77              PCAR                  Paccar   US Stocks  -65.45   39.35
# 74              ORLY     O'Reilly Automotive   US Stocks  -44.17   11.85
# 22              BKNG        Booking Holdings   US Stocks  -49.71  104.60
# 35              COST                  Costco   US Stocks  -56.41   15.63
# 78              PLTR   Palantir Technologies   US Stocks  345.34 1518.00
# 60               MAR  Marriott International   US Stocks  -39.63   48.02
# 79              PANW      Palo Alto Networks   US Stocks  -60.01   40.32
# 12               APP                AppLovin   US Stocks    4.27 4482.83
# 67              MSTR           MicroStrategy   US Stocks  -94.19 1002.56
# 24              CDNS  Cadence Design Systems   US Stocks  -39.22   54.44
# 20               BKR            Baker Hughes   US Stocks  -45.11   58.95
# 33              CPRT                  Copart   US Stocks  -68.55   30.94
# 47              GILD         Gilead Sciences   US Stocks  -16.13   42.91
# 63              META          Meta Platforms   US Stocks   14.88   20.16
# 10              AAPL              Apple Inc.   US Stocks   23.55   34.27
# 87              ROST             Ross Stores   US Stocks  -23.19   14.93
#
#      1 Yr  3 Yr  5 Yr   Vola  DS Vola  Std Dev  Annual Returns  Sharpe Ratio
# 23 116.61 54.53 53.51 104.98    29.20    38.74           54.53          1.41
# 91  37.09 23.75 23.35  27.02    23.68    18.95           23.75          1.25
# 72 187.22 66.53 88.68  34.71    16.13    54.03           66.53          1.23
# 19 137.05 56.81 52.00  33.51    25.69    47.49           56.81          1.20
# 77  10.88 26.14 18.70  17.53    14.33    26.79           26.14          0.98
# 74  25.69 18.81 22.11  14.91     9.67    20.61           18.81          0.91
# 22  42.76 27.73 19.33  22.38    16.68    30.54           27.73          0.91
# 35  40.65 18.69 27.39  13.64     9.81    24.48           18.69          0.76
# 78 353.50 60.55 60.55  54.21    24.31    83.22           60.55          0.73
# 60  24.67 19.08 13.20  21.82    15.64    26.58           19.08          0.72
# 79  25.11 24.38 36.19  33.41    24.54    34.45           24.38          0.71
# 12 781.33 55.28 55.28  82.43    57.38    86.08           55.28          0.64
# 67 337.87 75.39 84.06 103.21    53.96   119.98           75.39          0.63
# 24  13.22 16.16 33.58  33.03    24.06    26.59           16.16          0.61
# 20  25.65 22.69 13.48  23.12    15.71    38.57           22.69          0.59
# 33  18.54 14.31 19.91  17.06    11.78    28.17           14.31          0.51
# 47  14.89 12.15 11.66  19.06    12.15    24.32           12.15          0.50
# 63  73.71 20.60 24.09  25.54    14.24    46.39           20.60          0.44
# 10  32.00 11.38 28.11  18.36    12.27    26.02           11.38          0.44
# 87  11.93 11.73  6.56  16.55     9.86    28.62           11.73          0.41

# %% [markdown]
# ### Sample Portfolios
# Format 'Investment option': weight

# %%
# everything ranked
ranked_portfolio = {
    'Title': 'Ranked Portfolio'
}
everything = list(rank_filtered['Investment Option'])
ranked_portfolio.update(dict.fromkeys(everything, 1/len(everything)))

# top 10
top10_portfolio = {
    'Title': 'Ranked Portfolio'
}
top10 = list(rank_filtered['Investment Option'])[:10]
top10_portfolio.update(dict.fromkeys(top10, 1/len(top10)))

# %% [markdown]
# ### Custom Portfolios

# %%
# My portfolio
my_portfolio = {
    'Title': 'My Portfolio',

}

# %% [markdown]
# ### Choose Portfolio Option

# %%
# Select one of the portfolios from above
portfolio_option = top10_portfolio

# %%
# Make a copy so that the original portfolio is preserved
portfolio_option = portfolio_option.copy()

# %% [markdown]
# ### Analysis Options

# %%
# Specify the weighting scheme.  It will replace the weights specified in the portfolio
# You can also fix the weights on some Investent Options, Asset Classes, and Asset Subclasses
# while the others are automatically calculated.

# 'Equal' - will use equal weights.

# 'Sharpe Ratio' - will use proportionally weighted # allocations based on the percent
#  of an investment option's sharpe ratio to the sum of all the sharpe ratios in the portfolio.

# 'Std Dev' - will use standard deviation adjusted weights

# 'Annual Returns' - will use return adjusted weights

# 'Vola' - will use volatility adjusted weights

# 'DS Vola' - will use downside volatility adjusted weights

# None: 'Investment Option' means use user specified weights
#       'Asset Class' means do not group by Asset Class
#       'Asset Subclass means do not group by Asset Subclass 

weight_by = {
    'Asset Class':       {'weight_by': None},
    'Asset Subclass':    {'weight_by': None},
    'Investment Option': {'weight_by': 'DS Vola'},
}
#weight_by = None

# %%
bb.DEBUG = False

# Analyze portfolio
annual_ret, std_dev, sharpe_ratio = \
    bb.analyze(df, portfolio_option, weight_by)

# %%
# Display Results
summary = bb.summary(df, portfolio_option, annual_ret, std_dev, sharpe_ratio)
summary
# Out:
#                           AVGO   TMUS   NVDA   AXON   PCAR   ORLY   BKNG  \
# Annual Returns           54.53  23.75  66.53  56.81  26.14  18.81  27.73
# Std Dev                  38.74  18.95  54.03  47.49  26.79  20.61  30.54
# Sharpe Ratio              1.41   1.25   1.23   1.20   0.98   0.91   0.91
# Weight                    0.06   0.07   0.10   0.06   0.11   0.17   0.10
# Worst Typical Down Year -22.95 -14.15 -41.53 -38.17 -27.44 -22.41 -33.35
# Black Swan              -61.69 -33.10 -95.56 -85.66 -54.23 -43.02 -63.89
#
#                           COST    PLTR    MAR  Ranked Portfolio
# Annual Returns           18.69   60.55  19.08             32.80
# Std Dev                  24.48   83.22  26.58             31.33
# Sharpe Ratio              0.76    0.73   0.72              1.05
# Weight                    0.17    0.07   0.10              1.00
# Worst Typical Down Year -30.27 -105.89 -34.08            -29.86
# Black Swan              -54.75 -189.11 -60.66            -61.18

# %%
# Show pie charts of investment and asset class weights
bb.show_pie_charts(df, portfolio_option, charts=['Investment Option'])
# Out:
# AXON   0.06
# BKNG   0.10
# AVGO   0.06
# COST   0.17
# MAR    0.10
# NVDA   0.10
# ORLY   0.17
# PCAR   0.11
# PLTR   0.07
# TMUS   0.07

# %%
# Show exact weights
bb.print_portfolio(portfolio_option)
# Out:
# Ranked Portfolio Weights:
#     AVGO                           0.0555
#     TMUS                           0.0684
#     NVDA                           0.1004
#     AXON                           0.0630
#     PCAR                           0.1130
#     ORLY                           0.1675
#     BKNG                           0.0971
#     COST                           0.1651
#     PLTR                           0.0666
#     MAR                            0.1035

# %% [markdown]
# ### Optimize Portfolio

# %%
# Run_portfolio_optimizer = True will run portfolio optimizer after portfolio analysis is complete
run_portfolio_optimizer = True

# %%
# Optimize sharpe ratio while specifying Annual Rate, Worst Typical Down Year,
# and Black Swan.  Setting a constraint to None optimizes absolute Sharpe Ratio
# without regard to that constraint.

'''
constraints = {
    'Annual Return': 12,
    'Worst Typical Down Year': -5,
    'Black Swan': None
}
'''

constraints = {
    'Annual Return': 8,
    'Worst Typical Down Year': None,
    'Black Swan': -40
}

if run_portfolio_optimizer:
    bb.optimizer(df, portfolio_option, constraints)
# Out:
# Running optimizer
#
# Impossible criteria specified, lower your expectations!!!

# %% [markdown]
# ### Use Sharpe Ratio adjusted weights
# Recommend that you also try using Sharpe Ratio adjusted weights and compare those results with the Optimized Portflio.
# It tends to produce a higher Annual Return while keeping the allocations more balanced than the Optimizer.  (See 'Analysis Options' section).
