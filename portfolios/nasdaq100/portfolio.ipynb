# %% [markdown]
# <img src="../../images/brownbear.png" width="400">
#
# ## A financial tool that can analyze and maximize investment portfolios on a risk adjusted basis
#
#
# Description: This notebook is useful for examining potfolios comprised of stocks from the Nasdaq 100.  Construct portfolios from the 100 stocks in the Nasdaq 100 and examine the results of different weighting schemes.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import brownbear as bb

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# display all rows
pd.set_option('display.max_rows', None)

# do not truncate column names
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# ### Some Globals

# %%
investment_universe = ['nasdaq100-galaxy']
risk_free_rate = 0
annual_returns = '3 Yr'
vola = 'Vola'
ds_vola = 'DS Vola'

# %%
# Fetch Investment Options - all values annualized
df = bb.fetch(investment_universe, risk_free_rate, annual_returns, vola, ds_vola)
df
# Out:
#     Investment Option                     Description Asset Class    1 mo  \
# 0                ADBE                      Adobe Inc.   US Stocks  -33.70
# 1                 ADP                             ADP   US Stocks   31.05
# 2                ABNB                          Airbnb   US Stocks  141.86
# 3               GOOGL         Alphabet Inc. (Class A)   US Stocks   50.79
# 4                GOOG         Alphabet Inc. (Class C)   US Stocks   48.00
# 5                AMZN                          Amazon   US Stocks   57.19
# 6                 AMD     Advanced Micro Devices Inc.   US Stocks  708.30
# 7                 AEP         American Electric Power   US Stocks   34.88
# 8                AMGN                           Amgen   US Stocks  152.78
# 9                 ADI                  Analog Devices   US Stocks  187.11
# 10               ANSS                           Ansys   US Stocks  926.94
# 11               AAPL                      Apple Inc.   US Stocks   21.97
# 12               AMAT               Applied Materials   US Stocks  166.45
# 13               ASML                    ASML Holding   US Stocks  216.59
# 14                AZN                     AstraZeneca   US Stocks   80.36
# 15               TEAM                       Atlassian   US Stocks  948.97
# 16               ADSK                        Autodesk   US Stocks  374.51
# 17                BKR                    Baker Hughes   US Stocks   34.80
# 18               BIIB                          Biogen   US Stocks  269.63
# 19               BKNG                Booking Holdings   US Stocks  355.31
# 20               AVGO                   Broadcom Inc.   US Stocks  722.08
# 21               CDNS          Cadence Design Systems   US Stocks  -11.70
# 22                CDW                 CDW Corporation   US Stocks  129.83
# 23               CHTR          Charter Communications   US Stocks  -26.76
# 24               CTAS                          Cintas   US Stocks  205.66
# 25               CSCO                           Cisco   US Stocks   82.49
# 26               CCEP  Coca-Cola Europacific Partners   US Stocks  281.02
# 27               CTSH                       Cognizant   US Stocks  143.97
# 28              CMCSA                         Comcast   US Stocks   86.53
# 29                CEG            Constellation Energy   US Stocks  -31.13
# 30               CPRT                          Copart   US Stocks  -25.56
# 21           0.91
# 22           0.80
# 23        -553.73
# 24           0.93
# 25           0.29
# 26           0.63
# 27         -23.04
# 28         -69.06
# 29           1.19
# 30           0.54
# 31         -64.14
# 32           0.91
# 33           0.13
# 34           0.22
# 35           0.13
# 36           0.22
# 37           1.42
# 38           0.27
# 39        -693.76
# 40          -8.98
# 41           0.47
# 42           0.53
# 43           0.68
# 44           1.27
# 45           0.71
# 46           0.26
# 47           0.08
# 48           0.10
# 49       -1224.72
# 50           0.15
# 51           0.62
# 52           0.20
# 53           0.20
# 54           1.01
# 55           0.27
# 56           0.50
# 57           0.38
# 58           0.66
# 59           0.18
# 60         -90.58
# 61           0.19
# 62           0.31
# 63           0.20
# 64           0.84
# 65        -271.94
# 66           0.53
# 67           0.07
# 68           0.41
# 69        -101.53
# 70           1.02
# 71           0.40
# 72           1.30
# 73           0.92
# 74           0.79
# 75           1.00
# 76           1.06
# 77           0.45
# 78       -1526.85
# 79           0.01
# 80           0.48
# 81           0.04
# 82           0.90
# 83           0.42
# 84           0.18
# 85         -67.79
# 86        -194.77
# 87         -20.21
# 88           0.83
# 89        -205.49
# 90           0.33
# 91           0.06
# 92           0.19
# 93        -259.97
# 94           0.20
# 95           0.88
# 96        -315.12
# 97       -1594.84
# 98           0.13
# 99           0.06
# 100          0.07

# %%
# rank
rank = bb.rank(df, rank_by='Sharpe Ratio', group_by=None, num_per_group=50)
rank_filtered = rank
rank_filtered = rank.loc[(rank['3 mo'] > 0) & rank['1 Yr'] > 0]
rank_filtered = rank_filtered.head(20)
rank_filtered
# Out:
#    Investment Option             Description Asset Class   1 mo   3 mo   1 Yr  \
# 37              FANG      Diamondback Energy   US Stocks  10.54   9.50  21.72
# 72              ORLY     O'Reilly Automotive   US Stocks -25.74  19.41  12.49
# 20              AVGO           Broadcom Inc.   US Stocks 722.08 232.27 109.52
# 44              GEHC           GE HealthCare   US Stocks 391.66  67.07  34.63
# 29               CEG    Constellation Energy   US Stocks -31.13  33.09  36.61
# 76              PANW      Palo Alto Networks   US Stocks  27.82 150.30 114.72
# 70              NVDA                  Nvidia   US Stocks  40.59  68.05 252.98
# 54              KLAC         KLA Corporation   US Stocks 121.28 160.86  59.98
# 75              PCAR                  Paccar   US Stocks 233.24 101.18  54.58
# 24              CTAS                  Cintas   US Stocks 205.66 148.92  35.00
# 21              CDNS  Cadence Design Systems   US Stocks -11.70  82.62  72.02
# 32              COST                  Costco   US Stocks 426.09 105.38  50.16
# 82              REGN               Regeneron   US Stocks 169.72  29.73  23.18
# 95              VRTX  Vertex Pharmaceuticals   US Stocks 488.90  87.45  42.39
# 64              MSFT               Microsoft   US Stocks  -8.55 102.81  61.76
# 88              SNPS                Synopsys   US Stocks -57.03  58.41  63.30
# 22               CDW         CDW Corporation   US Stocks 129.83  63.00  31.13
# 45              GILD         Gilead Sciences   US Stocks 171.04  41.60  -0.51
# 12              AMAT       Applied Materials   US Stocks 166.45  89.39  73.59
# 58               MAR  Marriott International   US Stocks 264.25  75.01  56.52
#
#     3 Yr  5 Yr  Vola  DS Vola  Std Dev  Annual Returns  Sharpe Ratio
# 37 55.28 14.91 20.53    12.50    38.96           55.28          1.42
# 72 27.62 22.59 20.77    15.57    21.24           27.62          1.30
# 20 41.11 39.34 37.93     9.77    32.10           41.11          1.28
# 44 34.63 34.63 22.90     8.44    27.20           34.63          1.27
# 29 36.61 36.61 32.52    20.16    30.68           36.61          1.19
# 76 34.76 37.15 29.76    19.32    32.88           34.76          1.06
# 70 56.70 72.38 26.69    15.76    55.70           56.70          1.02
# 54 32.78 48.09 27.98    12.11    32.45           32.78          1.01
# 75 24.53 25.29 12.25     3.55    24.64           24.53          1.00
# 24 20.57 30.52 26.58     8.44    22.02           20.57          0.93
# 21 26.43 44.38 22.26    12.63    28.96           26.43          0.91
# 32 22.97 29.10 24.24    10.21    25.38           22.97          0.91
# 82 22.06 19.21 18.99     8.37    24.51           22.06          0.90
# 95 20.51 20.17 47.24     6.97    23.30           20.51          0.88
# 64 19.73 31.38 14.25     9.92    23.39           19.73          0.84
# 88 26.20 43.97 32.52    24.34    31.71           26.20          0.83
# 22 21.50 24.82 11.13     4.58    27.02           21.50          0.80
# 45 17.27  9.51 17.60     9.14    24.22           17.27          0.71
# 12 25.13 40.31 30.41    13.78    37.60           25.13          0.67
# 58 21.35 16.97 23.42    13.13    32.27           21.35          0.66

# %% [markdown]
# ### Sample Portfolios
# Format 'Investment option': weight

# %%
# everything ranked
ranked_portfolio = {
    'Title': 'Ranked Portfolio'
}
everything = list(rank_filtered['Investment Option'])
ranked_portfolio.update(dict.fromkeys(everything, 1/len(everything)))

# top 10
top10_portfolio = {
    'Title': 'Ranked Portfolio'
}
top10 = list(rank_filtered['Investment Option'])[:10]
top10_portfolio.update(dict.fromkeys(top10, 1/len(top10)))

# %% [markdown]
# ### Custom Portfolios

# %%
# My portfolio
my_portfolio = {
    'Title': 'My Portfolio',

}

# %% [markdown]
# ### Choose Portfolio Option

# %%
# Select one of the portfolios from above
portfolio_option = top10_portfolio

# %%
# Make a copy so that the original portfolio is preserved
portfolio_option = portfolio_option.copy()

# %% [markdown]
# ### Analysis Options

# %%
# Specify the weighting scheme.  It will replace the weights specified in the portfolio
# You can also fix the weights on some Investent Options, Asset Classes, and Asset Subclasses
# while the others are automatically calculated.

# 'Equal' - will use equal weights.

# 'Sharpe Ratio' - will use proportionally weighted # allocations based on the percent
#  of an investment option's sharpe ratio to the sum of all the sharpe ratios in the portfolio.

# 'Std Dev' - will use standard deviation adjusted weights

# 'Annual Returns' - will use return adjusted weights

# 'Vola' - will use volatility adjusted weights

# 'DS Vola' - will use downside volatility adjusted weights

# None: 'Investment Option' means use user specified weights
#       'Asset Class' means do not group by Asset Class
#       'Asset Subclass means do not group by Asset Subclass 

weight_by = {
    'Asset Class':       {'weight_by': None},
    'Asset Subclass':    {'weight_by': None},
    'Investment Option': {'weight_by': 'DS Vola'},
}
#weight_by = None

# %%
bb.DEBUG = False

# Analyze portfolio
annual_ret, std_dev, sharpe_ratio = \
    bb.analyze(df, portfolio_option, weight_by)

# %%
# Display Results
summary = bb.summary(df, portfolio_option, annual_ret, std_dev, sharpe_ratio)
summary
# Out:
#                           FANG   ORLY   AVGO   GEHC    CEG   PANW    NVDA  \
# Annual Returns           55.28  27.62  41.11  34.63  36.61  34.76   56.70
# Std Dev                  38.96  21.24  32.10  27.20  30.68  32.88   55.70
# Sharpe Ratio              1.42   1.30   1.28   1.27   1.19   1.06    1.02
# Weight                    0.08   0.06   0.10   0.12   0.05   0.05    0.06
# Worst Typical Down Year -22.64 -14.86 -23.09 -19.77 -24.75 -31.00  -54.70
# Black Swan              -61.60 -36.10 -55.19 -46.97 -55.43 -63.88 -110.40
#
#                           KLAC   PCAR   CTAS  Ranked Portfolio
# Annual Returns           32.78  24.53  20.57             33.35
# Std Dev                  32.45  24.64  22.02             27.59
# Sharpe Ratio              1.01   1.00   0.93              1.21
# Weight                    0.08   0.28   0.12              1.00
# Worst Typical Down Year -32.12 -24.75 -23.47            -21.83
# Black Swan              -64.57 -49.39 -45.49            -49.43

# %%
# Show pie charts of investment and asset class weights
bb.show_pie_charts(df, portfolio_option, charts=['Investment Option'])
# Out:
# AVGO   0.10
# CTAS   0.12
# CEG    0.05
# FANG   0.08
# GEHC   0.12
# KLAC   0.08
# NVDA   0.06
# ORLY   0.06
# PCAR   0.28
# PANW   0.05

# %%
# Show exact weights
bb.print_portfolio(portfolio_option)
# Out:
# Ranked Portfolio Weights:
#     FANG                           0.0790
#     ORLY                           0.0634
#     AVGO                           0.1011
#     GEHC                           0.1170
#     CEG                            0.0490
#     PANW                           0.0511
#     NVDA                           0.0627
#     KLAC                           0.0815
#     PCAR                           0.2782
#     CTAS                           0.1170

# %% [markdown]
# ### Optimize Portfolio

# %%
# Run_portfolio_optimizer = True will run portfolio optimizer after portfolio analysis is complete
run_portfolio_optimizer = True

# %%
# Optimize sharpe ratio while specifying Annual Rate, Worst Typical Down Year,
# and Black Swan.  Setting a constraint to None optimizes absolute Sharpe Ratio
# without regard to that constraint.

'''
constraints = {
    'Annual Return': 12,
    'Worst Typical Down Year': -5,
    'Black Swan': None
}
'''

constraints = {
    'Annual Return': 8,
    'Worst Typical Down Year': None,
    'Black Swan': -40
}

if run_portfolio_optimizer:
    bb.optimizer(df, portfolio_option, constraints)
# Out:
# Running optimizer
#
# Impossible criteria specified, lower your expectations!!!

# %% [markdown]
# ### Use Sharpe Ratio adjusted weights
# Recommend that you also try using Sharpe Ratio adjusted weights and compare those results with the Optimized Portflio.
# It tends to produce a higher Annual Return while keeping the allocations more balanced than the Optimizer.  (See 'Analysis Options' section).
