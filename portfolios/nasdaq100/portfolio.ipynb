# %% [markdown]
# <img src="../../images/brownbear.png" width="400">
#
# ## A financial tool that can analyze and maximize investment portfolios on a risk adjusted basis
#
#
# Description: This notebook is useful for examining potfolios comprised of stocks from the Nasdaq 100.  Construct portfolios from the 100 stocks in the Nasdaq 100 and examine the results of different weighting schemes.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import brownbear as bb

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# display all rows
pd.set_option('display.max_rows', None)

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# ### Some Globals

# %%
investment_universe = ['nasdaq100-galaxy']
risk_free_rate = 0
annual_returns = '3 Yr'
vola = 'Vola'
ds_vola = 'DS Vola'

# %%
# Fetch Investment Options - all values annualized
df = bb.fetch(investment_universe, risk_free_rate, annual_returns, vola, ds_vola)
df
# Out:
#    Investment Option                                 Description Asset Class  \
# 0               ATVI                         Activision Blizzard   US Stocks
# 1               ADBE                                  Adobe Inc.   US Stocks
# 2                AMD                      Advanced Micro Devices   US Stocks
# 3               ALXN                     Alexion Pharmaceuticals   US Stocks
# 4               ALGN                            Align Technology   US Stocks
# 5              GOOGL                     Alphabet Inc. (Class A)   US Stocks
# 6               GOOG                     Alphabet Inc. (Class C)   US Stocks
# 7               AMZN                                  Amazon.com   US Stocks
# 8               AMGN                                       Amgen   US Stocks
# 9                ADI                              Analog Devices   US Stocks
# 10              ANSS                                       ANSYS   US Stocks
# 11              AAPL                                  Apple Inc.   US Stocks
# 12              AMAT                     Applied Materials, Inc.   US Stocks
# 13              ASML                                ASML Holding   US Stocks
# 14              ADSK                                    Autodesk   US Stocks
# 15               ADP             Automatic Data Processing, Inc.   US Stocks
# 16              BIDU                                       Baidu   US Stocks
# 17              BIIB                                      Biogen   US Stocks
# 18              BMRN                BioMarin Pharmaceutical Inc.   US Stocks
# 19              BKNG                            Booking Holdings   US Stocks
# 20              AVGO                               Broadcom Inc.   US Stocks
# 21              CDNS                      Cadence Design Systems   US Stocks
# 22               CDW                                         CDW   US Stocks
# 23              CERN                          Cerner Corporation   US Stocks
# 24              CHTR                Charter Communications, Inc.   US Stocks
# 25              CHKP      Check Point Software Technologies Ltd.   US Stocks
# 26              CTAS                          Cintas Corporation   US Stocks
# 27              CSCO                               Cisco Systems   US Stocks
# 28              CTXS                              Citrix Systems   US Stocks
# 29              CTSH  Cognizant Technology Solutions Corporation   US Stocks
# 30             CMCSA                         Comcast Corporation   US Stocks
# 31              CPRT                                      Copart   US Stocks
# 32              COST                Costco Wholesale Corporation   US Stocks
# 33               CSX                             CSX Corporation   US Stocks
# 34              DXCM                                      DexCom   US Stocks
# 35              DLTR                           Dollar Tree, Inc.   US Stocks
# 56           -8.38       -261.12
# 57           77.68          2.05
# 58            3.05          0.07
# 59           22.43          0.79
# 60           78.99          1.63
# 61           20.59          0.50
# 62           22.50          0.53
# 63           40.24          2.11
# 64           13.51          0.75
# 65           11.34          0.37
# 66           11.82          0.37
# 67           39.38          1.05
# 68           43.09          0.98
# 69           14.00          0.37
# 70           21.58          0.80
# 71           12.06          0.50
# 72           15.45          0.70
# 73           45.31          1.48
# 74           10.78          0.64
# 75           39.23          0.88
# 76            9.18          0.25
# 77           14.79          0.56
# 78           45.76          1.12
# 79            4.99          0.18
# 80           17.16          0.46
# 81           27.52          0.62
# 82           22.80          0.92
# 83           39.25          1.55
# 84           29.82          1.34
# 85           20.96          0.65
# 86          114.10          1.44
# 87           23.51          0.96
# 88           -8.73       -337.68
# 89            8.04          0.17
# 90           21.92          1.01
# 91           27.29          1.40
# 92           18.05          0.62
# 93          -12.54       -351.75
# 94           32.01          0.80
# 95           11.98          0.78
# 96           31.58          0.93

# %%
# rank
rank = bb.rank(df, rank_by='Sharpe Ratio', group_by=None, num_per_group=50)
rank_filtered = rank
rank_filtered = rank.loc[(rank['3 mo'] > 0) & rank['1 Yr'] > 0]
rank_filtered = rank_filtered.head(20)
rank_filtered
# Out:
#    Investment Option                   Description Asset Class    1 mo   3 mo  \
# 63              MSFT         Microsoft Corporation   US Stocks   -7.85   1.26
# 57              LULU           Lululemon Athletica   US Stocks  243.89  18.48
# 2                AMD        Advanced Micro Devices   US Stocks  469.46  72.90
# 32              COST  Costco Wholesale Corporation   US Stocks   24.93  50.63
# 60              MELI                  MercadoLibre   US Stocks  656.65 327.03
# 83              SNPS                Synopsys, Inc.   US Stocks   19.99  65.08
# 44              IDXX            IDEXX Laboratories   US Stocks  -27.12 131.38
# 13              ASML                  ASML Holding   US Stocks  909.74 159.22
# 21              CDNS        Cadence Design Systems   US Stocks  -23.34  56.05
# 73              PYPL                        PayPal   US Stocks  293.16  66.05
# 48              INTU                        Intuit   US Stocks  137.21  50.98
# 86              TSLA                   Tesla, Inc.   US Stocks 6791.79 320.52
# 91              VRSK              Verisk Analytics   US Stocks   -4.25  32.18
# 84              TMUS                   T-Mobile US   US Stocks  361.95  76.86
# 11              AAPL                    Apple Inc.   US Stocks  113.73   5.06
# 31              CPRT                        Copart   US Stocks  -61.39  37.62
# 10              ANSS                         ANSYS   US Stocks   66.09  30.74
# 52              KLAC               KLA Corporation   US Stocks  795.07 251.24
# 78              SGEN                   Seagen Inc.   US Stocks   -5.01 108.19
# 51               KDP         Keurig Dr Pepper Inc.   US Stocks  155.97  16.61
#
#      1 Yr   3 Yr   5 Yr  Vola  DS Vola  Std Dev  Annual Returns  Sharpe Ratio
# 63  44.49  40.24  34.08 20.69    14.14    19.10           40.24          2.11
# 57  63.38  77.68  50.32 32.05    18.48    37.83           77.68          2.05
# 2  137.35 110.86 111.35 42.75    23.35    59.05          110.86          1.88
# 32  31.85  27.66  20.74 23.97    19.96    16.38           27.66          1.69
# 60 169.20  78.99  67.04 60.24    43.57    48.42           78.99          1.63
# 83  79.62  39.25  38.45 37.24    23.97    25.29           39.25          1.55
# 44  81.51  42.11  45.53 40.53    31.25    27.22           42.11          1.55
# 13  71.11  41.56  40.09 25.25     7.49    27.21           41.56          1.53
# 21  79.82  40.77  41.02 36.39    25.46    26.85           40.77          1.52
# 73 108.21  45.31  44.78 45.32    30.88    30.60           45.31          1.48
# 48  46.35  34.69  32.01 31.10    20.92    23.57           34.69          1.47
# 86 806.62 114.10  66.69 60.73    17.34    79.04          114.10          1.44
# 91  34.90  27.29  21.71 21.99    13.27    19.53           27.29          1.40
# 84  71.30  29.82  30.70 24.55     7.61    22.27           29.82          1.34
# 11  87.24  44.50  35.80 23.10    12.34    33.28           44.50          1.34
# 31  27.03  37.64  41.99 20.45    16.42    29.73           37.64          1.27
# 10  35.76  34.23  30.04 29.58    14.87    27.51           34.23          1.24
# 52  66.23  40.97  34.98 27.42    12.91    34.22           40.97          1.20
# 78  52.98  45.76  35.59 35.24    20.69    41.00           45.76          1.12
# 51   6.95  29.63  18.82 22.81    12.40    26.60           29.63          1.11

# %% [markdown]
# ### Sample Portfolios
# Format 'Investment option': weight

# %%
# everything ranked
ranked_portfolio = {
    'Title': 'Ranked Portfolio'
}
everything = list(rank_filtered['Investment Option'])
ranked_portfolio.update(dict.fromkeys(everything, 1/len(everything)))

# top 10
top10_portfolio = {
    'Title': 'Ranked Portfolio'
}
top10 = list(rank_filtered['Investment Option'])[:10]
top10_portfolio.update(dict.fromkeys(top10, 1/len(top10)))

# %% [markdown]
# ### Custom Portfolios

# %%
# My portfolio
my_portfolio = {
    'Title': 'My Portfolio',

}

# %% [markdown]
# ### Choose Portfolio Option

# %%
# Select one of the portfolios from above
portfolio_option = top10_portfolio

# %%
# Make a copy so that the original portfolio is preserved
portfolio_option = portfolio_option.copy()

# %% [markdown]
# ### Analysis Options

# %%
# Specify the weighting scheme.  It will replace the weights specified in the portfolio
# You can also fix the weights on some Investent Options, Asset Classes, and Asset Subclasses
# while the others are automatically calculated.

# 'Equal' - will use equal weights.

# 'Sharpe Ratio' - will use proportionally weighted # allocations based on the percent
#  of an investment option's sharpe ratio to the sum of all the sharpe ratios in the portfolio.

# 'Std Dev' - will use standard deviation adjusted weights

# 'Annual Returns' - will use return adjusted weights

# 'Vola' - will use volatility adjusted weights

# 'DS Vola' - will use downside volatility adjusted weights

# None: 'Investment Option' means use user specified weights
#       'Asset Class' means do not group by Asset Class
#       'Asset Subclass means do not group by Asset Subclass 

weight_by = {
    'Asset Class':       {'weight_by': None},
    'Asset Subclass':    {'weight_by': None},
    'Investment Option': {'weight_by': 'DS Vola'},
}
#weight_by = None

# %%
bb.DEBUG = False

# Analyze portfolio
annual_ret, std_dev, sharpe_ratio = \
    bb.analyze(df, portfolio_option, weight_by)

# %%
# Display Results
summary = bb.summary(df, portfolio_option, annual_ret, std_dev, sharpe_ratio)
summary
# Out:
#                           MSFT   LULU    AMD   COST   MELI   SNPS   IDXX  \
# Annual Returns           40.24  77.68 110.86  27.66  78.99  39.25  42.11
# Std Dev                  19.10  37.83  59.05  16.38  48.42  25.29  27.22
# Sharpe Ratio              2.11   2.05   1.88   1.69   1.63   1.55   1.55
# Weight                    0.14   0.10   0.08   0.10   0.04   0.08   0.06
# Worst Typical Down Year   2.04   2.02  -7.24  -5.10 -17.85 -11.33 -12.33
# Black Swan              -17.06 -35.81 -66.29 -21.48 -66.27 -36.62 -39.55
#
#                           ASML   CDNS   PYPL  Ranked Portfolio
# Annual Returns           41.56  40.77  45.31             54.44
# Std Dev                  27.21  26.85  30.60             29.61
# Sharpe Ratio              1.53   1.52   1.48              1.84
# Weight                    0.26   0.08   0.06              1.00
# Worst Typical Down Year -12.86 -12.93 -15.89             -4.78
# Black Swan              -40.07 -39.78 -46.49            -34.39

# %%
# Show pie charts of investment and asset class weights
bb.show_pie_charts(df, portfolio_option, charts=['Investment Option'])
# Out:
# AMD    0.08
# ASML   0.26
# CDNS   0.08
# COST   0.10
# IDXX   0.06
# LULU   0.10
# MELI   0.04
# MSFT   0.14
# PYPL   0.06
# SNPS   0.08

# %%
# Show exact weights
bb.print_portfolio(portfolio_option)
# Out:
# Ranked Portfolio Weights:
#     MSFT                           0.1361
#     LULU                           0.1041
#     AMD                            0.0824
#     COST                           0.0964
#     MELI                           0.0442
#     SNPS                           0.0803
#     IDXX                           0.0616
#     ASML                           0.2569
#     CDNS                           0.0756
#     PYPL                           0.0623

# %% [markdown]
# ### Optimize Portfolio

# %%
# Run_portfolio_optimizer = True will run portfolio optimizer after portfolio analysis is complete
run_portfolio_optimizer = True

# %%
# Optimize sharpe ratio while specifying Annual Rate, Worst Typical Down Year,
# and Black Swan.  Setting a constraint to None optimizes absolute Sharpe Ratio
# without regard to that constraint.

'''
constraints = {
    'Annual Return': 12,
    'Worst Typical Down Year': -5,
    'Black Swan': None
}
'''

constraints = {
    'Annual Return': 8,
    'Worst Typical Down Year': None,
    'Black Swan': -40
}

if run_portfolio_optimizer:
    bb.optimizer(df, portfolio_option, constraints)
# Out:
# Running optimizer............
#
# Ranked Portfolio Metrics:
#     max_sharpe_ratio            2.03
#     annual_return              56.87
#     std_dev                    28.00
#     worst typical down year     0.86
#     black_swan                -27.14
#
#
# Ranked Portfolio Weights:
#     MSFT                           0.4200
#     LULU                           0.2700
#     AMD                            0.0400
#     COST                           0.0400
#     MELI                           0.1000
#     SNPS                           0.0300
#     IDXX                           0.0000
#     ASML                           0.0400
#     CDNS                           0.0000
#     PYPL                           0.0600

# %% [markdown]
# ### Use Sharpe Ratio adjusted weights
# Recommend that you also try using Sharpe Ratio adjusted weights and compare those results with the Optimized Portflio.
# It tends to produce a higher Annual Return while keeping the allocations more balanced than the Optimizer.  (See 'Analysis Options' section).
