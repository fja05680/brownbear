# %% [markdown]
# <img src="../../images/brownbear.png" width="400">
#
# ## A financial tool that can analyze and maximize investment portfolios on a risk adjusted basis
#
#
# Description: This notebook is useful for examining potfolios comprised of stocks from the Nasdaq 100.  Construct portfolios from the 100 stocks in the Nasdaq 100 and examine the results of different weighting schemes.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import brownbear as bb

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# display all rows
pd.set_option('display.max_rows', None)

# do not truncate column names
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# ### Some Globals

# %%
investment_universe = ['nasdaq100-galaxy']
risk_free_rate = 0
annual_returns = '3 Yr'
vola = 'Vola'
ds_vola = 'DS Vola'

# %%
# Fetch Investment Options - all values annualized
df = bb.fetch(investment_universe, risk_free_rate, annual_returns, vola, ds_vola)
df
# Out:
#     Investment Option                Description Asset Class   1 mo   3 mo  \
# 0                ATVI        Activision Blizzard   US Stocks  -6.76 -12.81
# 1                ADBE                      Adobe   US Stocks -33.68 -55.34
# 2                 ADP                        ADP   US Stocks  82.71  12.30
# 3                ABNB                     Airbnb   US Stocks -45.39  -1.62
# 4                ALGN                      Align   US Stocks -90.06 -63.15
# 5               GOOGL         Alphabet (Class A)   US Stocks -82.41 -29.05
# 6                GOOG         Alphabet (Class C)   US Stocks -82.79 -28.53
# 7                AMZN                     Amazon   US Stocks -77.42   4.87
# 8                 AMD                        AMD   US Stocks -95.40 -69.71
# 9                 AEP    American Electric Power   US Stocks  67.96  59.60
# 10               AMGN                      Amgen   US Stocks 122.83  46.08
# 11                ADI             Analog Devices   US Stocks -25.69 -10.28
# 12               ANSS                      Ansys   US Stocks -70.84 -48.07
# 13               AAPL                      Apple   US Stocks -45.60  -1.52
# 14               AMAT          Applied Materials   US Stocks -84.01 -51.34
# 15               ASML                       ASML   US Stocks -66.36 -41.49
# 16                AZN                AstraZeneca   US Stocks  32.83  64.68
# 17               TEAM                  Atlassian   US Stocks -86.26 -43.56
# 18               ADSK                   Autodesk   US Stocks -70.45 -62.39
# 19               BIDU                      Baidu   US Stocks -97.32 -71.53
# 20               BIIB                     Biogen   US Stocks   2.14 -17.78
# 21               BKNG           Booking Holdings   US Stocks  34.58 -20.68
# 22               AVGO                   Broadcom   US Stocks -22.23  46.81
# 23               CDNS                    Cadence   US Stocks -51.56  -0.62
# 24               CHTR     Charter Communications   US Stocks -66.38 -35.08
# 25               CTAS                     Cintas   US Stocks  21.80  33.57
# 26               CSCO                      Cisco   US Stocks -50.72 -32.58
# 27               CTSH                  Cognizant   US Stocks -65.90  -5.12
# 36           0.43
# 37           0.37
# 38           0.55
# 39           0.71
# 40           0.71
# 41           0.16
# 42           1.22
# 43           0.12
# 44           0.24
# 45           0.93
# 46           0.03
# 47        -156.59
# 48           0.70
# 49           0.46
# 50           0.58
# 51           0.64
# 52           1.24
# 53           0.44
# 54           0.92
# 55        -906.95
# 56           0.75
# 57           0.23
# 58           0.89
# 59           0.19
# 60           0.53
# 61           0.01
# 62           0.33
# 63           0.44
# 64           1.46
# 65           0.71
# 66           0.62
# 67           0.60
# 68           0.66
# 69        -638.57
# 70           1.34
# 71           0.61
# 72           0.79
# 73           0.24
# 74           1.36
# 75           0.41
# 76           0.85
# 77           0.80
# 78        -301.96
# 79           0.80
# 80           0.19
# 81           0.46
# 82           0.81
# 83           0.07
# 84           0.77
# 85           0.15
# 86           0.28
# 87        -112.35
# 88           0.07
# 89           1.19
# 90           0.87
# 91           2.16
# 92           0.72
# 93           0.13
# 94           0.57
# 95           0.57
# 96         -70.24
# 97           0.05
# 98           0.67
# 99           0.25
# 100          0.90

# %%
# rank
rank = bb.rank(df, rank_by='Sharpe Ratio', group_by=None, num_per_group=50)
rank_filtered = rank
rank_filtered = rank.loc[(rank['3 mo'] > 0) & rank['1 Yr'] > 0]
rank_filtered = rank_filtered.head(20)
rank_filtered
# Out:
#    Investment Option          Description Asset Class   1 mo   3 mo   1 Yr  \
# 91              TSLA                Tesla   US Stocks   7.37  28.54  37.79
# 30              COST               Costco   US Stocks  45.79  98.56  53.77
# 42              FTNT             Fortinet   US Stocks -48.19  23.50  50.82
# 34              DXCM               DexCom   US Stocks -20.83  18.77   6.18
# 16               AZN          AstraZeneca   US Stocks  32.83  64.68  29.13
# 22              AVGO             Broadcom   US Stocks -22.23  46.81  26.91
# 90              TMUS             T-Mobile   US Stocks  43.31 156.72  -3.52
# 76              PANW   Palo Alto Networks   US Stocks -48.46  95.10  59.47
# 82              REGN            Regeneron   US Stocks  39.59  50.34  40.82
# 77              PAYX              Paychex   US Stocks  74.75  50.09  34.02
# 72              ORLY  O'Reilly Automotive   US Stocks  39.88  53.45  32.89
# 84              SGEN               Seagen   US Stocks  -6.13  37.02  -6.27
# 56              LULU            Lululemon   US Stocks 568.27  82.18   6.65
# 25              CTAS               Cintas   US Stocks  21.80  33.57  15.59
# 40              FAST             Fastenal   US Stocks  -2.49   3.08   9.70
# 39               EXC               Exelon   US Stocks 262.42 108.38  53.79
# 98               XEL          Xcel Energy   US Stocks 130.71  40.70   5.22
# 67              MNST     Monster Beverage   US Stocks 204.97   0.14 -13.20
# 10              AMGN                Amgen   US Stocks 122.83  46.08  -1.91
# 94              VRSK               Verisk   US Stocks  18.45  33.05  11.69
#
#      3 Yr  5 Yr  Vola  DS Vola  Std Dev  Annual Returns  Sharpe Ratio
# 91 168.83 75.07 55.57    30.43    78.25          168.83          2.16
# 30  34.21 30.15 27.21    15.44    18.51           34.21          1.85
# 42  48.85 50.41 38.43    26.81    39.99           48.85          1.22
# 34  54.79 42.41 43.36    27.73    47.23           54.79          1.16
# 16  22.68 21.02 23.83    13.85    19.96           22.68          1.14
# 22  26.85 25.88 25.10    17.43    28.82           26.85          0.93
# 90  20.60 14.73 22.21    11.95    23.80           20.60          0.87
# 76  32.97 39.41 31.19    22.25    39.00           32.97          0.85
# 82  26.43 13.20 24.16    12.83    32.50           26.43          0.81
# 77  19.24 20.63 27.03    17.95    24.13           19.24          0.80
# 72  21.28 21.68 30.21    16.00    26.92           21.28          0.79
# 84  25.81 16.13 36.84    22.63    33.63           25.81          0.77
# 56  26.83 46.94 55.44    22.60    35.90           26.83          0.75
# 25  24.66 28.26 21.11    13.23    34.36           24.66          0.72
# 40  19.33 23.07 28.02    19.15    27.10           19.33          0.71
# 39  15.06 19.07 25.29    14.81    21.19           15.06          0.71
# 98  12.49 13.38 12.96     5.20    18.68           12.49          0.67
# 67  14.66 13.54 24.66    12.69    24.31           14.66          0.60
# 10  14.39 12.00 13.33     7.35    24.62           14.39          0.58
# 94  15.28 21.27 17.81     9.52    27.02           15.28          0.57

# %% [markdown]
# ### Sample Portfolios
# Format 'Investment option': weight

# %%
# everything ranked
ranked_portfolio = {
    'Title': 'Ranked Portfolio'
}
everything = list(rank_filtered['Investment Option'])
ranked_portfolio.update(dict.fromkeys(everything, 1/len(everything)))

# top 10
top10_portfolio = {
    'Title': 'Ranked Portfolio'
}
top10 = list(rank_filtered['Investment Option'])[:10]
top10_portfolio.update(dict.fromkeys(top10, 1/len(top10)))

# %% [markdown]
# ### Custom Portfolios

# %%
# My portfolio
my_portfolio = {
    'Title': 'My Portfolio',

}

# %% [markdown]
# ### Choose Portfolio Option

# %%
# Select one of the portfolios from above
portfolio_option = top10_portfolio

# %%
# Make a copy so that the original portfolio is preserved
portfolio_option = portfolio_option.copy()

# %% [markdown]
# ### Analysis Options

# %%
# Specify the weighting scheme.  It will replace the weights specified in the portfolio
# You can also fix the weights on some Investent Options, Asset Classes, and Asset Subclasses
# while the others are automatically calculated.

# 'Equal' - will use equal weights.

# 'Sharpe Ratio' - will use proportionally weighted # allocations based on the percent
#  of an investment option's sharpe ratio to the sum of all the sharpe ratios in the portfolio.

# 'Std Dev' - will use standard deviation adjusted weights

# 'Annual Returns' - will use return adjusted weights

# 'Vola' - will use volatility adjusted weights

# 'DS Vola' - will use downside volatility adjusted weights

# None: 'Investment Option' means use user specified weights
#       'Asset Class' means do not group by Asset Class
#       'Asset Subclass means do not group by Asset Subclass 

weight_by = {
    'Asset Class':       {'weight_by': None},
    'Asset Subclass':    {'weight_by': None},
    'Investment Option': {'weight_by': 'DS Vola'},
}
#weight_by = None

# %%
bb.DEBUG = False

# Analyze portfolio
annual_ret, std_dev, sharpe_ratio = \
    bb.analyze(df, portfolio_option, weight_by)

# %%
# Display Results
summary = bb.summary(df, portfolio_option, annual_ret, std_dev, sharpe_ratio)
summary
# Out:
#                           TSLA   COST   FTNT   DXCM    AZN   AVGO   TMUS  \
# Annual Returns          168.83  34.21  48.85  54.79  22.68  26.85  20.60
# Std Dev                  78.25  18.51  39.99  47.23  19.96  28.82  23.80
# Sharpe Ratio              2.16   1.85   1.22   1.16   1.14   0.93   0.87
# Weight                    0.06   0.12   0.07   0.06   0.13   0.10   0.15
# Worst Typical Down Year  12.33  -2.81 -31.13 -39.67 -17.24 -30.79 -27.00
# Black Swan              -65.92 -21.32 -71.12 -86.90 -37.20 -59.61 -50.80
#
#                           PANW   REGN   PAYX  Ranked Portfolio
# Annual Returns           32.97  26.43  19.24             37.45
# Std Dev                  39.00  32.50  24.13             29.23
# Sharpe Ratio              0.85   0.81   0.80              1.28
# Weight                    0.08   0.14   0.10              1.00
# Worst Typical Down Year -45.03 -38.57 -29.02            -21.02
# Black Swan              -84.03 -71.07 -53.15            -50.25

# %%
# Show pie charts of investment and asset class weights
bb.show_pie_charts(df, portfolio_option, charts=['Investment Option'])
# Out:
# AZN    0.13
# AVGO   0.10
# COST   0.12
# DXCM   0.06
# FTNT   0.07
# PANW   0.08
# PAYX   0.10
# REGN   0.14
# TMUS   0.15
# TSLA   0.06

# %%
# Show exact weights
bb.print_portfolio(portfolio_option)
# Out:
# Ranked Portfolio Weights:
#     TSLA                           0.0584
#     COST                           0.1151
#     FTNT                           0.0663
#     DXCM                           0.0641
#     AZN                            0.1283
#     AVGO                           0.1019
#     TMUS                           0.1487
#     PANW                           0.0799
#     REGN                           0.1385
#     PAYX                           0.0990

# %% [markdown]
# ### Optimize Portfolio

# %%
# Run_portfolio_optimizer = True will run portfolio optimizer after portfolio analysis is complete
run_portfolio_optimizer = True

# %%
# Optimize sharpe ratio while specifying Annual Rate, Worst Typical Down Year,
# and Black Swan.  Setting a constraint to None optimizes absolute Sharpe Ratio
# without regard to that constraint.

'''
constraints = {
    'Annual Return': 12,
    'Worst Typical Down Year': -5,
    'Black Swan': None
}
'''

constraints = {
    'Annual Return': 8,
    'Worst Typical Down Year': None,
    'Black Swan': -40
}

if run_portfolio_optimizer:
    bb.optimizer(df, portfolio_option, constraints)
# Out:
# Running optimizer......
#
# Ranked Portfolio Metrics:
#     max_sharpe_ratio            1.78
#     annual_return              58.36
#     std_dev                    32.80
#     worst typical down year    -7.24
#     black_swan                -40.04
#
#
# Ranked Portfolio Weights:
#     TSLA                           0.1900
#     COST                           0.2900
#     FTNT                           0.1100
#     DXCM                           0.0500
#     AZN                            0.2900
#     AVGO                           0.0000
#     TMUS                           0.0300
#     PANW                           0.0000
#     REGN                           0.0400
#     PAYX                           0.0000

# %% [markdown]
# ### Use Sharpe Ratio adjusted weights
# Recommend that you also try using Sharpe Ratio adjusted weights and compare those results with the Optimized Portflio.
# It tends to produce a higher Annual Return while keeping the allocations more balanced than the Optimizer.  (See 'Analysis Options' section).
