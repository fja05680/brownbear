# %% [markdown]
# <img src="../../images/brownbear.png" width="400">
#
# ## A financial tool that can analyze and maximize investment portfolios on a risk adjusted basis
#
#
# Description: This notebook is useful for examining potfolios comprised of ETFs and S&P 500 stocks.  Construct portfolios from the ETFs and S&P 500 and examine the results of different weighting schemes.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import brownbear as bb

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# display all rows
pd.set_option('display.max_rows', None)

# do not truncate column names
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# ### Some Globals

# %%
investment_universe = ['sp500-galaxy']

# %%
# Fetch Investment Options - all values annualized
df = bb.fetch(investment_universe, risk_free_rate=0, annual_returns='3 Yr', standard_deviation='SD 3 Yr')
df.head(100)
# Out:
#    Investment Option                      Description  \
# 0                MMM                               3M
# 1                AOS                      A. O. Smith
# 2                ABT              Abbott Laboratories
# 3               ABBV                           AbbVie
# 4                ACN                        Accenture
# 5               ADBE                       Adobe Inc.
# 6                AMD           Advanced Micro Devices
# 7                AES                  AES Corporation
# 8                AFL                            Aflac
# 9                  A             Agilent Technologies
# 10               APD                     Air Products
# 11              ABNB                           Airbnb
# 12              AKAM              Akamai Technologies
# 13               ALB            Albemarle Corporation
# 14               ARE  Alexandria Real Estate Equities
# 15              ALGN                 Align Technology
# 16              ALLE                         Allegion
# 17               LNT                   Alliant Energy
# 18               ALL                         Allstate
# 19             GOOGL          Alphabet Inc. (Class A)
# 20              GOOG          Alphabet Inc. (Class C)
# 21                MO                           Altria
# 22              AMZN                           Amazon
# 23              AMCR                            Amcor
# 24               AEE                           Ameren
# 25               AEP          American Electric Power
# 26               AXP                 American Express
# 27               AIG     American International Group
# 28               AMT                   American Tower
# 29               AWK             American Water Works
# 30               AMP             Ameriprise Financial
# 31               AME                           Ametek
# 32              AMGN                            Amgen
# 33               APH                         Amphenol
# 34               ADI                   Analog Devices
# 35              ANSS                            Ansys
# 36               AON                          Aon plc
# 37               APA                  APA Corporation
# 38               APO         Apollo Global Management
# 39              AAPL                       Apple Inc.
# 40              AMAT                Applied Materials
# 41              APTV                            Aptiv
# 42              ACGL               Arch Capital Group
# 43               ADM           Archer Daniels Midland
# 44              ANET                  Arista Networks
# 45               AJG        Arthur J. Gallagher & Co.
# 46               AIZ                         Assurant
# 47                 T                             AT&T
# 48               ATO                     Atmos Energy
# 49              ADSK                         Autodesk
# 50               ADP        Automatic Data Processing
# 51               AZO                         AutoZone
# 52               AVB            AvalonBay Communities
# 53               AVY                   Avery Dennison
# 54              AXON                  Axon Enterprise
# 55               BKR                     Baker Hughes
# 56              BALL                 Ball Corporation
# 57               BAC                  Bank of America
# 58               BAX             Baxter International
# 59               BDX                 Becton Dickinson
# 60             BRK-B               Berkshire Hathaway
# 61               BBY                         Best Buy
# 62              TECH                       Bio-Techne
# 63              BIIB                           Biogen
# 64               BLK                        BlackRock
# 65                BX                  Blackstone Inc.
# 66                BK                       BNY Mellon
# 67                BA                           Boeing
# 68              BKNG                 Booking Holdings
# 69               BSX                Boston Scientific
# 70               BMY             Bristol Myers Squibb
# 71              AVGO                         Broadcom
# 72                BR   Broadridge Financial Solutions
# 73               BRO                    Brown & Brown
# 74              BF-B                     Brown–Forman
# 75              BLDR             Builders FirstSource
# 76                BG                     Bunge Global
# 77               BXP                        BXP, Inc.
# 78              CHRW                    C.H. Robinson
# 79              CDNS           Cadence Design Systems
# 80               CZR            Caesars Entertainment
# 81               CPT            Camden Property Trust
# 82               CPB         Campbell's Company (The)
# 83               COF                      Capital One
# 84               CAH                  Cardinal Health
# 85               KMX                           CarMax
# 86               CCL                         Carnival
# 87              CARR                   Carrier Global
# 88               CAT                 Caterpillar Inc.
# 89              CBOE              Cboe Global Markets
# 90              CBRE                       CBRE Group
# 91               CDW                  CDW Corporation
# 92               COR                          Cencora
# 93               CNC              Centene Corporation
# 94               CNP               CenterPoint Energy
# 95                CF                    CF Industries
# 96               CRL       Charles River Laboratories
# 97              SCHW       Charles Schwab Corporation
# 98              CHTR           Charter Communications
# 99               CVX              Chevron Corporation
#
#                          Asset Class   1 mo   3 mo   1 Yr   3 Yr   5 Yr  \
# 0              US Stocks:Industrials -37.52 -22.55  50.57  10.29   5.62
# 1              US Stocks:Industrials  61.06   9.21 -15.84   4.92  11.66
# 2               US Stocks:Healthcare  14.58  18.36  27.85   6.46   9.67
# 3               US Stocks:Healthcare -25.11  40.75  26.46  12.15  24.10
# 4               US Stocks:Technology -30.60 -59.63   3.27   1.89  13.02
# 5               US Stocks:Technology -14.25 -42.54 -17.71  -1.45   2.69
# 6               US Stocks:Technology -39.04 -47.28 -37.62   5.18  12.22
# 7                US Stocks:Utilities -89.26 -21.25 -39.98 -18.19  -2.12
# 8               US Stocks:Financials -52.43  -4.61  28.78  22.98  25.84
# 9               US Stocks:Healthcare -54.46 -73.36 -20.14  -1.94   8.29
# 10               US Stocks:Materials -51.67 -51.82  20.45   7.93   6.93
# 11  US Stocks:Consumer Discretionary  26.87 -16.84 -21.01  -6.29  -6.29
# 12              US Stocks:Technology  14.23 -53.40 -18.22 -10.13  -4.13
# 13               US Stocks:Materials -88.58 -73.09 -48.98 -31.28  -0.18
# 14             US Stocks:Real Estate -92.42 -63.80 -32.47 -23.26 -10.19
# 15              US Stocks:Healthcare 202.39 -54.64 -36.32 -20.69  -2.44
# 16             US Stocks:Industrials 116.39  29.19  17.68   8.38   8.28
# 17               US Stocks:Utilities -41.44  20.40  27.02   3.94   7.41
# 18              US Stocks:Financials -30.48  17.63  19.55  18.74  17.27
# 19  US Stocks:Communication Services  68.64 -58.02   1.25  12.98  21.74
# 92  21.44    14.68    22.81    22.85    21.60           24.17    22.85
# 93  39.92    26.85    27.82    25.83    25.45           -9.33    25.83
# 94  21.79    13.80    19.01    18.62    19.68           10.44    18.62
# 95  41.48    33.19    22.61    30.70    36.05           -4.00    30.70
# 96 120.26    97.94    37.63    38.61    36.12          -20.86    38.61
# 97  44.80    27.73    27.88    33.70    32.75            8.18    33.70
# 98  66.36    34.14    38.24    39.08    35.67           -7.22    39.08
# 99  51.01    37.58    26.78    28.41    30.11           -0.13    28.41
#
#     Sharpe Ratio
# 0           0.32
# 1           0.17
# 2           0.33
# 3           0.56
# 4           0.08
# 5         -55.33
# 6           0.10
# 7        -749.61
# 8           1.05
# 9         -57.70
# 10          0.30
# 11       -251.10
# 12       -278.88
# 13      -1448.26
# 14       -710.13
# 15      -1052.09
# 16          0.31
# 17          0.23
# 18          0.88
# 19          0.48
# 20          0.49
# 21          0.53
# 22          0.34
# 23        -77.86
# 24          0.27
# 25          0.34
# 26          0.64
# 27          0.62
# 28        -24.68
# 29          0.00
# 30          0.89
# 31          0.52
# 32          0.30
# 33          1.33
# 34          0.39
# 35          0.25
# 36          0.23
# 37       -900.01
# 38          1.11
# 39          0.39
# 40          0.36
# 41       -658.22
# 42          1.01
# 43       -510.94
# 44          1.29
# 45          1.22
# 46          0.17
# 47          0.81
# 48          0.79
# 49          0.48
# 50          0.63
# 51          1.09
# 52        -13.12
# 53         -4.13
# 54          1.63
# 55          0.23
# 56       -387.42
# 57          0.24
# 58       -674.32
# 59       -239.30
# 60          0.93
# 61       -195.78
# 62       -679.72
# 63       -473.68
# 64          0.59
# 65          0.32
# 66          1.26
# 67          0.17
# 68          1.08
# 69          1.96
# 70       -219.49
# 71          1.40
# 72          0.82
# 73          0.92
# 74       -418.92
# 75          0.50
# 76       -299.54
# 77       -460.14
# 78        -40.93
# 79          0.90
# 80      -1209.69
# 81       -134.40
# 82       -102.12
# 83          0.50
# 84          1.58
# 85       -349.57
# 86          0.06
# 87          0.75
# 88          0.48
# 89          1.60
# 90          0.46
# 91          0.08
# 92          1.06
# 93       -240.99
# 94          0.56
# 95       -122.80
# 96       -805.40
# 97          0.24
# 98       -282.16
# 99         -3.69

# %%
# Rank
rank = bb.rank(df, rank_by='Sharpe Ratio', group_by='Asset Subclass', num_per_group=2)
rank_filtered = rank
#rank_filtered = rank.loc[(rank['3 mo'] > 0) & rank['1 Yr'] > 0]
rank_filtered
# Out:
#     Investment Option              Description  \
# 474               VST             Vistra Corp.
# 345               NRG               NRG Energy
# 189              FICO               Fair Isaac
# 347              NVDA                   Nvidia
# 259               IRM            Iron Mountain
# 487              WELL                Welltower
# 289               LIN                Linde plc
# 161               ECL                   Ecolab
# 209               GEV               GE Vernova
# 236               HWM         Howmet Aerospace
# 69                BSX        Boston Scientific
# 84                CAH          Cardinal Health
# 380               PGR  Progressive Corporation
# 89               CBOE      Cboe Global Markets
# 492               WMB       Williams Companies
# 434              TRGP          Targa Resources
# 480 43.49    19.64    22.60    18.75    20.11           26.04    18.75
# 269 36.58    24.89    26.63    29.00    29.00           32.45    29.00
# 444 28.36    15.79    15.18    19.93    22.60           30.09    19.93
# 350 31.03    19.40    15.31    19.57    20.34           25.39    19.57
# 333 48.41    24.43    28.08    35.76    41.81           83.05    35.76
# 445 45.80    28.42    20.82    28.24    31.65           43.11    28.24
#
#      Sharpe Ratio
# 474          1.68
# 345          1.55
# 189          2.28
# 347          1.64
# 259          0.94
# 487          0.82
# 289          0.83
# 161          0.76
# 209          4.15
# 236          1.89
# 69           1.96
# 84           1.58
# 380          1.81
# 89           1.60
# 492          1.09
# 434          1.02
# 480          1.39
# 269          1.12
# 444          1.51
# 350          1.30
# 333          2.32
# 445          1.53

# %% [markdown]
# ### Sample Portfolios
# Format 'Investment option': weight

# %%
# put your "age" in bonds and the rest in stocks
age_portfolio = {
    'Title': 'Age Portfolio',
    'SPY': 0.50,
    'AGG': 0.50
}

# put your "age" in Short Term Treasuries and the rest in stocks
age2_portfolio = {
    'Title': 'Age2 Portfolio',
    'SPY': 0.50,
    'BIL': 0.50
}

# top dogs - top performer by sharpe ratio in each Asset Class, equal weights
top_dog_portfolio = {
    'Title': 'Top Dog Portfolio',
    'XLK': 1/7,
    'IYR': 1/7,
    'VPL': 1/7,
    'FXY': 1/7,
    'PALL': 1/7,
    'BIL': 1/7,
    'SHY': 1/7
}

# 50% S&P 500, 50% long term treasury
fifty_fifty_portfolio = {
    'Title': 'Fifty Fifty Portfolio',
    'SPY': 1/2,
    'TLT': 1/2
}

# 1/3 S&P 500, 1/3 bonds, 1/3 fixed income
thirds_portfolio = {
    'Title': 'Thirds Portfolio',
    'SPY': 1/3,
    'AGG': 1/3,
    'JPST': 1/3
}

# Dave Ramsey: 25% Growth and income, 25% Growth, 25% Aggressive growth, 25% International
dave_ramsey_portfolio = {
    'Title': 'Dave Ramsey Portfolio',
    'VTI': 1/4,
    'SPY': 1/4,
    'QQQ': 1/4,
    'VXUS': 1/4   
}

# Warren Buffett Retirement Fund: 90% S&P500, 10% Short Term Treasuries (sub General Account)
warren_buffett_portfolio = {
    'Title': 'Warren Buffet Portfolio',
    'SPY': 0.90,
    'BIL': 0.10
}

# https://www.forbes.com/sites/baldwin/2016/07/25/eight-famous-portfolios/#42c50d7d5cce
# american households: 25% real estate, 30% stocks, 30% fixed income, 5% cash, 10% alternatives
american_households_portfolio = {
    'Title': 'American Households Portfolio',
    'IYR': 0,
    'SPY': 0,
    'JPST': 0.43,
    'BIL': 0.51,
    'GLD': 0.06
}

# janet yellen: 50% fixed income, 40% S&P500, 10% cash
janet_yellen_portfolio = {
    'Title': 'Janet Yellen Portfolio',
    'JPST': 0.50,
    'SPY': 0.40,
    'BIL': 0.10
}

# risk off: 100% fixed income divided between risk free asset, bond fund, and money market 
risk_off_portfolio = {
    'Title': 'Risk Off Portfolio',
    'BIL': 1/3,
    'AGG': 1/3,
    'JPST': 1/3
}

# risk on: 100% US stocks bevided between large, emerging markets, and small cap
risk_on_portfolio = {
    'Title': 'Risk On Portfolio',
    'SPY': 1/3,
    'EEM':1/3,
}

# everything ranked
ranked_portfolio = {
    'Title': 'Ranked Portfolio'
}
everything = list(rank_filtered['Investment Option'])
ranked_portfolio.update(dict.fromkeys(everything, 1/len(everything)))

# top 10
top10_portfolio = {
    'Title': 'Ranked Portfolio'
}
top10 = list(rank_filtered['Investment Option'])[:10]
top10_portfolio.update(dict.fromkeys(top10, 1/len(top10)))

# %% [markdown]
# ### Custom Portfolios

# %%
# my portfolio
my_portfolio = {
    'Title': 'My Portfolio',

}

# %% [markdown]
# ### Choose Portfolio Option

# %%
# Select one of the portfolios from above
portfolio_option = ranked_portfolio

# %%
# Make a copy so that the original portfolio is preserved
portfolio_option = portfolio_option.copy()

# %% [markdown]
# ### Analysis Options

# %%
# Specify the weighting scheme.  It will replace the weights specified in the portfolio
# You can also fix the weights on some Investent Options, Asset Classes, and Asset Subclasses
# while the others are automatically calculated.

# 'Equal' - will use equal weights.

# 'Sharpe Ratio' - will use proportionally weighted # allocations based on the percent
#  of an investment option's sharpe ratio to the sum of all the sharpe ratios in the portfolio.

# 'Std Dev' - will use standard deviation adjusted weights

# 'Annual Returns' - will use return adjusted weights

# 'Vola' - will use volatility adjusted weights

# 'DS Vola' - will use downside volatility adjusted weights

# None: 'Investment Option' means use user specified weights
#       'Asset Class' means do not group by Asset Class
#       'Asset Subclass means do not group by Asset Subclass 

weight_by = {
    'Asset Class':       {'weight_by': None},
    'Asset Subclass':    {'weight_by': 'Annual Returns'},
    'Investment Option': {'weight_by': 'Equal'},
}
#weight_by = None

# %%
bb.DEBUG = False

# Analyze portfolio
annual_ret, std_dev, sharpe_ratio = \
    bb.analyze(df, portfolio_option, weight_by)

# %%
# Display Results
summary = bb.summary(df, portfolio_option, annual_ret, std_dev, sharpe_ratio)
summary
# Out:
#                            VST    NRG   FICO   NVDA    IRM   WELL    LIN  \
# Annual Returns           81.32  52.19  76.06  83.98  25.47  20.60  15.55
# Std Dev                  48.48  33.66  33.32  51.25  27.20  25.03  18.69
# Sharpe Ratio              1.68   1.55   2.28   1.64   0.94   0.82   0.83
# Weight                    0.04   0.04   0.08   0.08   0.01   0.01   0.02
# Worst Typical Down Year -15.64 -15.13   9.42 -18.52 -28.93 -29.46 -21.83
# Black Swan              -64.12 -48.79 -23.90 -69.77 -56.13 -54.49 -40.52
#
#                            ECL    GEV    HWM  ...   CBOE    WMB   TRGP    WMT  \
# Annual Returns           15.75 158.23  65.38  ...  26.29  26.42  32.20  26.04
# Std Dev                  20.61  38.17  34.54  ...  16.39  24.15  31.42  18.75
# Sharpe Ratio              0.76   4.15   1.89  ...   1.60   1.09   1.02   1.39
# Weight                    0.02   0.07   0.07  ...   0.07   0.04   0.04   0.03
# Worst Typical Down Year -25.47  81.89  -3.70  ...  -6.49 -21.88 -30.64 -11.46
# Black Swan              -46.08  43.72 -38.24  ... -22.88 -46.03 -62.06 -30.21
#
#                           KVUE    TJX   ORLY   NFLX    TKO  Ranked Portfolio
# Annual Returns           32.45  30.09  25.39  83.05  43.11             56.69
# Std Dev                  29.00  19.93  19.57  35.76  28.24             24.62
# Sharpe Ratio              1.12   1.51   1.30   2.32   1.53              2.30
# Weight                    0.03   0.04   0.04   0.09   0.09              1.00
# Worst Typical Down Year -25.55  -9.77 -13.75  11.53 -13.37              7.46
# Black Swan              -54.55 -29.70 -33.32 -24.23 -41.61            -17.16
#
# [6 rows x 23 columns]

# %%
# Show pie charts of investment and asset class weights
bb.show_pie_charts(df, portfolio_option, charts=['Investment Option', 'Asset Subclass'])
# Out:
# NFLX   0.09
# TKO    0.09
# TJX    0.04
# ORLY   0.04
# WMT    0.03
# KVUE   0.03
# TRGP   0.04
# WMB    0.04
# PGR    0.07
# CBOE   0.07
# CAH    0.03
# BSX    0.03
# HWM    0.07
# GEV    0.07
# LIN    0.02
# ECL    0.02
# WELL   0.01
# IRM    0.01
# NVDA   0.08
# FICO   0.08
# NRG    0.04
# VST    0.04
# US Stocks:Communication Services   0.18
# US Stocks:Consumer Discretionary   0.08
# US Stocks:Consumer Staples         0.06
# US Stocks:Energy                   0.08
# US Stocks:Financials               0.14
# US Stocks:Healthcare               0.05
# US Stocks:Industrials              0.13
# US Stocks:Materials                0.04
# US Stocks:Real Estate              0.02
# US Stocks:Technology               0.15
# US Stocks:Utilities                0.08

# %%
# Show exact weights
bb.print_portfolio(portfolio_option)
# Out:
# Ranked Portfolio Weights:
#     VST                            0.0380
#     NRG                            0.0380
#     FICO                           0.0755
#     NVDA                           0.0755
#     IRM                            0.0089
#     WELL                           0.0089
#     LIN                            0.0205
#     ECL                            0.0205
#     GEV                            0.0655
#     HWM                            0.0655
#     BSX                            0.0258
#     CAH                            0.0258
#     PGR                            0.0681
#     CBOE                           0.0681
#     WMB                            0.0397
#     TRGP                           0.0397
#     WMT                            0.0284
#     KVUE                           0.0284
#     TJX                            0.0408
#     ORLY                           0.0408
#     NFLX                           0.0888
#     TKO                            0.0888

# %% [markdown]
# ### Optimize Portfolio

# %%
# Run_portfolio_optimizer = True will run portfolio optimizer after portfolio analysis is complete
run_portfolio_optimizer = False

# %%
# Optimize sharpe ratio while specifying Annual Rate, Worst Typical Down Year,
# and Black Swan.  Setting a constraint to None optimizes absolute Sharpe Ratio
# without regard to that constraint.

'''
constraints = {
    'Annual Return': 12,
    'Worst Typical Down Year': -5,
    'Black Swan': None
}
'''

constraints = {
    'Annual Return': 8,
    'Worst Typical Down Year': None,
    'Black Swan': -40
}

if run_portfolio_optimizer:
    bb.optimizer(df, portfolio_option, constraints)

# %% [markdown]
# ### Use Sharpe Ratio adjusted weights
# Recommend that you also try using Sharpe Ratio adjusted weights and compare those results with the Optimized Portflio.
# It tends to produce a higher Annual Return while keeping the allocations more balanced than the Optimizer.  (See 'Analysis Options' section).
