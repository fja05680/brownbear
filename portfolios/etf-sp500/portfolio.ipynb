# %% [markdown]
# <img src="../../images/brownbear.png" width="400">
#
# ## A financial tool that can analyze and maximize investment portfolios on a risk adjusted basis
#
#
# Description: This notebook is useful for examining potfolios comprised of ETFs and S&P 500 stocks.  Construct portfolios from the ETFs and S&P 500 and examine the results of different weighting schemes.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt
import brownbear as bb

# format price data
pd.options.display.float_format = '{:0.2f}'.format

# display all rows
pd.set_option('display.max_rows', None)

# do not truncate column names
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
# set size of inline plots
'''note: rcParams can't be in same cell as import matplotlib
   or %matplotlib inline
   
   # %matplotlib notebook: will lead to interactive plots embedded within
   the notebook, you can zoom and resize the figure
   
   # %matplotlib inline: only draw static images in the notebook
'''
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# ### Some Globals

# %%
investment_universe = ['sp500-galaxy']

# %%
# Fetch Investment Options - all values annualized
df = bb.fetch(investment_universe, risk_free_rate=0, annual_returns='3 Yr', standard_deviation='SD 3 Yr')
df.head(100)
# Out:
#    Investment Option                      Description  \
# 0                MMM                               3M
# 1                AOS                      A. O. Smith
# 2                ABT              Abbott Laboratories
# 3               ABBV                           AbbVie
# 4                ACN                        Accenture
# 5               ADBE                       Adobe Inc.
# 6                AMD           Advanced Micro Devices
# 7                AES                  AES Corporation
# 8                AFL                            Aflac
# 9                  A             Agilent Technologies
# 10               APD                     Air Products
# 11              ABNB                           Airbnb
# 12              AKAM              Akamai Technologies
# 13               ALB            Albemarle Corporation
# 14               ARE  Alexandria Real Estate Equities
# 15              ALGN                 Align Technology
# 16              ALLE                         Allegion
# 17               LNT                   Alliant Energy
# 18               ALL                         Allstate
# 19             GOOGL          Alphabet Inc. (Class A)
# 20              GOOG          Alphabet Inc. (Class C)
# 21                MO                           Altria
# 22              AMZN                           Amazon
# 23              AMCR                            Amcor
# 24               AEE                           Ameren
# 25               AEP          American Electric Power
# 26               AXP                 American Express
# 27               AIG     American International Group
# 28               AMT                   American Tower
# 29               AWK             American Water Works
# 30               AMP             Ameriprise Financial
# 31               AME                           Ametek
# 32              AMGN                            Amgen
# 33               APH                         Amphenol
# 34               ADI                   Analog Devices
# 35              ANSS                            Ansys
# 36               AON                              Aon
# 37               APA                  APA Corporation
# 38               APO         Apollo Global Management
# 39              AAPL                       Apple Inc.
# 40              AMAT                Applied Materials
# 41              APTV                            Aptiv
# 42              ACGL               Arch Capital Group
# 43               ADM           Archer Daniels Midland
# 44              ANET                  Arista Networks
# 45               AJG        Arthur J. Gallagher & Co.
# 46               AIZ                         Assurant
# 47                 T                             AT&T
# 48               ATO                     Atmos Energy
# 49              ADSK                         Autodesk
# 50               ADP        Automatic Data Processing
# 51               AZO                         AutoZone
# 52               AVB            AvalonBay Communities
# 53               AVY                   Avery Dennison
# 54              AXON                  Axon Enterprise
# 55               BKR                     Baker Hughes
# 56              BALL                 Ball Corporation
# 57               BAC                  Bank of America
# 58               BAX             Baxter International
# 59               BDX                 Becton Dickinson
# 60             BRK-B               Berkshire Hathaway
# 61               BBY                         Best Buy
# 62              TECH                       Bio-Techne
# 63              BIIB                           Biogen
# 64               BLK                        BlackRock
# 65                BX                  Blackstone Inc.
# 66                BK                       BNY Mellon
# 67                BA                           Boeing
# 68              BKNG                 Booking Holdings
# 69               BWA                       BorgWarner
# 70               BSX                Boston Scientific
# 71               BMY             Bristol Myers Squibb
# 72              AVGO                         Broadcom
# 73                BR   Broadridge Financial Solutions
# 74               BRO                    Brown & Brown
# 75              BF-B                     Brown–Forman
# 76              BLDR             Builders FirstSource
# 77                BG                     Bunge Global
# 78               BXP                        BXP, Inc.
# 79              CHRW                    C.H. Robinson
# 80              CDNS           Cadence Design Systems
# 81               CZR            Caesars Entertainment
# 82               CPT            Camden Property Trust
# 83               CPB            Campbell Soup Company
# 84               COF                      Capital One
# 85               CAH                  Cardinal Health
# 86               KMX                           CarMax
# 87               CCL                         Carnival
# 88              CARR                   Carrier Global
# 89               CAT                 Caterpillar Inc.
# 90              CBOE              Cboe Global Markets
# 91              CBRE                       CBRE Group
# 92               CDW                              CDW
# 93                CE                         Celanese
# 94               COR                          Cencora
# 95               CNC              Centene Corporation
# 96               CNP               CenterPoint Energy
# 97                CF                    CF Industries
# 98               CRL       Charles River Laboratories
# 99              SCHW       Charles Schwab Corporation
#
#                          Asset Class   1 mo   3 mo   1 Yr   3 Yr   5 Yr  \
# 0              US Stocks:Industrials  20.03  84.06  86.37  11.79   7.42
# 1              US Stocks:Industrials  33.74 -28.16 -20.86   1.41  11.63
# 2               US Stocks:Healthcare -29.72  47.91   7.07   4.28  11.34
# 3               US Stocks:Healthcare 204.57 119.27  21.32  16.78  24.46
# 4               US Stocks:Technology -90.77 -40.43 -15.17   2.45  14.38
# 5               US Stocks:Technology -85.16 -72.89 -31.84  -4.33   3.50
# 6               US Stocks:Technology -70.30 -60.96 -50.20  -3.12  17.35
# 7                US Stocks:Utilities 987.43 -29.35 -19.15 -14.50  -0.89
# 8               US Stocks:Financials  74.92  14.68  32.00  23.94  25.31
# 9               US Stocks:Healthcare -79.13 -46.47 -17.46  -2.45  11.45
# 10               US Stocks:Materials -52.03 -24.61  22.39  11.55   8.92
# 11  US Stocks:Consumer Discretionary -80.04 -37.72 -26.29  -6.08  -6.08
# 12              US Stocks:Technology -93.25 -55.39 -26.46  -9.57  -1.29
# 13               US Stocks:Materials -13.86 -71.53 -38.01 -25.30   1.24
# 14             US Stocks:Real Estate  62.46 -14.40 -17.57 -16.52  -5.63
# 15              US Stocks:Healthcare -92.10 -75.88 -46.50 -27.83  -6.14
# 16             US Stocks:Industrials -36.24 -34.10  -3.77   4.77   2.63
# 17               US Stocks:Utilities  56.93  19.71  33.68   5.27   6.47
# 18              US Stocks:Financials 218.68  30.61  32.62  22.26  18.83
# 19  US Stocks:Communication Services -70.86 -35.91  20.06   7.62  21.13
# 90  28.32    16.16    18.65    16.10    18.82           24.07    16.10
# 91  36.96    28.56    34.08    33.68    32.04           12.68    33.68
# 92  25.11    18.30    25.72    27.20    26.62            0.40    27.20
# 93 102.63    77.23    49.59    44.27    38.83          -24.05    44.27
# 94  20.29     9.48    22.19    22.41    21.37           22.23    22.41
# 95  36.50    25.31    27.64    25.77    25.92          -11.11    25.77
# 96  19.21     9.76    18.35    18.32    19.90           10.61    18.32
# 97  30.19    22.39    23.45    30.97    36.20           -4.00    30.97
# 98  41.56    19.21    35.86    37.51    36.71          -13.96    37.51
# 99  33.72    19.70    27.99    36.15    33.22            0.49    36.15
#
#     Sharpe Ratio
# 0           0.37
# 1           0.05
# 2           0.21
# 3           0.76
# 4           0.10
# 5        -167.79
# 6        -164.95
# 7        -601.32
# 8           1.04
# 9         -73.33
# 10          0.43
# 11       -255.30
# 12       -269.87
# 13      -1276.38
# 14       -472.64
# 15      -1492.80
# 16          0.17
# 17          0.29
# 18          1.00
# 19          0.27
# 20          0.28
# 21          0.64
# 22          0.35
# 23          0.02
# 24          0.43
# 25          0.39
# 26          0.64
# 27          0.64
# 28         -6.52
# 29         -1.27
# 30          0.81
# 31          0.52
# 32          0.56
# 33          0.83
# 34          0.44
# 35          0.04
# 36          0.51
# 37       -675.66
# 38          0.77
# 39          0.37
# 40          0.19
# 41       -594.21
# 42          1.09
# 43       -411.84
# 44          1.06
# 45          1.42
# 46          0.46
# 47          0.85
# 48          0.69
# 49          0.22
# 50          0.70
# 51          1.31
# 52        -33.88
# 53          0.20
# 54          1.25
# 55          0.29
# 56       -457.25
# 57          0.09
# 58       -680.25
# 59        -51.71
# 60          0.82
# 61       -247.86
# 62       -560.94
# 63       -341.99
# 64          0.45
# 65          0.25
# 66          0.79
# 67       -132.27
# 68          1.00
# 69       -103.08
# 70          1.71
# 71        -19.68
# 72          1.30
# 73          0.76
# 74          1.03
# 75       -387.57
# 76          0.41
# 77       -272.54
# 78       -480.85
# 79          0.06
# 80          0.63
# 81      -1453.60
# 82       -186.00
# 83         -4.74
# 84          0.33
# 85          1.50
# 86       -466.81
# 87          0.07
# 88          0.51
# 89          0.56
# 90          1.50
# 91          0.38
# 92          0.01
# 93      -1064.69
# 94          0.99
# 95       -286.30
# 96          0.58
# 97       -123.88
# 98       -523.64
# 99          0.01

# %%
# Rank
rank = bb.rank(df, rank_by='Sharpe Ratio', group_by='Asset Subclass', num_per_group=2)
rank_filtered = rank
#rank_filtered = rank.loc[(rank['3 mo'] > 0) & rank['1 Yr'] > 0]
rank_filtered
# Out:
#     Investment Option                  Description  \
# 473               VST                 Vistra Corp.
# 122               CEG         Constellation Energy
# 189              FICO                   Fair Isaac
# 347              NVDA                       Nvidia
# 259               IRM                Iron Mountain
# 486              WELL                    Welltower
# 289               LIN                    Linde plc
# 162               ECL                       Ecolab
# 236               HWM             Howmet Aerospace
# 397               RSG            Republic Services
# 70                BSX            Boston Scientific
# 288               LLY                  Lilly (Eli)
# 70     22.73    19.90    18.87    21.35           32.18    18.87          1.71
# 288    24.12    33.24    29.80    31.16           47.08    29.80          1.58
# 380     6.99    26.43    22.88    22.07           41.13    22.88          1.80
# 90     16.16    18.65    16.10    18.82           24.07    16.10          1.50
# 433    18.16    29.80    30.05    53.51           43.77    30.05          1.46
# 490    12.69    19.72    24.32    27.01           27.32    24.32          1.12
# 479    26.60    24.93    21.42    20.21           24.20    21.42          1.13
# 371    12.57    24.84    22.83    21.83           23.69    22.83          1.04
# 51     13.77    15.52    17.98    22.40           23.56    17.98          1.31
# 350    10.45    21.36    21.22    23.56           25.30    21.22          1.19
# 429    19.13    23.94    19.95    22.61           28.99    19.95          1.45
# 311    24.43    29.07    43.07    40.95           45.42    43.07          1.05

# %% [markdown]
# ### Sample Portfolios
# Format 'Investment option': weight

# %%
# put your "age" in bonds and the rest in stocks
age_portfolio = {
    'Title': 'Age Portfolio',
    'SPY': 0.50,
    'AGG': 0.50
}

# put your "age" in Short Term Treasuries and the rest in stocks
age2_portfolio = {
    'Title': 'Age2 Portfolio',
    'SPY': 0.50,
    'BIL': 0.50
}

# top dogs - top performer by sharpe ratio in each Asset Class, equal weights
top_dog_portfolio = {
    'Title': 'Top Dog Portfolio',
    'XLK': 1/7,
    'IYR': 1/7,
    'VPL': 1/7,
    'FXY': 1/7,
    'PALL': 1/7,
    'BIL': 1/7,
    'SHY': 1/7
}

# 50% S&P 500, 50% long term treasury
fifty_fifty_portfolio = {
    'Title': 'Fifty Fifty Portfolio',
    'SPY': 1/2,
    'TLT': 1/2
}

# 1/3 S&P 500, 1/3 bonds, 1/3 fixed income
thirds_portfolio = {
    'Title': 'Thirds Portfolio',
    'SPY': 1/3,
    'AGG': 1/3,
    'JPST': 1/3
}

# Dave Ramsey: 25% Growth and income, 25% Growth, 25% Aggressive growth, 25% International
dave_ramsey_portfolio = {
    'Title': 'Dave Ramsey Portfolio',
    'VTI': 1/4,
    'SPY': 1/4,
    'QQQ': 1/4,
    'VXUS': 1/4   
}

# Warren Buffett Retirement Fund: 90% S&P500, 10% Short Term Treasuries (sub General Account)
warren_buffett_portfolio = {
    'Title': 'Warren Buffet Portfolio',
    'SPY': 0.90,
    'BIL': 0.10
}

# https://www.forbes.com/sites/baldwin/2016/07/25/eight-famous-portfolios/#42c50d7d5cce
# american households: 25% real estate, 30% stocks, 30% fixed income, 5% cash, 10% alternatives
american_households_portfolio = {
    'Title': 'American Households Portfolio',
    'IYR': 0,
    'SPY': 0,
    'JPST': 0.43,
    'BIL': 0.51,
    'GLD': 0.06
}

# janet yellen: 50% fixed income, 40% S&P500, 10% cash
janet_yellen_portfolio = {
    'Title': 'Janet Yellen Portfolio',
    'JPST': 0.50,
    'SPY': 0.40,
    'BIL': 0.10
}

# risk off: 100% fixed income divided between risk free asset, bond fund, and money market 
risk_off_portfolio = {
    'Title': 'Risk Off Portfolio',
    'BIL': 1/3,
    'AGG': 1/3,
    'JPST': 1/3
}

# risk on: 100% US stocks bevided between large, emerging markets, and small cap
risk_on_portfolio = {
    'Title': 'Risk On Portfolio',
    'SPY': 1/3,
    'EEM':1/3,
}

# everything ranked
ranked_portfolio = {
    'Title': 'Ranked Portfolio'
}
everything = list(rank_filtered['Investment Option'])
ranked_portfolio.update(dict.fromkeys(everything, 1/len(everything)))

# top 10
top10_portfolio = {
    'Title': 'Ranked Portfolio'
}
top10 = list(rank_filtered['Investment Option'])[:10]
top10_portfolio.update(dict.fromkeys(top10, 1/len(top10)))

# %% [markdown]
# ### Custom Portfolios

# %%
# my portfolio
my_portfolio = {
    'Title': 'My Portfolio',

}

# %% [markdown]
# ### Choose Portfolio Option

# %%
# Select one of the portfolios from above
portfolio_option = ranked_portfolio

# %%
# Make a copy so that the original portfolio is preserved
portfolio_option = portfolio_option.copy()

# %% [markdown]
# ### Analysis Options

# %%
# Specify the weighting scheme.  It will replace the weights specified in the portfolio
# You can also fix the weights on some Investent Options, Asset Classes, and Asset Subclasses
# while the others are automatically calculated.

# 'Equal' - will use equal weights.

# 'Sharpe Ratio' - will use proportionally weighted # allocations based on the percent
#  of an investment option's sharpe ratio to the sum of all the sharpe ratios in the portfolio.

# 'Std Dev' - will use standard deviation adjusted weights

# 'Annual Returns' - will use return adjusted weights

# 'Vola' - will use volatility adjusted weights

# 'DS Vola' - will use downside volatility adjusted weights

# None: 'Investment Option' means use user specified weights
#       'Asset Class' means do not group by Asset Class
#       'Asset Subclass means do not group by Asset Subclass 

weight_by = {
    'Asset Class':       {'weight_by': None},
    'Asset Subclass':    {'weight_by': 'Annual Returns'},
    'Investment Option': {'weight_by': 'Equal'},
}
#weight_by = None

# %%
bb.DEBUG = False

# Analyze portfolio
annual_ret, std_dev, sharpe_ratio = \
    bb.analyze(df, portfolio_option, weight_by)

# %%
# Display Results
summary = bb.summary(df, portfolio_option, annual_ret, std_dev, sharpe_ratio)
summary
# Out:
#                            VST    CEG   FICO   NVDA    IRM   WELL    LIN  \
# Annual Returns           80.32  63.00  54.73  74.30  24.06  21.81  17.61
# Std Dev                  47.88  43.79  36.45  54.83  27.24  25.53  18.82
# Sharpe Ratio              1.68   1.44   1.50   1.36   0.88   0.85   0.94
# Weight                    0.04   0.04   0.07   0.07   0.01   0.01   0.02
# Worst Typical Down Year -15.44 -24.58 -18.17 -35.36 -30.42 -29.25 -20.03
# Black Swan              -63.32 -68.37 -54.62 -90.19 -57.66 -54.78 -38.85
#
#                            ECL    HWM    RSG  ...   CBOE   TRGP    WMB    WMT  \
# Annual Returns           16.37  55.50  24.27  ...  24.07  43.77  27.32  24.20
# Std Dev                  21.13  34.95  16.79  ...  16.10  30.05  24.32  21.42
# Sharpe Ratio              0.77   1.59   1.45  ...   1.50   1.46   1.12   1.13
# Weight                    0.02   0.06   0.06  ...   0.06   0.05   0.05   0.03
# Worst Typical Down Year -25.89 -14.40  -9.31  ...  -8.13 -16.33 -21.32 -18.64
# Black Swan              -47.02 -49.35 -26.10  ... -24.23 -46.38 -45.64 -40.06
#
#                             PM    AZO   ORLY   TMUS   META  Ranked Portfolio
# Annual Returns           23.69  23.56  25.30  28.99  45.42             40.64
# Std Dev                  22.83  17.98  21.22  19.95  43.07             20.35
# Sharpe Ratio              1.04   1.31   1.19   1.45   1.05              2.00
# Weight                    0.03   0.04   0.04   0.08   0.08              1.00
# Worst Typical Down Year -21.97 -12.40 -17.14 -10.91 -40.72             -0.05
# Black Swan              -44.80 -30.38 -38.36 -30.86 -83.79            -20.40
#
# [6 rows x 23 columns]

# %%
# Show pie charts of investment and asset class weights
bb.show_pie_charts(df, portfolio_option, charts=['Investment Option', 'Asset Subclass'])
# Out:
# META   0.08
# TMUS   0.08
# ORLY   0.04
# AZO    0.04
# WMT    0.03
# PM     0.03
# WMB    0.05
# TRGP   0.05
# PGR    0.06
# CBOE   0.06
# LLY    0.03
# BSX    0.03
# RSG    0.06
# HWM    0.06
# LIN    0.02
# ECL    0.02
# WELL   0.01
# IRM    0.01
# NVDA   0.07
# FICO   0.07
# CEG    0.04
# VST    0.04
# US Stocks:Communication Services   0.15
# US Stocks:Consumer Discretionary   0.07
# US Stocks:Consumer Staples         0.07
# US Stocks:Energy                   0.11
# US Stocks:Financials               0.12
# US Stocks:Healthcare               0.07
# US Stocks:Industrials              0.12
# US Stocks:Materials                0.05
# US Stocks:Real Estate              0.02
# US Stocks:Technology               0.14
# US Stocks:Utilities                0.08

# %%
# Show exact weights
bb.print_portfolio(portfolio_option)
# Out:
# Ranked Portfolio Weights:
#     VST                            0.0414
#     CEG                            0.0414
#     FICO                           0.0710
#     NVDA                           0.0710
#     IRM                            0.0075
#     WELL                           0.0075
#     LIN                            0.0246
#     ECL                            0.0246
#     HWM                            0.0618
#     RSG                            0.0618
#     BSX                            0.0327
#     LLY                            0.0327
#     PGR                            0.0610
#     CBOE                           0.0610
#     TRGP                           0.0543
#     WMB                            0.0543
#     WMT                            0.0341
#     PM                             0.0341
#     AZO                            0.0362
#     ORLY                           0.0362
#     TMUS                           0.0753
#     META                           0.0753

# %% [markdown]
# ### Optimize Portfolio

# %%
# Run_portfolio_optimizer = True will run portfolio optimizer after portfolio analysis is complete
run_portfolio_optimizer = False

# %%
# Optimize sharpe ratio while specifying Annual Rate, Worst Typical Down Year,
# and Black Swan.  Setting a constraint to None optimizes absolute Sharpe Ratio
# without regard to that constraint.

'''
constraints = {
    'Annual Return': 12,
    'Worst Typical Down Year': -5,
    'Black Swan': None
}
'''

constraints = {
    'Annual Return': 8,
    'Worst Typical Down Year': None,
    'Black Swan': -40
}

if run_portfolio_optimizer:
    bb.optimizer(df, portfolio_option, constraints)

# %% [markdown]
# ### Use Sharpe Ratio adjusted weights
# Recommend that you also try using Sharpe Ratio adjusted weights and compare those results with the Optimized Portflio.
# It tends to produce a higher Annual Return while keeping the allocations more balanced than the Optimizer.  (See 'Analysis Options' section).
